# %%
##Update scores, spreads, spreadscores from previous week

# %%
import requests
import json

# An api key is emailed to you when you sign up to a plan
# Get a free API key at https://api.the-odds-api.com/
API_KEY = '8f2863c1fffb9d994a5b359fce7802ba'
# API_KEY = '685f879ea79649c48a2ed648a7876f1f'

SPORT = 'americanfootball_nfl' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h,spreads' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

DATE = '2023-10-10T12:15:00Z'

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports',
    params={
        'api_key': API_KEY
    }
)

# %%
if sports_response.status_code != 200:
    print(f'Failed to get sports: status_code {sports_response.status_code}, response body {sports_response.text}')

else:
    print('List of in season sports:', sports_response.json())
# Out:
# List of in season sports: [{'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_ncaaf_championship_winner', 'group': 'American Football', 'title': 'NCAAF Championship Winner', 'description': 'US College Football Championship Winner', 'active': True, 'has_outrights': True}, {'key': 'americanfootball_nfl', 'group': 'American Football', 'title': 'NFL', 'description': 'US Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Super Bowl Winner 2024/2025', 'active': True, 'has_outrights': True}, {'key': 'baseball_mlb', 'group': 'Baseball', 'title': 'MLB', 'description': 'Major League Baseball', 'active': True, 'has_outrights': False}, {'key': 'baseball_mlb_world_series_winner', 'group': 'Baseball', 'title': 'MLB World Series Winner', 'description': 'World Series Winner 2024', 'active': True, 'has_outrights': True}, {'key': 'basketball_euroleague', 'group': 'Basketball', 'title': 'Basketball Euroleague', 'description': 'Basketball Euroleague', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba', 'group': 'Basketball', 'title': 'NBA', 'description': 'US Basketball', 'active': True, 'has_outrights': False}, {'key': 'basketball_nba_championship_winner', 'group': 'Basketball', 'title': 'NBA Championship Winner', 'description': 'Championship Winner 2024/2025', 'active': True, 'has_outrights': True}, {'key': 'basketball_nbl', 'group': 'Basketball', 'title': 'NBL', 'description': 'AU National Basketball League', 'active': True, 'has_outrights': False}, {'key': 'basketball_ncaab_championship_winner', 'group': 'Basketball', 'title': 'NCAAB Championship Winner', 'description': 'US College Basketball Championship Winner', 'active': True, 'has_outrights': True}, {'key': 'boxing_boxing', 'group': 'Boxing', 'title': 'Boxing', 'description': 'Boxing Bouts', 'active': True, 'has_outrights': False}, {'key': 'cricket_odi', 'group': 'Cricket', 'title': 'One Day Internationals', 'description': 'One Day Internationals', 'active': True, 'has_outrights': False}, {'key': 'cricket_test_match', 'group': 'Cricket', 'title': 'Test Matches', 'description': 'International Test Matches', 'active': True, 'has_outrights': False}, {'key': 'golf_masters_tournament_winner', 'group': 'Golf', 'title': 'Masters Tournament Winner', 'description': '2025 Winner', 'active': True, 'has_outrights': True}, {'key': 'golf_pga_championship_winner', 'group': 'Golf', 'title': 'PGA Championship Winner', 'description': '2025 Winner', 'active': True, 'has_outrights': True}, {'key': 'icehockey_nhl', 'group': 'Ice Hockey', 'title': 'NHL', 'description': 'US Ice Hockey', 'active': True, 'has_outrights': False}, {'key': 'icehockey_nhl_championship_winner', 'group': 'Ice Hockey', 'title': 'NHL Championship Winner', 'description': 'Stanley Cup Winner 2024/2025', 'active': True, 'has_outrights': True}, {'key': 'icehockey_sweden_allsvenskan', 'group': 'Ice Hockey', 'title': 'HockeyAllsvenskan', 'description': 'Swedish Hockey Allsvenskan', 'active': True, 'has_outrights': False}, {'key': 'icehockey_sweden_hockey_league', 'group': 'Ice Hockey', 'title': 'SHL', 'description': 'Swedish Hockey League', 'active': True, 'has_outrights': False}, {'key': 'mma_mixed_martial_arts', 'group': 'Mixed Martial Arts', 'title': 'MMA', 'description': 'Mixed Martial Arts', 'active': True, 'has_outrights': False}, {'key': 'politics_us_presidential_election_winner', 'group': 'Politics', 'title': 'US Presidential Elections Winner', 'description': '2024 US Presidential Election Winner', 'active': True, 'has_outrights': True}, {'key': 'soccer_argentina_primera_division', 'group': 'Soccer', 'title': 'Primera División - Argentina', 'description': 'Argentine Primera División', 'active': True, 'has_outrights': False}, {'key': 'soccer_australia_aleague' ...

# %%
url = f'https://api.the-odds-api.com/v4/historical/sports/{SPORT}/odds?apiKey={API_KEY}&regions={REGIONS}&markets={MARKETS}&date={DATE}'
# ping api for historical data
r = requests.get(url)
if r.status_code == 200:
    # for p in r.content:
    #     print(p)
    spreaddata = json.loads(r.content)

# %%
spreaddata['data'][1]
# Out:
# {'id': 'b956b90b48a7a34230fac518cd294c7a',
#  'sport_key': 'americanfootball_nfl',
#  'sport_title': 'NFL',
#  'commence_time': '2023-10-13T00:16:00Z',
#  'home_team': 'Kansas City Chiefs',
#  'away_team': 'Denver Broncos',
#  'bookmakers': [{'key': 'fanduel',
#    'title': 'FanDuel',
#    'last_update': '2023-10-10T12:10:25Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:10:25Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.1},
#       {'name': 'Kansas City Chiefs', 'price': 1.18}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:10:25Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'betus',
#    'title': 'BetUS',
#    'last_update': '2023-10-10T12:09:56Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:09:56Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.17}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:09:56Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'draftkings',
#    'title': 'DraftKings',
#    'last_update': '2023-10-10T12:07:53Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:07:53Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.1},
#       {'name': 'Kansas City Chiefs', 'price': 1.18}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:07:53Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.89, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.93, 'point': -10.5}]}]},
#   {'key': 'mybookieag',
#    'title': 'MyBookie.ag',
#    'last_update': '2023-10-10T12:09:02Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:09:02Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.1},
#       {'name': 'Kansas City Chiefs', 'price': 1.17}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:09:02Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'superbook',
#    'title': 'SuperBook',
#    'last_update': '2023-10-10T12:09:28Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:09:28Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.25},
#       {'name': 'Kansas City Chiefs', 'price': 1.17}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:09:28Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'betonlineag',
#    'title': 'BetOnline.ag',
#    'last_update': '2023-10-10T12:09:04Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:09:04Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.6},
#       {'name': 'Kansas City Chiefs', 'price': 1.17}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:09:04Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.88, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.94, 'point': -10.5}]}]},
#   {'key': 'lowvig',
#    'title': 'LowVig.ag',
#    'last_update': '2023-10-10T12:09:18Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:09:18Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.6},
#       {'name': 'Kansas City Chiefs', 'price': 1.17}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:09:18Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.94, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.97, 'point': -10.5}]}]},
#   {'key': 'williamhill_us',
#    'title': 'Caesars',
#    'last_update': '2023-10-10T12:08:33Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:08:33Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.3},
#       {'name': 'Kansas City Chiefs', 'price': 1.17}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:08:33Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'bovada',
#    'title': 'Bovada',
#    'last_update': '2023-10-10T12:09:36Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:09:36Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.25},
#       {'name': 'Kansas City Chiefs', 'price': 1.17}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:09:36Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'betrivers',
#    'title': 'BetRivers',
#    'last_update': '2023-10-10T12:10:11Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:10:11Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.1},
#       {'name': 'Kansas City Chiefs', 'price': 1.18}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:10:11Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'unibet_us',
#    'title': 'Unibet',
#    'last_update': '2023-10-10T12:10:16Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:10:16Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.1},
#       {'name': 'Kansas City Chiefs', 'price': 1.18}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:10:16Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'twinspires',
#    'title': 'TwinSpires',
#    'last_update': '2023-10-10T12:09:18Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:09:18Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.1},
#       {'name': 'Kansas City Chiefs', 'price': 1.18}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:09:18Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'pointsbetus',
#    'title': 'PointsBet (US)',
#    'last_update': '2023-10-10T12:09:18Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:09:18Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.16}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:09:18Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'wynnbet',
#    'title': 'WynnBET',
#    'last_update': '2023-10-10T12:06:11Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:06:11Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.4},
#       {'name': 'Kansas City Chiefs', 'price': 1.17}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:06:11Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]},
#   {'key': 'betmgm',
#    'title': 'BetMGM',
#    'last_update': '2023-10-10T12:09:26Z',
#    'markets': [{'key': 'h2h',
#      'last_update': '2023-10-10T12:09:25Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 5.0},
#       {'name': 'Kansas City Chiefs', 'price': 1.18}]},
#     {'key': 'spreads',
#      'last_update': '2023-10-10T12:09:25Z',
#      'outcomes': [{'name': 'Denver Broncos', 'price': 1.91, 'point': 10.5},
#       {'name': 'Kansas City Chiefs', 'price': 1.91, 'point': -10.5}]}]}]}

# %%
odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': API_KEY,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
        'date':'2023-10-10T12:15:00Z',
    }
)

if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(odds_json)

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# Number of events: 18
# [{'id': '269f082de1c875831ceb05c8e0fa6e9e', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2024-10-22T00:15:00Z', 'home_team': 'Tampa Bay Buccaneers', 'away_team': 'Baltimore Ravens', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2024-10-21T14:32:51Z', 'markets': [{'key': 'h2h', 'last_update': '2024-10-21T14:32:51Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.54}, {'name': 'Tampa Bay Buccaneers', 'price': 2.54}]}, {'key': 'spreads', 'last_update': '2024-10-21T14:32:51Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.91, 'point': -3.5}, {'name': 'Tampa Bay Buccaneers', 'price': 1.91, 'point': 3.5}]}]}, {'key': 'williamhill_us', 'title': 'Caesars', 'last_update': '2024-10-21T14:30:11Z', 'markets': [{'key': 'h2h', 'last_update': '2024-10-21T14:30:11Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.53}, {'name': 'Tampa Bay Buccaneers', 'price': 2.58}]}, {'key': 'spreads', 'last_update': '2024-10-21T14:30:11Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.91, 'point': -3.5}, {'name': 'Tampa Bay Buccaneers', 'price': 1.91, 'point': 3.5}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2024-10-21T14:32:06Z', 'markets': [{'key': 'h2h', 'last_update': '2024-10-21T14:32:06Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.53}, {'name': 'Tampa Bay Buccaneers', 'price': 2.63}]}, {'key': 'spreads', 'last_update': '2024-10-21T14:32:06Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.91, 'point': -3.5}, {'name': 'Tampa Bay Buccaneers', 'price': 1.91, 'point': 3.5}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2024-10-21T14:32:06Z', 'markets': [{'key': 'h2h', 'last_update': '2024-10-21T14:32:06Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.53}, {'name': 'Tampa Bay Buccaneers', 'price': 2.6}]}, {'key': 'spreads', 'last_update': '2024-10-21T14:32:06Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.91, 'point': -3.5}, {'name': 'Tampa Bay Buccaneers', 'price': 1.91, 'point': 3.5}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2024-10-21T14:32:51Z', 'markets': [{'key': 'h2h', 'last_update': '2024-10-21T14:32:51Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.53}, {'name': 'Tampa Bay Buccaneers', 'price': 2.65}]}, {'key': 'spreads', 'last_update': '2024-10-21T14:32:51Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.95, 'point': -3.5}, {'name': 'Tampa Bay Buccaneers', 'price': 1.95, 'point': 3.5}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2024-10-21T14:32:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-10-21T14:32:05Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.53}, {'name': 'Tampa Bay Buccaneers', 'price': 2.65}]}, {'key': 'spreads', 'last_update': '2024-10-21T14:32:05Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.91, 'point': -3.5}, {'name': 'Tampa Bay Buccaneers', 'price': 1.91, 'point': 3.5}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2024-10-21T14:32:52Z', 'markets': [{'key': 'h2h', 'last_update': '2024-10-21T14:32:52Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.51}, {'name': 'Tampa Bay Buccaneers', 'price': 2.55}]}, {'key': 'spreads', 'last_update': '2024-10-21T14:32:52Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.91, 'point': -3.5}, {'name': 'Tampa Bay Buccaneers', 'price': 1.91, 'point': 3.5}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2024-10-21T14:32:51Z', 'markets': [{'key': 'h2h', 'last_update': '2024-10-21T14:32:51Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.53}, {'name': 'Tampa Bay Buccaneers', 'price': 2.55}]}, {'key': 'spreads', 'last_update': '2024-10-21T14:32:51Z', 'outcomes': [{'name': 'Baltimore Ravens', 'price': 1.91, 'point': -3.5}, {'name': 'Tampa Bay Buccaneers', 'price': 1.91, 'point': 3.5}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2024-10-21T14:32:05Z', 'markets': [{'key': 'h2h', 'last_update': '2024-10-21T14:32:05Z', ' ...
# Remaining requests 19994
# Used requests 6

# %%
import pandas as pd

dfseasonspreads = pd.read_csv('data/Season_spreads.csv', index_col=0)

# [game for game in json.loads(data.decode("utf-8"))['response'] if
#  game['teams']['away']['name'] == 'Buffalo Bills' and game['game']['stage'] == 'Regular Season']
import http.client
import json

conn = http.client.HTTPSConnection("v1.american-football.api-sports.io")
scoreskey = '40c091a0954eb4e610a4cc8fce5cefd7'
headers = {
    'x-rapidapi-host': "v1.american-football.api-sports.io",
    'x-rapidapi-key': scoreskey
}

conn.request("GET", "/games?league=1&season=2023", headers=headers)

res = conn.getresponse()
data = res.read()
games = [game for game in json.loads(data.decode("utf-8"))['response'] if
         game['game']['stage'] == 'Regular Season' and game['game']['status']['short'] != 'NS']
weeks = list(set([game['game']['week'] for game in games]))
gamescores = {}
gamescorediffs = {}
for game in games:
    if game['game']['week'] == weeks[-1]:
        gamescores[game['teams']['home']['name']] = game['scores']['home']['total']
        gamescores[game['teams']['away']['name']] = game['scores']['away']['total']
        gamescorediffs[game['teams']['home']['name']] = game['scores']['home']['total'] - game['scores']['away'][
            'total']
        gamescorediffs[game['teams']['away']['name']] = game['scores']['away']['total'] - game['scores']['home'][
            'total']

dfgameresults = pd.concat([pd.Series(gamescores, name=weeks[-1] + ' score'),
                           pd.Series(gamescorediffs, name=weeks[-1] + ' diff')], axis=1)
dfseasonspreads_temp = dfseasonspreads.merge(dfgameresults, left_index=True, right_index=True, how='left')
dfseasonspreads_temp['Week 1 spreadscore'] = dfseasonspreads_temp[weeks[-1] + ' diff'] + dfseasonspreads_temp[
    weeks[-1] + ' spread']
dfseasonspreads_temp
import requests

API_KEY = '685f879ea79649c48a2ed648a7876f1f'
url = f'https://api.the-odds-api.com/v4/sports/americanfootball_nfl/odds?regions=us&markets=h2h,spreads,totals&oddsFormat=american&apiKey={API_KEY}'

r = requests.get(url)

r = requests.get(url)
if r.status_code == 200:
    # for p in r.content:
    #     print(p)
    spreaddata = json.loads(r.content)
    # print(spreaddata)
# import datetime
# today  = datetime.datetime.now().date()
# today + datetime.timedelta(days=7)

thisweek = [game for game in spreaddata]
games = [game['bookmakers'][0]['markets'] for game in
         thisweek]  #+ [game['bookmakers'][1]['markets'] for game in thisweek]

thisweek_spreads = {}
for game in games:
    for bet in game:
        if bet['key'] == 'spreads':
            thisweek_spreads[bet['outcomes'][0]['name']] = bet['outcomes'][0]['point']
            thisweek_spreads[bet['outcomes'][1]['name']] = bet['outcomes'][1]['point']
thisweek_spreads
dfseasonspreads_temp = pd.concat(
    [dfseasonspreads_temp, pd.Series(thisweek_spreads, name=weeks[-1][:-1] + str(int(weeks[-1][-1]) + 1) + ' spread')],
    axis=1)
# dfseasonspreads
# Out:
# [{'id': '217559949d3b88a1267c2c4c480eab51', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2023-09-15T00:16:00Z', 'home_team': 'Philadelphia Eagles', 'away_team': 'Minnesota Vikings', 'bookmakers': [{'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-09-13T08:18:24Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-13T08:18:24Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': 250}, {'name': 'Philadelphia Eagles', 'price': -310}]}, {'key': 'spreads', 'last_update': '2023-09-13T08:18:24Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': -110, 'point': 7.0}, {'name': 'Philadelphia Eagles', 'price': -110, 'point': -7.0}]}, {'key': 'totals', 'last_update': '2023-09-13T08:18:24Z', 'outcomes': [{'name': 'Over', 'price': -108, 'point': 49.0}, {'name': 'Under', 'price': -112, 'point': 49.0}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-09-13T08:18:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-13T08:18:38Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': 250}, {'name': 'Philadelphia Eagles', 'price': -320}]}, {'key': 'spreads', 'last_update': '2023-09-13T08:18:38Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': -110, 'point': 7.0}, {'name': 'Philadelphia Eagles', 'price': -110, 'point': -7.0}]}, {'key': 'totals', 'last_update': '2023-09-13T08:18:38Z', 'outcomes': [{'name': 'Over', 'price': -110, 'point': 49.0}, {'name': 'Under', 'price': -110, 'point': 49.0}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-09-13T08:18:03Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-13T08:18:03Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': 250}, {'name': 'Philadelphia Eagles', 'price': -315}]}, {'key': 'spreads', 'last_update': '2023-09-13T08:18:03Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': -112, 'point': 7.0}, {'name': 'Philadelphia Eagles', 'price': -109, 'point': -7.0}]}, {'key': 'totals', 'last_update': '2023-09-13T08:18:03Z', 'outcomes': [{'name': 'Over', 'price': -114, 'point': 48.0}, {'name': 'Under', 'price': -107, 'point': 48.0}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2023-09-13T08:18:28Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-13T08:18:28Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': 260}, {'name': 'Philadelphia Eagles', 'price': -315}]}, {'key': 'spreads', 'last_update': '2023-09-13T08:18:28Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': -110, 'point': 7.0}, {'name': 'Philadelphia Eagles', 'price': -110, 'point': -7.0}]}, {'key': 'totals', 'last_update': '2023-09-13T08:18:28Z', 'outcomes': [{'name': 'Over', 'price': -110, 'point': 49.0}, {'name': 'Under', 'price': -110, 'point': 49.0}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-09-13T08:18:19Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-13T08:18:19Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': 260}, {'name': 'Philadelphia Eagles', 'price': -305}]}, {'key': 'spreads', 'last_update': '2023-09-13T08:18:19Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': -112, 'point': 7.0}, {'name': 'Philadelphia Eagles', 'price': -109, 'point': -7.0}]}, {'key': 'totals', 'last_update': '2023-09-13T08:18:19Z', 'outcomes': [{'name': 'Over', 'price': -114, 'point': 48.0}, {'name': 'Under', 'price': -107, 'point': 48.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-09-13T08:17:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-13T08:17:38Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': 250}, {'name': 'Philadelphia Eagles', 'price': -330}]}, {'key': 'spreads', 'last_update': '2023-09-13T08:17:38Z', 'outcomes': [{'name': 'Minnesota Vikings', 'price': -110, 'point': 7.0}, {'name': 'Philadelphia Eagles', 'price': -110, 'point': -7.0}]}, {'key': 'totals', 'last_update': '2023-09-13T08:17:38Z', 'outcomes': [{'name': 'Over', 'price': -110, 'point': 49.0}, {'name': 'Under', 'price': -110, 'point': 49.0}]}]}, {'key': 'twinspires', 'tit ...

# %% [markdown]
# #### start model dataset creation

# %%
def create_spread():
    pass ## no longer needs this function, serves to learn!
#     ## import spreadsheet and select timeframe of interest
#     # create dictionary of teams and shortnames
#     teams_save = ['Chicago Bears', 'Arizona Cardinals', 'Carolina Panthers',
#                   'Cleveland Browns', 'Dallas Cowboys', 'Jacksonville Jaguars',
#                   'Los Angeles Chargers', 'Miami Dolphins', 'Minnesota Vikings',
#                   'New England Patriots', 'New York Jets', 'Philadelphia Eagles',
#                   'Seattle Seahawks', 'Tampa Bay Buccaneers', 'New Orleans Saints',
#                   'Las Vegas Raiders', 'Atlanta Falcons', 'Baltimore Ravens',
#                   'Cincinnati Bengals', 'Denver Broncos', 'Detroit Lions', 'Los Angeles Chargers',
#                   'Green Bay Packers', 'Houston Texans', 'Los Angeles Rams',
#                   'New York Giants', 'Pittsburgh Steelers', 'Tennessee Titans',
#                   'Washington Commanders', 'Buffalo Bills', 'Indianapolis Colts',
#                   'Kansas City Chiefs', 'San Francisco 49ers']
#
#     ids = ['CHI', 'ARI', 'CAR', 'CLE', 'DAL', 'JAC', 'LAC', 'MIA', 'MIN', 'NE',
#            'NYJ', 'PHI', 'SEA', 'TB', 'NO', 'LVR', 'ATL', 'BAL', 'CIN', 'DEN',
#            'DET', 'LAC', 'GB', 'HOU', 'LAR', 'NYG', 'PIT', 'TEN', 'WAS', 'BUF',
#            'IND', 'KC', 'SF']
#     teamids = {teams_save[i]: ids[i] for i in range(len(teams_save))}
#
#     dfnfl = pd.read_csv('data/spreadspoke_scores.csv')
#     dfnfl.loc[:, 'gamedate'] = pd.to_datetime(dfnfl.loc[:, 'schedule_date'])
#     dfnfl['scoredif'] = dfnfl['score_home'] - dfnfl['score_away']
#     dfnfltime = dfnfl[dfnfl['gamedate'] > pd.to_datetime('2000-07-15')].copy()
#     # dfnfltime = dfnfltime[dfnfltime['gamedate'] < pd.to_datetime('2021-1-31')]
#     dfnfltime = dfnfltime[dfnfltime['schedule_playoff'] == False].copy()
#     dfnfltime['schedule_week'] = pd.to_numeric(dfnfltime['schedule_week'])
#     dfnfltime = dfnfltime.replace('Washington Redskins', 'Washington Commanders')
#     dfnfltime = dfnfltime.replace('Washington Football Team', 'Washington Commanders')
#     dfnfltime = dfnfltime.replace('Oakland Raiders', 'Las Vegas Raiders')
#     dfnfltime = dfnfltime.replace('St. Louis Rams', 'Los Angeles Rams')
#     dfnfltime = dfnfltime.replace('San Diego Chargers', 'Los Angeles Chargers')
#
#     # split dataframe from game indexed (home and away) to each teams score and spread
#     dfnfltimehome = dfnfltime[['schedule_date', 'schedule_season', 'schedule_week', 'schedule_playoff',
#                                'team_home', 'score_home', 'team_favorite_id', 'spread_favorite', 'gamedate',
#                                'scoredif']].copy()
#     dfnfltimehome.loc[:, 'team'] = dfnfltimehome['team_home'].copy()
#     dfnfltimehome.loc[:, 'score'] = dfnfltimehome['score_home'].copy()
#     dfnfltimehome['scoredif'] = dfnfltimehome['scoredif'].copy()
#     dfnfltimeaway = dfnfltime[['schedule_date', 'schedule_season', 'schedule_week', 'schedule_playoff',
#                                'team_away', 'score_away', 'team_favorite_id', 'spread_favorite', 'gamedate',
#                                'scoredif']].copy()
#     dfnfltimeaway.loc[:, 'team'] = dfnfltimeaway['team_away'].copy()
#     dfnfltimeaway.loc[:, 'score'] = dfnfltimeaway['score_away'].copy()
#     dfnfltimeaway.loc[:, 'scoredif'] = -dfnfltimeaway['scoredif'].copy()
#     dfnfltimesingle = pd.concat([dfnfltimehome.copy(), dfnfltimeaway.copy()])
#     dfnfltimesingle.drop(['score_home', 'team_home', 'team_away', 'score_away'], axis=1, inplace=True)
#     dfnfltimesingle = dfnfltimesingle.sort_values(['schedule_season', 'schedule_week']).copy()
#
#     # calculate each teams score ATS and whether covered ATS
#     def spread(team, team_favorite_id, scoredif, spread_favorite, teamids):
#         if teamids[team] == team_favorite_id:
#             spreadscore = scoredif + spread_favorite
#         else:
#             spreadscore = scoredif - spread_favorite
#         return spreadscore
#
#     dfnfltimesingle['spreadscore'] = dfnfltimesingle.apply(
#         lambda row: spread(row['team'], row['team_favorite_id'], row['scoredif'], row['spread_favorite'], teamids),
#         axis=1)
#
#     # regular season only
#     # dfnfltimesingle = dfnfltimesingle[dfnfltimesingle['schedule_playoff'] == False].copy()
#     dfnfltimesingle = dfnfltimesingle[dfnfltimesingle['schedule_week'] < 18].copy()
#     dfnfltimesingle.drop(['schedule_playoff'], axis=1, inplace=True)
#     dfnfltimesingle = dfnfltimesingle.reset_index().copy()
#     dfnfltimesingle
#
#     ### get each teams score ATS each week of the season, concat seasons vertically
#     years = dfnfltimesingle['schedule_season'].unique()
#     years = list(range(2000, 2021))
#     print(years)
#     dfspreadall = []
#
#     for year in years:
#         print(year)
#         dfnfltimesingleloop = dfnfltimesingle[dfnfltimesingle['schedule_season'] == year].copy()
#
#         # create dataframe of score ATS for each team through the season
#         dfspread = pd.DataFrame(
#             dfnfltimesingleloop[dfnfltimesingle['team'] == teams_save[0]]['spreadscore']).copy().reset_index(drop=True)
#         for team in teams_save:
#
#             if team != teams_save[0]:
#                 seasonspread = pd.DataFrame(
#                     dfnfltimesingleloop[dfnfltimesingleloop['team'] == team]['spreadscore']).reset_index(drop=True)
#                 dfspread = pd.concat([dfspread, seasonspread], axis=1)
#         dfspread.columns = teams_save
#         dfspread = dfspread.transpose()
#
#         dfspread.dropna(inplace=True)
#         dfspread['Year'] = year
#         dfspreadall.append(dfspread)
#     dfspreadall = pd.concat(dfspreadall)
#     return dfspreadall.reset_index().rename(columns={'index':"Team",0: "Week_1", 1: "Week_2",2: "Week_3", 3: "Week_4",4: "Week_5", 5: "Week_6",6: "Week_7", 7: "Week_8",8: "Week_9", 9: "Week_10",10: "Week_11", 11: "Week_12",12: "Week_13", 13: "Week_14",14: "Week_15", 15: "Week_16"})
# dfspread = create_spread()

# %%
import pandas as pd

teams_save = ['Chicago Bears', 'Arizona Cardinals', 'Carolina Panthers',
              'Cleveland Browns', 'Dallas Cowboys', 'Jacksonville Jaguars',
              'Los Angeles Chargers', 'Miami Dolphins', 'Minnesota Vikings',
              'New England Patriots', 'New York Jets', 'Philadelphia Eagles',
              'Seattle Seahawks', 'Tampa Bay Buccaneers', 'New Orleans Saints',
              'Las Vegas Raiders', 'Atlanta Falcons', 'Baltimore Ravens',
              'Cincinnati Bengals', 'Denver Broncos', 'Detroit Lions', 'Los Angeles Chargers',
              'Green Bay Packers', 'Houston Texans', 'Los Angeles Rams',
              'New York Giants', 'Pittsburgh Steelers', 'Tennessee Titans',
              'Washington Commanders', 'Buffalo Bills', 'Indianapolis Colts',
              'Kansas City Chiefs', 'San Francisco 49ers']

ids = ['CHI', 'ARI', 'CAR', 'CLE', 'DAL', 'JAC', 'LAC', 'MIA', 'MIN', 'NE',
       'NYJ', 'PHI', 'SEA', 'TB', 'NO', 'LVR', 'ATL', 'BAL', 'CIN', 'DEN',
       'DET', 'LAC', 'GB', 'HOU', 'LAR', 'NYG', 'PIT', 'TEN', 'WAS', 'BUF',
       'IND', 'KC', 'SF']
teamids = {teams_save[i]: ids[i] for i in range(len(teams_save))}

dfnfl = pd.read_csv('data/spreadspoke_scores.csv')
dfnfl.loc[:, 'gamedate'] = pd.to_datetime(dfnfl.loc[:, 'schedule_date'])
dfnfl['scoredif'] = dfnfl['score_home'] - dfnfl['score_away']
dfnfltime = dfnfl[dfnfl['gamedate'] > pd.to_datetime('2000-07-15')].copy()
# dfnfltime = dfnfltime[dfnfltime['gamedate'] < pd.to_datetime('2021-1-31')]
dfnfltime = dfnfltime[dfnfltime['schedule_playoff'] == False].copy()
dfnfltime['schedule_week'] = pd.to_numeric(dfnfltime['schedule_week'])
dfnfltime = dfnfltime.replace('Washington Redskins', 'Washington Commanders')
dfnfltime = dfnfltime.replace('Washington Football Team', 'Washington Commanders')
dfnfltime = dfnfltime.replace('Oakland Raiders', 'Las Vegas Raiders')
dfnfltime = dfnfltime.replace('St. Louis Rams', 'Los Angeles Rams')
dfnfltime = dfnfltime.replace('San Diego Chargers', 'Los Angeles Chargers')

# %%
dfnfltime
# Out:
#       schedule_date  schedule_season  schedule_week  schedule_playoff  \
# 7354       9/3/2000             2000              1             False
# 7355       9/3/2000             2000              1             False
# 7356       9/3/2000             2000              1             False
# 7357       9/3/2000             2000              1             False
# 7358       9/3/2000             2000              1             False
# ...             ...              ...            ...               ...
# 13498      1/8/2023             2022             18             False
# 13499      1/8/2023             2022             18             False
# 13500      1/8/2023             2022             18             False
# 13501      1/8/2023             2022             18             False
# 13502      1/8/2023             2022             18             False
#
#                    team_home  score_home  score_away             team_away  \
# 7354         Atlanta Falcons          36          28   San Francisco 49ers
# 7355           Buffalo Bills          16          13      Tennessee Titans
# 7356        Cleveland Browns           7          27  Jacksonville Jaguars
# 7357          Dallas Cowboys          14          41   Philadelphia Eagles
# 7358       Green Bay Packers          16          20         New York Jets
# ...                      ...         ...         ...                   ...
# 13498    Philadelphia Eagles          22          16       New York Giants
# 13499    Pittsburgh Steelers          28          14      Cleveland Browns
# 13500    San Francisco 49ers          38          13     Arizona Cardinals
# 13501       Seattle Seahawks          19          16      Los Angeles Rams
# 13502  Washington Commanders          26           6        Dallas Cowboys
#
#       team_favorite_id  spread_favorite over_under_line  \
# 7354               ATL             -6.5            46.5
# 7355               BUF             -1.0              40
# 7356               JAX            -10.5            38.5
# 7357               DAL             -6.0            39.5
# 7358                GB             -2.5              44
# ...                ...              ...             ...
# 13498              PHI            -17.0              43
# 13499              PIT             -2.5              40
# 13500               SF            -14.5              40
# 13501              SEA             -4.5              43
# 13502              DAL             -7.5              41
#
#                        stadium  stadium_neutral  weather_temperature  \
# 7354              Georgia Dome            False                 72.0
# 7355      Ralph Wilson Stadium            False                 70.0
# 7356       FirstEnergy Stadium            False                 75.0
# 7357             Texas Stadium            False                 95.0
# 7358             Lambeau Field            False                 69.0
# ...                        ...              ...                  ...
# 13498  Lincoln Financial Field            False                  NaN
# 13499         Acrisure Stadium            False                  NaN
# 13500           Levi's Stadium            False                  NaN
# 13501              Lumen Field            False                  NaN
# 13502              FedEx Field            False                  NaN
#
#        weather_wind_mph  weather_humidity weather_detail   gamedate  scoredif
# 7354                0.0               NaN         indoor 2000-09-03         8
# 7355                7.0              82.0            NaN 2000-09-03         3
# 7356                8.0              86.0            NaN 2000-09-03       -20
# 7357                7.0              32.0            NaN 2000-09-03       -27
# 7358               13.0              87.0            NaN 2000-09-03        -4
# ...                 ...               ...            ...        ...       ...
# 13498               NaN               NaN            NaN 2023-01-08         6
# 13499               NaN               NaN            NaN 2023-01-08        14
# 13500               NaN               NaN            NaN 2023-01-08        25
# 13501               NaN               NaN            NaN 2023-01-08         3
# 13502               NaN               NaN            NaN 2023-01-08        20
#
# [5903 rows x 19 columns]

# %%
def gameSpreadScore_v0(team_home, team_away, team_favorite_id, scoredif, spread_favorite,teamids,week,year):
    if teamids[team_home] == team_favorite_id:
        spreadscore = scoredif + spread_favorite
        # homespread = spread_favorite
    else:
        spreadscore = scoredif - spread_favorite
        # homespread = -spread_favorite

    return team_home, spreadscore,team_away,-spreadscore,week,year#,homespread,-homespread,overunder

# %%
def gameSpreadScore(team_home, team_away, team_favorite_id, scoredif, spread_favorite,teamids,week,year,overunder):
    if teamids[team_home] == team_favorite_id:
        spreadscore = scoredif + spread_favorite
        homespread = spread_favorite
    else:
        spreadscore = scoredif - spread_favorite
        homespread = -spread_favorite

    return team_home, spreadscore,team_away,-spreadscore,week,year,homespread,-homespread,overunder

dfnflspread_zip = dfnfltime.apply(lambda row: gameSpreadScore(row['team_home'],row['team_away'], row['team_favorite_id'], row['scoredif'], row['spread_favorite'],teamids,row['schedule_week'],row['schedule_season'],row['over_under_line']), axis=1).apply(pd.Series)
dfnflspread_zip
# Out:
#                            0     1                     2     3   4     5  \
# 7354         Atlanta Falcons   1.5   San Francisco 49ers  -1.5   1  2000
# 7355           Buffalo Bills   2.0      Tennessee Titans  -2.0   1  2000
# 7356        Cleveland Browns  -9.5  Jacksonville Jaguars   9.5   1  2000
# 7357          Dallas Cowboys -33.0   Philadelphia Eagles  33.0   1  2000
# 7358       Green Bay Packers  -6.5         New York Jets   6.5   1  2000
# ...                      ...   ...                   ...   ...  ..   ...
# 13498    Philadelphia Eagles -11.0       New York Giants  11.0  18  2022
# 13499    Pittsburgh Steelers  11.5      Cleveland Browns -11.5  18  2022
# 13500    San Francisco 49ers  10.5     Arizona Cardinals -10.5  18  2022
# 13501       Seattle Seahawks  -1.5      Los Angeles Rams   1.5  18  2022
# 13502  Washington Commanders  27.5        Dallas Cowboys -27.5  18  2022
#
#           6     7     8
# 7354   -6.5   6.5  46.5
# 7355   -1.0   1.0    40
# 7356   10.5 -10.5  38.5
# 7357   -6.0   6.0  39.5
# 7358   -2.5   2.5    44
# ...     ...   ...   ...
# 13498 -17.0  17.0    43
# 13499  -2.5   2.5    40
# 13500 -14.5  14.5    40
# 13501  -4.5   4.5    43
# 13502   7.5  -7.5    41
#
# [5903 rows x 9 columns]

# %%
dfspread = pd.concat([dfnflspread_zip[[0,1,4,5]],dfnflspread_zip[[2,3,4,5]].rename(columns={2:0,3:1})]).rename(columns={0:'Team',1:'Spread',4:'Week',5:'Year'}).set_index(['Team','Year','Week']).unstack()
dfspread.columns = dfspread.columns.droplevel()
# dfspread.columns = ['Week_'+str(i) for i in dfspread.columns]
dfspread['teamyearid'] = dfspread.index.map(lambda x: '-'.join(map(str, x)))
dfspread.set_index('teamyearid',inplace=True,append=True)

dfspreadts = dfspread.T
# dfspread.to_csv('data/dfspread.csv')
dfspread
# Out:
# Week                                                      1     2     3     4  \
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000       1.5  -2.0   NaN -27.0
#                       2001 Arizona Cardinals-2001       NaN -12.5 -17.0  15.5
#                       2002 Arizona Cardinals-2002      -2.0  15.0  -5.5  17.0
#                       2003 Arizona Cardinals-2003     -14.5 -33.0  14.5 -12.5
#                       2004 Arizona Cardinals-2004       4.0  -3.0   8.0  27.5
# ...                                                     ...   ...   ...   ...
# Washington Commanders 2018 Washington Commanders-2018  20.0 -18.0  16.5   NaN
#                       2019 Washington Commanders-2019   5.0  -4.0 -11.0 -18.0
#                       2020 Washington Commanders-2020  15.0  -8.0  -7.0   0.0
#                       2021 Washington Commanders-2021  -3.0  -2.0 -15.0   2.0
#                       2022 Washington Commanders-2022   3.0  -8.0 -10.0 -12.0
#
# Week                                                      5     6     7     8  \
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000      -3.5   3.5 -16.5 -34.0
#                       2001 Arizona Cardinals-2001      -0.0  10.0 -17.0  -7.0
#                       2002 Arizona Cardinals-2002       8.0   NaN  -0.5  -1.5
#                       2003 Arizona Cardinals-2003      -9.5  -1.5   NaN  10.0
#                       2004 Arizona Cardinals-2004      -2.0   NaN  14.5 -19.5
# ...                                                     ...   ...   ...   ...
# Washington Commanders 2018 Washington Commanders-2018 -18.5   7.0   4.0   6.0
#                       2019 Washington Commanders-2019  -9.5  -4.5   1.0   6.5
#                       2020 Washington Commanders-2020 -13.0   1.5  21.0   NaN
#                       2021 Washington Commanders-2021  -8.5 -11.5  -5.5  -3.0
#                       2022 Washington Commanders-2022  -3.0   4.0   6.0   4.0
#
# Week                                                      9    10    11    12  \
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000      -5.0  11.0  -4.5 -18.0
#                       2001 Arizona Cardinals-2001      -1.5   5.0  10.0  16.0
#                       2002 Arizona Cardinals-2002      -8.0 -24.0 -12.0 -11.5
#                       2003 Arizona Cardinals-2003       6.0  -6.0 -33.0   4.0
#                       2004 Arizona Cardinals-2004       4.0   2.0 -22.0  -7.0
# ...                                                     ...   ...   ...   ...
# Washington Commanders 2018 Washington Commanders-2018 -25.5  16.5   1.0  -1.0
#                       2019 Washington Commanders-2019  -4.5   NaN -19.0   7.0
#                       2020 Washington Commanders-2020  -5.5  -0.0   9.5  28.0
#                       2021 Washington Commanders-2021   NaN  20.0   9.0   3.5
#                       2022 Washington Commanders-2022   0.0  22.0  10.0   2.5
#
# Week                                                     13    14    15    16  \
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000     -18.0  -7.0 -49.0   9.0
#                       2001 Arizona Cardinals-2001     -12.0   1.0   3.5  24.0
#                       2002 Arizona Cardinals-2002     -40.0   4.0   9.0   0.5
#                       2003 Arizona Cardinals-2003     -20.5 -25.5   4.0  -2.5
#                       2004 Arizona Cardinals-2004      -8.0 -10.0  27.0   4.0
# ...                                                     ...   ...   ...   ...
# Washington Commanders 2018 Washington Commanders-2018  -9.5 -21.0  -4.5   2.5
#                       2019 Washington Commanders-2019  18.5   8.0  -3.5  -5.0
#                       2020 Washington Commanders-2020  12.0  11.0   1.0  -6.0
#                       2021 Washington Commanders-2021   3.5  -0.5  -0.0 -32.0
#                       2022 Washington Commanders-2022  -2.5   NaN -12.0 -10.5
#
# Week                                                     17    18
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000     -10.0   NaN
#                       2001 Arizona Cardinals-2001       0.5   NaN
#                       2002 Arizona Cardinals-2002     -16.5   NaN
#                       2003 Arizona Cardinals-2003       8.5   NaN
#                       2004 Arizona Cardinals-2004       1.0   NaN
# ...                                                     ...   ...
# Washington Commanders 2018 Washington Commanders-2018 -18.0   NaN
#                       2019 Washington Commanders-2019 -18.5   NaN
#                       2020 Washington Commanders-2020  -0.5   NaN
#                       2021 Washington Commanders-2021   0.5   9.0
#                       2022 Washington Commanders-2022 -16.0  27.5
#
# [734 rows x 18 columns]

# %%
dfspread = pd.concat([dfnflspread_zip[[0,1,4,5]],dfnflspread_zip[[2,3,4,5]].rename(columns={2:0,3:1})]).rename(columns={0:'Team',1:'Spread',4:'Week',5:'Year'}).set_index(['Team','Year','Week']).unstack()
dfspread.columns = dfspread.columns.droplevel()
# dfspread.columns = ['Week_'+str(i) for i in dfspread.columns]
dfspread['teamyearid'] = dfspread.index.map(lambda x: '-'.join(map(str, x)))
dfspread['Bet'] = 'SpreadScore'
dfspread.set_index(['teamyearid','Bet'],inplace=True,append=True)

dfspreadts = dfspread.T
# dfspread.to_csv('data/dfspread.csv')
dfspread

dfprespread = pd.concat([dfnflspread_zip[[0,6,4,5]],dfnflspread_zip[[2,7,4,5]].rename(columns={2:0,7:6})]).rename(columns={0:'Team',1:'Spread',4:'Week',5:'Year'}).set_index(['Team','Year','Week']).unstack()
dfprespread.columns = dfprespread.columns.droplevel()
# dfspread.columns = ['Week_'+str(i) for i in dfspread.columns]
dfprespread['teamyearid'] = dfprespread.index.map(lambda x: '-'.join(map(str, x)))
dfprespread['Bet'] = 'Spread'
dfprespread.set_index(['teamyearid','Bet'],inplace=True,append=True)

dfoverunder = pd.concat([dfnflspread_zip[[0,8,4,5]],dfnflspread_zip[[2,8,4,5]].rename(columns={2:0})]).rename(columns={0:'Team',1:'OverUnder',4:'Week',5:'Year'}).set_index(['Team','Year','Week']).unstack()
dfoverunder.columns = dfoverunder.columns.droplevel()
# dfspread.columns = ['Week_'+str(i) for i in dfspread.columns]
dfoverunder['teamyearid'] = dfoverunder.index.map(lambda x: '-'.join(map(str, x)))
dfoverunder['Bet'] = 'OverUnder'
dfoverunder.set_index(['teamyearid','Bet'],inplace=True,append=True)

# dfspreadts = dfspread.T
# dfprespread.to_csv('data/dfprespread.csv')
dfbets = pd.concat([dfspread, dfoverunder,dfprespread],axis=0)
dfbets.to_csv('data/dfbets.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from xgboost import XGBRegressor,XGBClassifier
from sklearn.model_selection import train_test_split
# from gluonts.dataset.common import ListDataset
# from gluonts.torch.model.deepar.estimator import DeepAREstimator
# from gluonts.mx.trainer import Trainer
# from gluonts.mx.evaluation import Evaluator
# from gluonts.mx.evaluation.backtest import make_evaluation_predictions

# %%
dfmodel = dfspread.loc[pd.IndexSlice[2022] != dfspread.index.get_level_values('Year')]
dfval = dfspread.loc[pd.IndexSlice[2022] == dfspread.index.get_level_values('Year')]
dfmodel
# Out:
# Week                                                      1     2     3     4  \
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000       1.5  -2.0   NaN -27.0
#                       2001 Arizona Cardinals-2001       NaN -12.5 -17.0  15.5
#                       2002 Arizona Cardinals-2002      -2.0  15.0  -5.5  17.0
#                       2003 Arizona Cardinals-2003     -14.5 -33.0  14.5 -12.5
#                       2004 Arizona Cardinals-2004       4.0  -3.0   8.0  27.5
# ...                                                     ...   ...   ...   ...
# Washington Commanders 2017 Washington Commanders-2017 -12.0   9.5  20.0  -2.0
#                       2018 Washington Commanders-2018  20.0 -18.0  16.5   NaN
#                       2019 Washington Commanders-2019   5.0  -4.0 -11.0 -18.0
#                       2020 Washington Commanders-2020  15.0  -8.0  -7.0   0.0
#                       2021 Washington Commanders-2021  -3.0  -2.0 -15.0   2.0
#
# Week                                                      5     6     7     8  \
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000      -3.5   3.5 -16.5 -34.0
#                       2001 Arizona Cardinals-2001      -0.0  10.0 -17.0  -7.0
#                       2002 Arizona Cardinals-2002       8.0   NaN  -0.5  -1.5
#                       2003 Arizona Cardinals-2003      -9.5  -1.5   NaN  10.0
#                       2004 Arizona Cardinals-2004      -2.0   NaN  14.5 -19.5
# ...                                                     ...   ...   ...   ...
# Washington Commanders 2017 Washington Commanders-2017   NaN -10.0  -5.5 -12.0
#                       2018 Washington Commanders-2018 -18.5   7.0   4.0   6.0
#                       2019 Washington Commanders-2019  -9.5  -4.5   1.0   6.5
#                       2020 Washington Commanders-2020 -13.0   1.5  21.0   NaN
#                       2021 Washington Commanders-2021  -8.5 -11.5  -5.5  -3.0
#
# Week                                                      9    10    11    12  \
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000      -5.0  11.0  -4.5 -18.0
#                       2001 Arizona Cardinals-2001      -1.5   5.0  10.0  16.0
#                       2002 Arizona Cardinals-2002      -8.0 -24.0 -12.0 -11.5
#                       2003 Arizona Cardinals-2003       6.0  -6.0 -33.0   4.0
#                       2004 Arizona Cardinals-2004       4.0   2.0 -22.0  -7.0
# ...                                                     ...   ...   ...   ...
# Washington Commanders 2017 Washington Commanders-2017  11.0  -7.0   4.5   2.5
#                       2018 Washington Commanders-2018 -25.5  16.5   1.0  -1.0
#                       2019 Washington Commanders-2019  -4.5   NaN -19.0   7.0
#                       2020 Washington Commanders-2020  -5.5  -0.0   9.5  28.0
#                       2021 Washington Commanders-2021   NaN  20.0   9.0   3.5
#
# Week                                                     13    14    15    16  \
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000     -18.0  -7.0 -49.0   9.0
#                       2001 Arizona Cardinals-2001     -12.0   1.0   3.5  24.0
#                       2002 Arizona Cardinals-2002     -40.0   4.0   9.0   0.5
#                       2003 Arizona Cardinals-2003     -20.5 -25.5   4.0  -2.5
#                       2004 Arizona Cardinals-2004      -8.0 -10.0  27.0   4.0
# ...                                                     ...   ...   ...   ...
# Washington Commanders 2017 Washington Commanders-2017 -26.0 -11.0   1.0  13.0
#                       2018 Washington Commanders-2018  -9.5 -21.0  -4.5   2.5
#                       2019 Washington Commanders-2019  18.5   8.0  -3.5  -5.0
#                       2020 Washington Commanders-2020  12.0  11.0   1.0  -6.0
#                       2021 Washington Commanders-2021   3.5  -0.5  -0.0 -32.0
#
# Week                                                     17   18
# Team                  Year teamyearid
# Arizona Cardinals     2000 Arizona Cardinals-2000     -10.0  NaN
#                       2001 Arizona Cardinals-2001       0.5  NaN
#                       2002 Arizona Cardinals-2002     -16.5  NaN
#                       2003 Arizona Cardinals-2003       8.5  NaN
#                       2004 Arizona Cardinals-2004       1.0  NaN
# ...                                                     ...  ...
# Washington Commanders 2017 Washington Commanders-2017 -12.5  NaN
#                       2018 Washington Commanders-2018 -18.0  NaN
#                       2019 Washington Commanders-2019 -18.5  NaN
#                       2020 Washington Commanders-2020  -0.5  NaN
#                       2021 Washington Commanders-2021   0.5  9.0
#
# [702 rows x 18 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
model = XGBRegressor(enable_categorical=True,tree_method="hist")
def genFrames(df,startweek,nweeks):
    ytemp = df[startweek+nweeks]
    ytemp = ytemp[ytemp!=0].dropna()
    Xtemp = df[[i for i in range(startweek,startweek+nweeks)]].loc[ytemp.index]
    Xtemp['Week'] = ytemp.name
    Xtemp = Xtemp.droplevel(2).reset_index().set_index(['Team','Year','Week']).rename_axis(None,axis=1)
    # Xtemp['Team'] = Xtemp['Team'].astype('category')
    # Xtemp['Year'] = Xtemp['Year'].astype('category')
    return Xtemp,ytemp#,year,week

# startweek = 1
for nweeks in range(1,8):
    # nweeks = 5
    plt.subplots()
    # X,y = genFrames(1,5)

    Xlist = [genFrames(dfspread,startweek,nweeks)[0].reset_index() for startweek in range(1,18-nweeks)]
    ylist = [genFrames(dfspread,startweek,nweeks)[1] for startweek in range(1,18-nweeks)]
    X = pd.DataFrame(np.concatenate(Xlist, axis=0))
    X.columns = ['Team','Year','Week']+list(range(1,nweeks+1))
    for col in X.columns:
        if col in ['Team','Year','Week']:
            X[col] = X[col].astype('category')
        else:
            X[col] = pd.to_numeric(X[col])
    y = pd.Series(np.concatenate(ylist, axis=0))
    import random
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=random.randint(1,100))
    model.fit(X_train,y_train)
    y_pred = pd.Series(model.predict(X_test),index=y_test.index)
    # print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))

    dfpred = pd.DataFrame({'y_pred':y_pred,'y_test':y_test})
    dfpred['Win'] = np.sign(dfpred['y_pred'].round())==np.sign(dfpred['y_test'])
    dfpred['y_pred_round'] = dfpred['y_pred'].round()
    # dfpred.mean()

    dfpred[dfpred['y_pred'].abs()>1].sort_values('y_pred',ascending=False).set_index('y_pred')['Win'].expanding().mean().plot()
    dfpred[dfpred['y_pred'].abs()>1].sort_values('y_pred',ascending=True).set_index('y_pred')['Win'].expanding().mean().plot()
    dfpred.groupby('y_pred_round')['Win'].mean().rolling(1).mean().plot()
    plt.plot([-20,20],[.53,.53])
    plt.title(f'Past weeks in prediction = {nweeks}')

# %% [markdown]
# ###  create model with this history
# ### for early weeks use how ever many weeks of history are available

# %%
thisweek = 4
nweeks = 3

Xlist = [genFrames(dfspread,startweek,nweeks)[0].reset_index() for startweek in range(1,thisweek+1-nweeks)]
ylist = [genFrames(dfspread,startweek,nweeks)[1] for startweek in range(1,thisweek+1-nweeks)]
X = pd.DataFrame(np.concatenate(Xlist, axis=0))
X.columns = ['Team','Year','Week']+list(range(1,nweeks+1))
for col in X.columns:
    if col in ['Team','Year','Week']:
        X[col] = X[col].astype('category')
    else:
        X[col] = pd.to_numeric(X[col])
y = pd.Series(np.concatenate(ylist, axis=0))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,
                                                    random_state=random.randint(1,100)
                                                    # random_state=42
                                                    )

Xlist = [genFrames(dfval,startweek,nweeks)[0].reset_index() for startweek in range(1,3-nweeks)]
ylist = [genFrames(dfval,startweek,nweeks)[1] for startweek in range(1,3-nweeks)]
X_val = pd.DataFrame(np.concatenate(Xlist, axis=0))
X_val.columns = ['Team','Year','Week']+list(range(1,nweeks+1))
for col in X_val.columns:
    if col in ['Team','Year','Week']:
        X_val[col] = X_val[col].astype('category')
    else:
        X_val[col] = pd.to_numeric(X_val[col])
y_val = pd.Series(np.concatenate(ylist, axis=0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[162], line 21
#      19 Xlist = [genFrames(dfval,startweek,nweeks)[0].reset_index() for startweek in range(1,3-nweeks)]
#      20 ylist = [genFrames(dfval,startweek,nweeks)[1] for startweek in range(1,3-nweeks)]
# ---> 21 X_val = pd.DataFrame(np.concatenate(Xlist, axis=0))
#      22 X_val.columns = ['Team','Year','Week']+list(range(1,nweeks+1))
#      23 for col in X_val.columns:
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %%
Xlist = [genFrames(dfspread,startweek,nweeks)[0].reset_index() for startweek in range(1,thisweek+1-nweeks)]
ylist = [genFrames(dfspread,startweek,nweeks)[1] for startweek in range(1,thisweek+1-nweeks)]
X = pd.DataFrame(np.concatenate(Xlist, axis=0))
X.columns = ['Team','Year','Week']+list(range(1,nweeks+1))
for col in X.columns:
    if col in ['Team','Year','Week']:
        X[col] = X[col].astype('category')
    else:
        X[col] = pd.to_numeric(X[col])
y = pd.Series(np.concatenate(ylist, axis=0))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,
                                                    random_state=random.randint(1,100)
                                                    # random_state=42
                                                    )

Xlist = [genFrames(dfval,startweek,nweeks)[0].reset_index() for startweek in range(1,3-nweeks)]
ylist = [genFrames(dfval,startweek,nweeks)[1] for startweek in range(1,3-nweeks)]
X_val = pd.DataFrame(np.concatenate(Xlist, axis=0))
X_val.columns = ['Team','Year','Week']+list(range(1,nweeks+1))
for col in X_val.columns:
    if col in ['Team','Year','Week']:
        X_val[col] = X_val[col].astype('category')
    else:
        X_val[col] = pd.to_numeric(X_val[col])
y_val = pd.Series(np.concatenate(ylist, axis=0))


from hyperopt import fmin, tpe, hp
def objective(params):

    # selected_features = [i for i, use_feature in enumerate(params['features']) if use_feature]

    # if not any(params['features']):  # Ensure at least one feature is selected
    #     return 1.0  # Penalize if no features are selected

    params = {
        'learning_rate': params['learning_rate'],
        'max_depth': int(params['max_depth']),
        'n_estimators': int(params['n_estimators']),
        'reg_lambda': params['reg_lambda'],
        'reg_alpha': params['reg_alpha'],
        'min_child_weight': params['min_child_weight'],

        # 'scale_pos_weight': params['scale_pos_weight'],
        # Add more hyperparameters
    }

    cvscore = cross_val_score(model, X_train, y_train, cv=5)
    return 1-cvscore.mean()  # Hyperopt minimizes the objective, so we use negative accuracy

# Define the search space for hyperparameters
space = {
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.3),
    'max_depth': hp.quniform('max_depth', 2, 5, 1),
    'n_estimators': hp.quniform('n_estimators', 50, 200, 10),
    'reg_lambda': hp.uniform('reg_lambda', 1, 5),
    'reg_alpha': hp.uniform('reg_alpha', 1, 5),
    'min_child_weight': hp.uniform('min_child_weight', 1, 5),
    # 'scale_pos_weight': hp.quniform('scale_pos_weight', 1, 10, 3),
    # 'features': [hp.choice(f'feature_{i}', [True, False]) for i in range(X[modelcolsall].shape[1])]

    # Add more hyperparameters to optimize
}

# Run hyperparameter optimization
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=20)
print("Best hyperparameters:", best)

def round_whole_numbers(d, decimal_places=2):
    rounded_dict = {}

    for key, value in d.items():
        if isinstance(value, (int, float)) and value.is_integer():
            rounded_value = int(value)
        else:
            rounded_value = value
        rounded_dict[key] = rounded_value

    return rounded_dict

bestparams = round_whole_numbers(best)

reg = XGBRegressor(**bestparams,enable_categorical=True,tree_method="hist")
# model = XGBRegressor()
reg.fit(X_train,y_train)
# Out:
# 100%|██████████| 20/20 [00:14<00:00,  1.40trial/s, best loss: 1.344581122705188]
# Best hyperparameters: {'learning_rate': 0.2162905101037037, 'max_depth': 4.0, 'min_child_weight': 1.6171497486171411, 'n_estimators': 170.0, 'reg_alpha': 4.572626584598982, 'reg_lambda': 2.406904471765233}

# %%
from sklearn.metrics import accuracy_score,f1_score,make_scorer
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor,XGBClassifier

reg = XGBRegressor(enable_categorical=True,tree_method="hist")
# model = XGBRegressor()
# reg.fit(pd.concat([X_train,y_train+.5],axis=1),y_train)
cross_val_score(reg, pd.concat([X_train,y_train+.5],axis=1), y_train, cv=5)

# y_pred = pd.Series(reg.predict(X_test),index=y_test.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[152], line 8
#       5 reg = XGBRegressor(enable_categorical=True,tree_method="hist")
#       6 # model = XGBRegressor()
#       7 # reg.fit(pd.concat([X_train,y_train+.5],axis=1),y_train)
# ----> 8 cross_val_score(reg, pd.concat([X_train,y_train+.5],axis=1), y_train, cv=5)
#
# NameError: name 'X_train' is not defined

# %%
reg = XGBRegressor(**bestparams,enable_categorical=True,tree_method="hist")
# model = XGBRegressor()
reg.fit(X_train,y_train)
y_pred = pd.Series(reg.predict(X_test),index=y_test.index)
# print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))

dfpred = pd.DataFrame({'y_pred':y_pred,'y_test':y_test})
dfpred['Win'] = np.sign(dfpred['y_pred'].round(1))==np.sign(dfpred['y_test'])
dfpred['y_pred_round'] = dfpred['y_pred'].round()
# dfpred.mean()

thresh = .5
plt.subplots(figsize=(10,5))
plt.subplot(1,2,1)
dfpred[dfpred['y_pred'].abs()>thresh].sort_values('y_pred',ascending=False).set_index('y_pred')['Win'].expanding().mean().plot()
dfpred[dfpred['y_pred'].abs()>thresh].sort_values('y_pred',ascending=True).set_index('y_pred')['Win'].expanding().mean().plot()
dfpred.groupby('y_pred_round')['Win'].mean().rolling(1).mean().plot()
plt.plot([dfpred['y_pred'].min(),dfpred['y_pred'].max()],[.53,.53])
plt.title(f'Past weeks in prediction = {nweeks}, test set')

y_pred = pd.Series(reg.predict(X_val),index=y_val.index)
# print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))

dfpred = pd.DataFrame({'y_pred':y_pred,'y_test':y_val})
dfpred['Win'] = np.sign(dfpred['y_pred'].round())==np.sign(dfpred['y_test'])
dfpred['y_pred_round'] = dfpred['y_pred'].round()
# dfpred.mean()

plt.subplot(1,2,2)
dfpred[dfpred['y_pred'].abs()>thresh].sort_values('y_pred',ascending=False).set_index('y_pred')['Win'].expanding().mean().plot()
dfpred[dfpred['y_pred'].abs()>thresh].sort_values('y_pred',ascending=True).set_index('y_pred')['Win'].expanding().mean().plot()
dfpred.groupby('y_pred_round')['Win'].mean().rolling(1).mean().plot()
plt.plot([dfpred['y_pred'].min(),dfpred['y_pred'].max()],[.53,.53])
plt.title(f'Past weeks in prediction = {nweeks}, 2022 season')

dfpredreg = dfpred.copy()
# Out:
# 100%|██████████| 20/20 [00:18<00:00,  1.10trial/s, best loss: 1.0768007767627936]
# Best hyperparameters: {'learning_rate': 0.029764007232276728, 'max_depth': 4.0, 'min_child_weight': 3.6416610825234264, 'n_estimators': 50.0, 'reg_alpha': 1.7119289429224671, 'reg_lambda': 3.2839093207096157}
# C:\Users\hogan\AppData\Local\Temp\ipykernel_33964\3109911735.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %%
from sklearn.metrics import accuracy_score,f1_score,make_scorer
from sklearn.model_selection import cross_val_score
from hyperopt import fmin, tpe, hp
def objective(params):

    # selected_features = [i for i, use_feature in enumerate(params['features']) if use_feature]

    # if not any(params['features']):  # Ensure at least one feature is selected
    #     return 1.0  # Penalize if no features are selected

    params = {
        'learning_rate': params['learning_rate'],
        'max_depth': int(params['max_depth']),
        'n_estimators': int(params['n_estimators']),
        'reg_lambda': params['reg_lambda'],
        'reg_alpha': params['reg_alpha'],
        'min_child_weight': params['min_child_weight'],

        # 'scale_pos_weight': params['scale_pos_weight'],
        # Add more hyperparameters
    }

    model = XGBClassifier(**params,objective="multi:softmax",num_class=2,enable_categorical=True,tree_method="hist")
    # model.fit(X_train, y_train)
    # y_pred = model.predict(X_test)
    # accuracy = accuracy_score(y_test, y_pred)
    # f1 = f1_score(y_test, y_pred,pos_label=1)
    from sklearn.preprocessing import LabelEncoder
    y_encoded = LabelEncoder().fit_transform(np.sign(y_train))
    score = cross_val_score(model, X_train, y_encoded, cv=5)
    return 1-score.mean()  # Hyperopt minimizes the objective, so we use negative accuracy

# Define the search space for hyperparameters
space = {
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.3),
    'max_depth': hp.quniform('max_depth', 2, 5, 1),
    'n_estimators': hp.quniform('n_estimators', 50, 200, 10),
    'reg_lambda': hp.uniform('reg_lambda', 1, 5),
    'reg_alpha': hp.uniform('reg_alpha', 1, 5),
    'min_child_weight': hp.uniform('min_child_weight', 1, 5),
    # 'scale_pos_weight': hp.quniform('scale_pos_weight', 1, 10, 3),
    # 'features': [hp.choice(f'feature_{i}', [True, False]) for i in range(X[modelcolsall].shape[1])]

    # Add more hyperparameters to optimize
}

# Run hyperparameter optimization
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=20)

print("Best hyperparameters:", best)
def round_whole_numbers(d, decimal_places=2):
    rounded_dict = {}

    for key, value in d.items():
        if isinstance(value, (int, float)) and value.is_integer():
            rounded_value = int(value)
        else:
            rounded_value = value
        rounded_dict[key] = rounded_value

    return rounded_dict

bestparams = round_whole_numbers(best)
# Out:
# 100%|██████████| 20/20 [00:16<00:00,  1.20trial/s, best loss: 0.4808510638297874]
# Best hyperparameters: {'learning_rate': 0.28070444018724117, 'max_depth': 4.0, 'min_child_weight': 2.987062715521712, 'n_estimators': 70.0, 'reg_alpha': 4.543211286411378, 'reg_lambda': 4.007061662937264}

# %%
clas = XGBClassifier(**bestparams,objective="multi:softmax",num_class=2,enable_categorical=True,tree_method="hist")
from sklearn.preprocessing import LabelEncoder
y_encoded = LabelEncoder().fit_transform(np.sign(y_train))
clas.fit(X_train,y_encoded)
y_pred = pd.DataFrame(clas.predict_proba(X_test),index=y_test.index)[0]
# print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))

dfpred = pd.DataFrame({'y_pred':y_pred-.5,'y_test':np.sign(y_test)})
dfpred['Win'] = np.sign(dfpred['y_pred'])==dfpred['y_test']
dfpred['y_pred_round'] = dfpred['y_pred'].round()
# dfpred.mean()

thresh = 0
plt.subplots(figsize=(10,5))
plt.subplot(1,2,1)
dfpred[dfpred['y_pred'].abs()>thresh].sort_values('y_pred',ascending=False).set_index('y_pred')['Win'].expanding().mean().plot()
dfpred[dfpred['y_pred'].abs()>thresh].sort_values('y_pred',ascending=True).set_index('y_pred')['Win'].expanding().mean().plot()
dfpred.groupby('y_pred_round')['Win'].mean().rolling(1).mean().plot()
plt.plot([dfpred['y_pred'].min(),dfpred['y_pred'].max()],[.53,.53])
plt.title(f'Past weeks in prediction = {nweeks}')

y_pred = pd.DataFrame(clas.predict_proba(X_val),index=y_val.index)[0]
# print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))

dfpred = pd.DataFrame({'y_pred':y_pred-.5,'y_test':np.sign(y_val)})
dfpred['Win'] = np.sign(dfpred['y_pred'])==dfpred['y_test']
dfpred['y_pred_round'] = dfpred['y_pred'].round()
# dfpred.mean()

plt.subplot(1,2,2)
dfpred[dfpred['y_pred'].abs()>thresh].sort_values('y_pred',ascending=False).set_index('y_pred')['Win'].expanding().mean().plot()
dfpred[dfpred['y_pred'].abs()>thresh].sort_values('y_pred',ascending=True).set_index('y_pred')['Win'].expanding().mean().plot()
dfpred.groupby('y_pred_round')['Win'].mean().rolling(1).mean().plot()
plt.plot([dfpred['y_pred'].min(),dfpred['y_pred'].max()],[.53,.53])
plt.title(f'Past weeks in prediction = {nweeks}')

dfpredclas = dfpred.copy()
# Out:
# C:\Users\hogan\AppData\Local\Temp\ipykernel_33964\839821257.py:15: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %%
dfpredreg.columns = ['y_pred_reg','y_test_reg','Win_reg','y_pred_round_reg']
dfpredclas.columns = ['y_pred_clas','y_test_clas','Win_clas','y_pred_round_clas']
dfboth = pd.concat([dfpredreg,dfpredclas],axis=1)

dfboth[(-dfboth['y_pred_reg'].between(dfboth['y_pred_reg'].quantile(.2),dfboth['y_pred_reg'].quantile(.8)))&(-dfboth['y_pred_clas'].between(dfboth['y_pred_clas'].quantile(.2),dfboth['y_pred_clas'].quantile(.8)))]
# Out:
#     y_pred_reg  y_test_reg  Win_reg  y_pred_round_reg  y_pred_clas  \
# 3     3.806942        24.0     True               4.0    -0.041733
# 9     5.862731        -3.0    False               6.0     0.110016
# 18   -5.954015        -6.0     True              -6.0     0.107692
# 19   -5.698251         7.5    False              -6.0    -0.018671
#
#     y_test_clas  Win_clas  y_pred_round_clas
# 3           1.0     False               -0.0
# 9          -1.0     False                0.0
# 18         -1.0     False                0.0
# 19          1.0     False               -0.0

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## import past spreads

# %%
dfseasonspreads = pd.read_csv('data/Season_spreads.csv',index_col=0)
dfseasonspreads
# Out:
#                                     opponent  spread  score  diff  Week  Year  \
# Arizona Cardinals      Washington Commanders     7.0   16.0  -4.0     1  2023
# Atlanta Falcons            Carolina Panthers    -3.5   24.0  14.0     1  2023
# Baltimore Ravens              Houston Texans    -9.5   25.0  16.0     1  2023
# Buffalo Bills                  New York Jets    -2.5   16.0  -6.0     1  2023
# Carolina Panthers            Atlanta Falcons     3.5   10.0 -14.0     1  2023
# ...                                      ...     ...    ...   ...   ...   ...
# San Francisco 49ers                      NaN     NaN    NaN   NaN     2  2023
# Seattle Seahawks                         NaN     NaN    NaN   NaN     2  2023
# Tampa Bay Buccaneers                     NaN     NaN    NaN   NaN     2  2023
# Tennessee Titans                         NaN     NaN    NaN   NaN     2  2023
# Washington Commanders                    NaN     NaN    NaN   NaN     2  2023
#
#                        spreadscore  coverprob  predspread
# Arizona Cardinals              3.0        NaN         NaN
# Atlanta Falcons               10.5        NaN         NaN
# Baltimore Ravens               6.5        NaN         NaN
# Buffalo Bills                 -8.5        NaN         NaN
# Carolina Panthers            -10.5        NaN         NaN
# ...                            ...        ...         ...
# San Francisco 49ers            NaN   0.471402   -4.576632
# Seattle Seahawks               NaN   0.564059    2.564864
# Tampa Bay Buccaneers           NaN   0.490795    7.881182
# Tennessee Titans               NaN   0.545528   -6.536362
# Washington Commanders          NaN   0.587712   -4.141398
#
# [64 rows x 9 columns]

# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://non-profit:retire@cluster0.ml8jvfc.mongodb.net/?retryWrites=true&w=majority&appName=AtlasApp"
# Create a new client and connect to the server
client = MongoClient(uri)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
mongo_db = 'withTheSpread'  # Replace with your desired database name
mongo_collection = 'bets'  # Replace with your desired collection name
cursor = client[mongo_db][mongo_collection].find({})
data = list(cursor)
dfbets = pd.DataFrame(data)
dfbets

mongo_db = 'withTheSpread'  # Replace with your desired database name
mongo_collection = 'season_spreads'  # Replace with your desired collection name
cursor = client[mongo_db][mongo_collection].find({})
data = list(cursor)
dfseasonspreads = pd.DataFrame(data).set_index(['Team'],drop=True).drop(['_id'],axis=1)
dfseasonspreads
# Out:
#                        Week              opponent  spread  score  diff  Year  \
# Team
# Cincinnati Bengals        3      Los Angeles Rams    -1.5   19.0   3.0  2023
# Carolina Panthers         2    New Orleans Saints     3.0   17.0  -3.0  2023
# Chicago Bears             2  Tampa Bay Buccaneers     2.5   17.0 -10.0  2023
# Kansas City Chiefs        3         Chicago Bears   -12.5   41.0  31.0  2023
# Tennessee Titans          2  Los Angeles Chargers     2.5   27.0   3.0  2023
# ...                     ...                   ...     ...    ...   ...   ...
# San Francisco 49ers       5        Dallas Cowboys    -3.5    NaN   NaN  2023
# Seattle Seahawks          5                   NaN     NaN    NaN   NaN  2023
# Tampa Bay Buccaneers      5                   NaN     NaN    NaN   NaN  2023
# Tennessee Titans          5    Indianapolis Colts    -2.5    NaN   NaN  2023
# Washington Commanders     5         Chicago Bears    -6.0    NaN   NaN  2023
#
#                        spreadscore  coverprob  predspread  order  \
# Team
# Cincinnati Bengals             1.5   0.507081   -1.633186   15.0
# Carolina Panthers              0.0   0.468306    0.263147    NaN
# Chicago Bears                 -7.5   0.405467   -7.578706    NaN
# Kansas City Chiefs            18.5   0.440254    8.711520   12.0
# Tennessee Titans               5.5   0.454472   -6.536362    NaN
# ...                            ...        ...         ...    ...
# San Francisco 49ers            NaN   0.420517    3.349460   12.0
# Seattle Seahawks               NaN   0.396312   -4.675699    NaN
# Tampa Bay Buccaneers           NaN   0.472254    0.025706    NaN
# Tennessee Titans               NaN   0.546127    2.602900    5.0
# Washington Commanders          NaN   0.602020    2.436749    0.0
#
#                        coverprob_diff  predspread_diff
# Team
# Cincinnati Bengals          -0.015729        -0.114765
# Carolina Panthers            0.066440              NaN
# Chicago Bears               -0.103738              NaN
# Kansas City Chiefs          -0.066827        15.995833
# Tennessee Titans             0.115370              NaN
# ...                               ...              ...
# San Francisco 49ers         -0.123986         4.762201
# Seattle Seahawks                  NaN              NaN
# Tampa Bay Buccaneers              NaN              NaN
# Tennessee Titans             0.030632        -0.509364
# Washington Commanders        0.139653        -0.675514
#
# [160 rows x 12 columns]

# %%
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
mongo_db = 'withTheSpread'  # Replace with your desired database name
mongo_collection = 'season_spreads'  # Replace with your desired collection name
from api_calls import get_db,mongoConn
client = mongoConn()
dfseasonspreads = get_db(client,mongo_db,mongo_collection)
dfseasonspreads = dfseasonspreads.set_index(['Team'],drop=True).drop(['_id'],axis=1)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
data
# Out:
# b'{"get":"games","parameters":{"league":"1","season":"2023"},"errors":[],"results":332,"response":[{"game":{"id":7804,"stage":"Pre Season","week":"Hall of Fame Weekend","date":{"timezone":"UTC","date":"2023-08-04","time":"00:00","timestamp":1691107200},"venue":{"name":"Tom Benson Hall of Fame Stadium","city":"Canton"},"status":{"short":"FT","long":"Finished","timer":null}},"league":{"id":1,"name":"NFL","season":"2023","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/leagues\\/1.png","country":{"name":"USA","code":"US","flag":"https:\\/\\/media-4.api-sports.io\\/flags\\/us.svg"}},"teams":{"home":{"id":9,"name":"Cleveland Browns","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/9.png"},"away":{"id":13,"name":"New York Jets","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/13.png"}},"scores":{"home":{"quarter_1":0,"quarter_2":7,"quarter_3":7,"quarter_4":7,"overtime":null,"total":21},"away":{"quarter_1":6,"quarter_2":10,"quarter_3":0,"quarter_4":0,"overtime":null,"total":16}}},{"game":{"id":7805,"stage":"Pre Season","week":"Week 1","date":{"timezone":"UTC","date":"2023-08-10","time":"23:00","timestamp":1691708400},"venue":{"name":"Gillette Stadium","city":"Foxborough"},"status":{"short":"FT","long":"Finished","timer":null}},"league":{"id":1,"name":"NFL","season":"2023","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/leagues\\/1.png","country":{"name":"USA","code":"US","flag":"https:\\/\\/media-4.api-sports.io\\/flags\\/us.svg"}},"teams":{"home":{"id":3,"name":"New England Patriots","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/3.png"},"away":{"id":26,"name":"Houston Texans","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/26.png"}},"scores":{"home":{"quarter_1":3,"quarter_2":0,"quarter_3":0,"quarter_4":6,"overtime":null,"total":9},"away":{"quarter_1":0,"quarter_2":7,"quarter_3":6,"quarter_4":7,"overtime":null,"total":20}}},{"game":{"id":7806,"stage":"Pre Season","week":"Week 1","date":{"timezone":"UTC","date":"2023-08-11","time":"02:00","timestamp":1691719200},"venue":{"name":"Lumen Field","city":"Seattle"},"status":{"short":"FT","long":"Finished","timer":null}},"league":{"id":1,"name":"NFL","season":"2023","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/leagues\\/1.png","country":{"name":"USA","code":"US","flag":"https:\\/\\/media-4.api-sports.io\\/flags\\/us.svg"}},"teams":{"home":{"id":23,"name":"Seattle Seahawks","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/23.png"},"away":{"id":32,"name":"Minnesota Vikings","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/32.png"}},"scores":{"home":{"quarter_1":0,"quarter_2":7,"quarter_3":10,"quarter_4":7,"overtime":null,"total":24},"away":{"quarter_1":3,"quarter_2":7,"quarter_3":3,"quarter_4":0,"overtime":null,"total":13}}},{"game":{"id":7807,"stage":"Pre Season","week":"Week 1","date":{"timezone":"UTC","date":"2023-08-11","time":"23:00","timestamp":1691794800},"venue":{"name":"Paycor Stadium","city":"Cincinnati"},"status":{"short":"FT","long":"Finished","timer":null}},"league":{"id":1,"name":"NFL","season":"2023","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/leagues\\/1.png","country":{"name":"USA","code":"US","flag":"https:\\/\\/media-4.api-sports.io\\/flags\\/us.svg"}},"teams":{"home":{"id":10,"name":"Cincinnati Bengals","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/10.png"},"away":{"id":15,"name":"Green Bay Packers","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/15.png"}},"scores":{"home":{"quarter_1":3,"quarter_2":13,"quarter_3":3,"quarter_4":0,"overtime":null,"total":19},"away":{"quarter_1":7,"quarter_2":14,"quarter_3":9,"quarter_4":6,"overtime":null,"total":36}}},{"game":{"id":7808,"stage":"Pre Season","week":"Week 1","date":{"timezone":"UTC","date":"2023-08-11","time":"23:00","timestamp":1691794800},"venue":{"name":"Ford Field" ...

# %%
from api_calls import getLastWeeksResults, extractLastWeeksResults
import json

# data = getLastWeeksResults()
games = [game for game in json.loads(data.decode("utf-8"))['response'] if
         game['game']['stage'] == 'Regular Season' and game['game']['status']['short'] != 'NS']
weeks = sorted(list(set([game['game']['week'] for game in games])))
weeks_num = sorted([int(week.split(' ')[1]) for week in weeks])
lastweekstr = 'week' + str(max(weeks_num))
nextweekstr = 'week' + str(max(weeks_num) + 1)
print(lastweekstr, nextweekstr)
print(weeks_num)
gamescores = {}
gamescorediffs = {}
opponent = {}
allweeks = []
for week in weeks_num[:-1]:
    print(week)
    for game in games:
        if game['game']['week'] == weeks[week-1]:
            gamescores[game['teams']['home']['name']] = game['scores']['home']['total']
            gamescores[game['teams']['away']['name']] = game['scores']['away']['total']
            gamescorediffs[game['teams']['home']['name']] = game['scores']['home']['total'] - game['scores']['away']['total']
            gamescorediffs[game['teams']['away']['name']] = game['scores']['away']['total'] - game['scores']['home']['total']
            # opponent[game['teams']['home']['name']] = game['teams']['away']['name']
            # opponent[game['teams']['away']['name']] = game['teams']['home']['name']

    dfgameresults = pd.concat([
        pd.Series(gamescores, name='score'),
        pd.Series(gamescorediffs, name='diff')
    ], axis=1)
    dfgameresults
    dfgameresults['Week'] = week
    display(dfgameresults.loc['Arizona Cardinals'])
    allweeks.append(dfgameresults)
dfgameresultsall = pd.concat(allweeks)
# Out:
# week4 week5
# [1, 2, 3, 4]
# 1
# score    16
# diff     -4
# Week      1
# Name: Arizona Cardinals, dtype: int64
# 2
# score    28
# diff     -3
# Week      2
# Name: Arizona Cardinals, dtype: int64
# 3
# score    28
# diff     12
# Week      3
# Name: Arizona Cardinals, dtype: int64

# %%
mongo_db = 'withTheSpread'  # Replace with your desired database name
mongo_collection = 'season_spreads'  # Replace with your desired collection name
from api_calls import get_db,mongoConn
client = mongoConn()
dfseasonspreads = get_db(client,mongo_db,mongo_collection)
dfseasonspreads = dfseasonspreads.set_index(['Team'],drop=True).drop(['_id'],axis=1)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
dfplot = dfseasonspreads.copy()
def checkcover(x,metric):
    if 'pred' in metric:
        result = np.nan if (pd.isna(x[[metric,'spreadscore']]).any() or np.sign(x['spreadscore'])==0) else np.sign(x['spreadscore'])==np.sign(x[metric])
    elif 'cover' in metric:
        result = np.nan if (pd.isna(x[[metric,'spreadscore']]).any() or np.sign(x['spreadscore'])==0) else np.sign(x['spreadscore'])==np.sign(x[metric]-.5)
    else:
        return 'Not valid metric'
    return result

dfplot['predspread_diff'+'_cover'] = dfplot.apply(lambda row: checkcover(row,'predspread_diff'),axis=1).astype(bool)
dfplot
# for metric in ['predspread_diff','predspread','coverprob_diff','coverprob']:
#     dfplot[metric+'_cover'] = dfplot.apply(lambda row: checkcover(row,metric),axis=1).astype(bool)
#     dfplot.groupby('Week')[metric+'_cover'].mean().plot()
#     plt.title(metric)
#     plt.show()
# dfplot['cover'] = dfplot.apply(lambda row: checkcover(row,'predspread_diff'),axis=1).astype(bool)
# dfplot.groupby('Week')['cover'].mean().plot()
# sns.relplot(data=dfseasonspreads,x='coverprob_diff',y='spreadscore',col='Week',col_wrap=2)
# Out:
#                        Week              opponent  spread  score  diff  Year  \
# Team
# Cincinnati Bengals        3      Los Angeles Rams    -1.5   19.0   3.0  2023
# Carolina Panthers         2    New Orleans Saints     3.0   17.0  -3.0  2023
# Chicago Bears             2  Tampa Bay Buccaneers     2.5   17.0 -10.0  2023
# Kansas City Chiefs        3         Chicago Bears   -12.5   41.0  31.0  2023
# Tennessee Titans          2  Los Angeles Chargers     2.5   27.0   3.0  2023
# ...                     ...                   ...     ...    ...   ...   ...
# San Francisco 49ers       5        Dallas Cowboys    -3.5    NaN   NaN  2023
# Seattle Seahawks          5                   NaN     NaN    NaN   NaN  2023
# Tampa Bay Buccaneers      5                   NaN     NaN    NaN   NaN  2023
# Tennessee Titans          5    Indianapolis Colts    -2.5    NaN   NaN  2023
# Washington Commanders     5         Chicago Bears    -6.0    NaN   NaN  2023
#
#                        spreadscore  coverprob  predspread  order  \
# Team
# Cincinnati Bengals             1.5   0.507081   -1.633186   15.0
# Carolina Panthers              0.0   0.468306    0.263147    NaN
# Chicago Bears                 -7.5   0.405467   -7.578706    NaN
# Kansas City Chiefs            18.5   0.440254    8.711520   12.0
# Tennessee Titans               5.5   0.454472   -6.536362    NaN
# ...                            ...        ...         ...    ...
# San Francisco 49ers            NaN   0.420517    3.349460   12.0
# Seattle Seahawks               NaN   0.396312   -4.675699    NaN
# Tampa Bay Buccaneers           NaN   0.472254    0.025706    NaN
# Tennessee Titans               NaN   0.546127    2.602900    5.0
# Washington Commanders          NaN   0.602020    2.436749    0.0
#
#                        coverprob_diff  predspread_diff  predspread_diff_cover
# Team
# Cincinnati Bengals          -0.015729        -0.114765                  False
# Carolina Panthers            0.066440              NaN                   True
# Chicago Bears               -0.103738              NaN                   True
# Kansas City Chiefs          -0.066827        15.995833                   True
# Tennessee Titans             0.115370              NaN                   True
# ...                               ...              ...                    ...
# San Francisco 49ers         -0.123986         4.762201                   True
# Seattle Seahawks                  NaN              NaN                   True
# Tampa Bay Buccaneers              NaN              NaN                   True
# Tennessee Titans             0.030632        -0.509364                   True
# Washington Commanders        0.139653        -0.675514                   True
#
# [160 rows x 13 columns]

# %%
dfp = dfplot.loc['San Francisco 49ers']
dfp
# Out:
#                      Week             opponent  spread  score  diff  Year  \
# Team
# San Francisco 49ers     1  Pittsburgh Steelers    -2.0   30.0  23.0  2023
# San Francisco 49ers     4    Arizona Cardinals   -14.0    NaN   NaN  2023
# San Francisco 49ers     3      New York Giants   -10.0   30.0  18.0  2023
# San Francisco 49ers     2     Los Angeles Rams    -7.5   30.0   7.0  2023
# San Francisco 49ers     5       Dallas Cowboys    -3.5    NaN   NaN  2023
#
#                      spreadscore  coverprob  predspread  order  \
# Team
# San Francisco 49ers         21.0        NaN         NaN    NaN
# San Francisco 49ers          NaN   0.489679    1.897856   12.0
# San Francisco 49ers          8.0   0.553376   -6.308135    0.0
# San Francisco 49ers         -0.5   0.528598   -4.576632    NaN
# San Francisco 49ers          NaN   0.420517    3.349460   12.0
#
#                      coverprob_diff  predspread_diff  predspread_diff_cover
# Team
# San Francisco 49ers             NaN              NaN                   True
# San Francisco 49ers        0.062241         1.745077                   True
# San Francisco 49ers       -0.008355       -12.357222                  False
# San Francisco 49ers       -0.013134              NaN                   True
# San Francisco 49ers       -0.123986         4.762201                   True

# %%
np.sign(dfp['predspread'])==np.sign(dfp['spreadscore'])
# Out:
# Team
# San Francisco 49ers    False
# San Francisco 49ers    False
# San Francisco 49ers    False
# San Francisco 49ers     True
# San Francisco 49ers    False
# dtype: bool

# %% [markdown]
#     ### get last weeks game results through api

# %%
import pandas as pd
import pymongo

# Step 1: Load data from MongoDB into a DataFrame
# Replace "field_name" with the actual field name you want to use as the unique identifier
data = list(collection.find({}, {"_id": 0, "field_name": 1}))
df_mongo = pd.DataFrame(data)

# Step 2: Load your current DataFrame (the one you want to update from)
# Replace 'your_dataframe.csv' with the actual path to your CSV or any other data source
df_current = pd.read_csv('your_dataframe.csv')

# Step 3: Update the DataFrame with the new values
# You may need to align the data based on a common column or identifier
# For example, assuming 'field_name' is the common identifier in both DataFrames:
df_updated = df_mongo.merge(df_current, on='field_name', how='left')

# Step 4: Iterate through the DataFrame and update MongoDB documents
for index, row in df_updated.iterrows():
    filter_query = {"field_name": row["field_name"]}  # Replace "field_name" with the actual identifier
    update_query = {"$set": {"other_field": row["other_field"]}}  # Update other fields as needed
    collection.update_one(filter_query, update_query)

# Print a message indicating the update is complete
print("Update complete.")

# %%
weeks_num
# Out:
# [1, 2, 3, 4]

# %%
def update_document(client, mongo_db, mongo_collection, week, fields_to_update,df):
    """
    Update a document in a MongoDB collection.

    Parameters
    ----------
    client : pymongo.MongoClient
        A MongoClient instance connected to MongoDB.
    mongo_db : str
        Name of the MongoDB database.
    mongo_collection : str
        Name of the MongoDB collection.
    filter_query : dict
        A MongoDB filter query.
    update_query : dict
        A MongoDB update query.

    Returns
    -------
    None.
    """

    # Connect to the database and collection
    database = client[mongo_db]
    collection = database[mongo_collection]

    df_forUpdate = df[df['Week']==week]


    # Update the document
    for field in fields_to_update:
        for index, row in df_forUpdate.iterrows():
            filter_query = {"Week": row["Week"],'Team':row['Team']}  # Replace "field_name" with the actual identifier
            old_value = collection.find_one(filter_query)[field]
            update_query = {"$set": {field: row[field]}}  # Update other fields as needed
            result = collection.update_one(filter_query, update_query)
            new_value = collection.find_one(filter_query)[field]
            print(f"Updated week: {week}, team: {row['Team']} {field} from {old_value} to {new_value}.")
    # Print success message
    print("Updated document in the collection.")

# %%
dfupdate = dfseasonspreads.reset_index().copy()
dfupdate = dfupdate[(dfupdate['Team']=='San Francisco 49ers')&(dfupdate['Week']==5)]
update_document(client, mongo_db, 'season_spreads_backup', 5, ['spread'],dfupdate)
# Out:
# Updated week: 5, team: San Francisco 49ers spread from -3.5 to -3.5.
# Updated document in the collection.

# %%
def delete_documents(mongo_db, mongo_collection, field_to_match, value_to_match):
    """
    Delete documents from a MongoDB collection that match a certain value.

    Parameters
    ----------
    mongo_db : str
        Name of the MongoDB database.
    mongo_collection : str
        Name of the MongoDB collection.
    value_to_match : int or str
        Value to match for deletion.

    Returns
    -------
    None.
    """

    # Connect to the database and collection
    database = client[mongo_db]
    collection = database[mongo_collection]


    # Create a query to find documents matching the value
    query = {field_to_match: value_to_match}  # Replace 'field_name_to_match' with your actual field name

    # Delete documents that match the query
    result = collection.delete_many(query)

    # Print the number of deleted documents
    print(f"Deleted {result.deleted_count} documents that matched the value.")

# %%
mongo_db = 'withTheSpread'  # Replace with your desired database name
mongo_collection = 'season_spreads'  # Replace with your desired collection name

def delete_documents(mongo_db, mongo_collection, value_to_match):
    """
    Delete documents from a MongoDB collection that match a certain value.

    Parameters
    ----------
    mongo_db : str
        Name of the MongoDB database.
    mongo_collection : str
        Name of the MongoDB collection.
    value_to_match : int or str
        Value to match for deletion.

    Returns
    -------
    None.
    """

    # Connect to the database and collection
    database = client[mongo_db]
    collection = database[mongo_collection]

    # Define the value you want to match for deletion
    value_to_match = 5

    # Create a query to find documents matching the value
    query = {"Week": value_to_match}  # Replace 'field_name_to_match' with your actual field name

    # Delete documents that match the query
    result = collection.delete_many(query)

    # Print the number of deleted documents
    print(f"Deleted {result.deleted_count} documents that matched the value.")


database = client[mongo_db]
collection = database[mongo_collection]

# Define the value you want to match for deletion
value_to_match = 5

# Create a query to find documents matching the value
query = {"Week": value_to_match}  # Replace 'field_name_to_match' with your actual field name

# Delete documents that match the query
result = collection.delete_many(query)

# Print the number of deleted documents
print(f"Deleted {result.deleted_count} documents that matched the value.")
# Out:
# Deleted 32 documents that matched the value.

# %%
# [game for game in json.loads(data.decode("utf-8"))['response'] if
#  game['teams']['away']['name'] == 'Buffalo Bills' and game['game']['stage'] == 'Regular Season']
import http.client
import json

conn = http.client.HTTPSConnection("v1.american-football.api-sports.io")
scoreskey = '40c091a0954eb4e610a4cc8fce5cefd7'
headers = {
    'x-rapidapi-host': "v1.american-football.api-sports.io",
    'x-rapidapi-key': scoreskey
}

conn.request("GET", "/games?league=1&season=2023", headers=headers)

res = conn.getresponse()
data = res.read()

# %%
data
# Out:
# b'{"get":"games","parameters":{"league":"1","season":"2023"},"errors":[],"results":332,"response":[{"game":{"id":7804,"stage":"Pre Season","week":"Hall of Fame Weekend","date":{"timezone":"UTC","date":"2023-08-04","time":"00:00","timestamp":1691107200},"venue":{"name":"Tom Benson Hall of Fame Stadium","city":"Canton"},"status":{"short":"FT","long":"Finished","timer":null}},"league":{"id":1,"name":"NFL","season":"2023","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/leagues\\/1.png","country":{"name":"USA","code":"US","flag":"https:\\/\\/media-4.api-sports.io\\/flags\\/us.svg"}},"teams":{"home":{"id":9,"name":"Cleveland Browns","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/9.png"},"away":{"id":13,"name":"New York Jets","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/13.png"}},"scores":{"home":{"quarter_1":0,"quarter_2":7,"quarter_3":7,"quarter_4":7,"overtime":null,"total":21},"away":{"quarter_1":6,"quarter_2":10,"quarter_3":0,"quarter_4":0,"overtime":null,"total":16}}},{"game":{"id":7805,"stage":"Pre Season","week":"Week 1","date":{"timezone":"UTC","date":"2023-08-10","time":"23:00","timestamp":1691708400},"venue":{"name":"Gillette Stadium","city":"Foxborough"},"status":{"short":"FT","long":"Finished","timer":null}},"league":{"id":1,"name":"NFL","season":"2023","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/leagues\\/1.png","country":{"name":"USA","code":"US","flag":"https:\\/\\/media-4.api-sports.io\\/flags\\/us.svg"}},"teams":{"home":{"id":3,"name":"New England Patriots","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/3.png"},"away":{"id":26,"name":"Houston Texans","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/26.png"}},"scores":{"home":{"quarter_1":3,"quarter_2":0,"quarter_3":0,"quarter_4":6,"overtime":null,"total":9},"away":{"quarter_1":0,"quarter_2":7,"quarter_3":6,"quarter_4":7,"overtime":null,"total":20}}},{"game":{"id":7806,"stage":"Pre Season","week":"Week 1","date":{"timezone":"UTC","date":"2023-08-11","time":"02:00","timestamp":1691719200},"venue":{"name":"Lumen Field","city":"Seattle"},"status":{"short":"FT","long":"Finished","timer":null}},"league":{"id":1,"name":"NFL","season":"2023","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/leagues\\/1.png","country":{"name":"USA","code":"US","flag":"https:\\/\\/media-4.api-sports.io\\/flags\\/us.svg"}},"teams":{"home":{"id":23,"name":"Seattle Seahawks","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/23.png"},"away":{"id":32,"name":"Minnesota Vikings","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/32.png"}},"scores":{"home":{"quarter_1":0,"quarter_2":7,"quarter_3":10,"quarter_4":7,"overtime":null,"total":24},"away":{"quarter_1":3,"quarter_2":7,"quarter_3":3,"quarter_4":0,"overtime":null,"total":13}}},{"game":{"id":7807,"stage":"Pre Season","week":"Week 1","date":{"timezone":"UTC","date":"2023-08-11","time":"23:00","timestamp":1691794800},"venue":{"name":"Paycor Stadium","city":"Cincinnati"},"status":{"short":"FT","long":"Finished","timer":null}},"league":{"id":1,"name":"NFL","season":"2023","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/leagues\\/1.png","country":{"name":"USA","code":"US","flag":"https:\\/\\/media-4.api-sports.io\\/flags\\/us.svg"}},"teams":{"home":{"id":10,"name":"Cincinnati Bengals","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/10.png"},"away":{"id":15,"name":"Green Bay Packers","logo":"https:\\/\\/media-4.api-sports.io\\/american-football\\/teams\\/15.png"}},"scores":{"home":{"quarter_1":3,"quarter_2":13,"quarter_3":3,"quarter_4":0,"overtime":null,"total":19},"away":{"quarter_1":7,"quarter_2":14,"quarter_3":9,"quarter_4":6,"overtime":null,"total":36}}},{"game":{"id":7808,"stage":"Pre Season","week":"Week 1","date":{"timezone":"UTC","date":"2023-08-11","time":"23:00","timestamp":1691794800},"venue":{"name":"Ford Field" ...

# %% [markdown]
# ### should delete later

# %% [markdown]
# ### extract game data to compare with predictions

# %%
dfgameresults
# Out:
#                        score  diff
# San Francisco 49ers       30    18
# New York Giants           12   -18
# Cleveland Browns          27    24
# Tennessee Titans           3   -24
# Detroit Lions             20    14
# Atlanta Falcons            6   -14
# Green Bay Packers         18     1
# New Orleans Saints        17    -1
# Miami Dolphins            70    50
# Denver Broncos            20   -50
# Minnesota Vikings         24    -4
# Los Angeles Chargers      28     4
# New York Jets             10    -5
# New England Patriots      15     5
# Washington Commanders      3   -34
# Buffalo Bills             37    34
# Jacksonville Jaguars      17   -20
# Houston Texans            37    20
# Baltimore Ravens          19    -3
# Indianapolis Colts        22     3
# Seattle Seahawks          37    10
# Carolina Panthers         27   -10
# Kansas City Chiefs        41    31
# Chicago Bears             10   -31
# Arizona Cardinals         28    12
# Dallas Cowboys            16   -12
# Las Vegas Raiders         18    -5
# Pittsburgh Steelers       23     5
# Tampa Bay Buccaneers      11   -14
# Philadelphia Eagles       25    14
# Cincinnati Bengals        19     3
# Los Angeles Rams          16    -3

# %%
games = [game for game in json.loads(data.decode("utf-8"))['response'] if game['game']['stage']=='Regular Season' and game['game']['status']['short']!='NS']
weeks = sorted(list(set([game['game']['week'] for game in games])))
weeks_num = sorted([int(week.split(' ')[1]) for week in weeks])
lastweekstr = 'week'+str(max(weeks_num))
nextweekstr = 'week'+str(max(weeks_num)+1)
print(lastweekstr,nextweekstr)
print(weeks_num)
gamescores = {}
gamescorediffs = {}
opponent = {}
for game in games:
    if game['game']['week']==weeks[-1]:
        gamescores[game['teams']['home']['name']] = game['scores']['home']['total']
        gamescores[game['teams']['away']['name']] = game['scores']['away']['total']
        gamescorediffs[game['teams']['home']['name']] = game['scores']['home']['total']-game['scores']['away']['total']
        gamescorediffs[game['teams']['away']['name']] = game['scores']['away']['total']-game['scores']['home']['total']
        # opponent[game['teams']['home']['name']] = game['teams']['away']['name']
        # opponent[game['teams']['away']['name']] = game['teams']['home']['name']

dfgameresults = pd.concat([
                           pd.Series(gamescores,name='score'),
                            pd.Series(gamescorediffs,name='diff')
                           ],axis=1)
dfgameresults
# dfgameresults['Week'] = weeks_num[-1]
# dfgameresults['Year'] = 2023

dfseasonspreads_lastweek = dfseasonspreads[dfseasonspreads['Week']==weeks_num[-1]].drop(['diff','score'],axis=1).merge(dfgameresults,left_index=True,right_index=True,how='left')
dfseasonspreads_lastweek['spreadscore'] = dfseasonspreads_lastweek['diff'] + dfseasonspreads_lastweek['spread']
dfseasonspreads_lastweek
# Out:
# week3 week4
# [1, 2, 3]
#                                     opponent  spread  Week  Year  spreadscore  \
# Team
# New England Patriots           New York Jets    -3.0     3  2023          2.0
# Philadelphia Eagles     Tampa Bay Buccaneers    -5.0     3  2023          9.0
# Chicago Bears             Kansas City Chiefs    12.5     3  2023        -18.5
# Las Vegas Raiders        Pittsburgh Steelers    -2.5     3  2023         -7.5
# Los Angeles Chargers       Minnesota Vikings     1.0     3  2023          5.0
# Cincinnati Bengals          Los Angeles Rams    -1.5     3  2023          1.5
# Jacksonville Jaguars          Houston Texans    -9.5     3  2023        -29.5
# Tampa Bay Buccaneers     Philadelphia Eagles     5.0     3  2023         -9.0
# Kansas City Chiefs             Chicago Bears   -12.5     3  2023         18.5
# Minnesota Vikings       Los Angeles Chargers    -1.0     3  2023         -5.0
# Seattle Seahawks           Carolina Panthers    -6.0     3  2023          4.0
# Buffalo Bills          Washington Commanders    -6.5     3  2023         27.5
# New Orleans Saints         Green Bay Packers     2.0     3  2023          1.0
# Washington Commanders          Buffalo Bills     6.5     3  2023        -27.5
# Cleveland Browns            Tennessee Titans    -3.0     3  2023         21.0
# Pittsburgh Steelers        Las Vegas Raiders     2.5     3  2023          7.5
# Carolina Panthers           Seattle Seahawks     6.0     3  2023         -4.0
# Dallas Cowboys             Arizona Cardinals   -12.0     3  2023        -24.0
# Green Bay Packers         New Orleans Saints    -2.0     3  2023         -1.0
# Miami Dolphins                Denver Broncos    -6.5     3  2023         43.5
# Atlanta Falcons                Detroit Lions     3.0     3  2023        -11.0
# Denver Broncos                Miami Dolphins     6.5     3  2023        -43.5
# New York Jets           New England Patriots     3.0     3  2023         -2.0
# Arizona Cardinals             Dallas Cowboys    12.0     3  2023         24.0
# Los Angeles Rams          Cincinnati Bengals     1.5     3  2023         -1.5
# San Francisco 49ers          New York Giants   -10.0     3  2023          8.0
# Detroit Lions                Atlanta Falcons    -3.0     3  2023         11.0
# Indianapolis Colts          Baltimore Ravens     7.5     3  2023         10.5
# Houston Texans          Jacksonville Jaguars     9.5     3  2023         29.5
# Baltimore Ravens          Indianapolis Colts    -7.5     3  2023        -10.5
# New York Giants          San Francisco 49ers    10.0     3  2023         -8.0
# Tennessee Titans            Cleveland Browns     3.0     3  2023        -21.0
#
#                        coverprob  predspread  order  coverprob_diff  \
# Team
# New England Patriots    0.498703   -2.853181    8.0        0.103923
# Philadelphia Eagles     0.477190    0.630877   14.0       -0.097268
# Chicago Bears           0.492919   -7.284313   12.0       -0.066827
# Las Vegas Raiders       0.470431   -4.212704   13.0       -0.113735
# Los Angeles Chargers    0.498703   -5.450742    7.0        0.060434
# Cincinnati Bengals      0.492919   -1.633186   15.0        0.015729
# Jacksonville Jaguars    0.431436   -0.724891    6.0        0.047580
# Tampa Bay Buccaneers    0.574457   -1.803754   14.0        0.097268
# Kansas City Chiefs      0.559746    8.711520   12.0        0.066827
# Minnesota Vikings       0.438268   10.976600    7.0       -0.060434
# Seattle Seahawks        0.574457    7.257826   10.0        0.125297
# Buffalo Bills           0.557164   -5.536414    3.0       -0.017294
# New Orleans Saints      0.456077    0.017965    5.0       -0.012991
# Washington Commanders   0.574457   -3.097260    3.0        0.017294
# Cleveland Browns        0.491753   -0.171173    9.0       -0.082704
# Pittsburgh Steelers     0.584167    0.092946   13.0        0.113735
# Carolina Panthers       0.449161   -1.791258   10.0       -0.125297
# Dallas Cowboys          0.570609    7.563698   11.0        0.100379
# Green Bay Packers       0.469069    5.775466    5.0        0.012991
# Miami Dolphins          0.584167    1.624571    4.0        0.092413
# Atlanta Falcons         0.432580    9.257001    1.0        0.048724
# Denver Broncos          0.491753    8.356886    4.0       -0.092413
# New York Jets           0.394779   -0.589251    8.0       -0.103923
# Arizona Cardinals       0.470230   -0.069118   11.0       -0.100379
# Los Angeles Rams        0.477190   -1.518422   15.0       -0.015729
# San Francisco 49ers     0.446624   -6.308135    0.0        0.008355
# Detroit Lions           0.383856    0.881525    1.0       -0.048724
# Indianapolis Colts      0.561735    0.823084    2.0       -0.025605
# Houston Texans          0.383856   -4.531844    6.0       -0.047580
# Baltimore Ravens        0.587340   -0.649730    2.0        0.025605
# New York Giants         0.438268    6.049087    0.0       -0.008355
# Tennessee Titans        0.574457    4.505132    9.0        0.082704
#
#                        predspread_diff  score  diff
# Team
# New England Patriots         -2.263929     15     5
# Philadelphia Eagles           2.434631     25    14
# Chicago Bears               -15.995833     10   -31
# Las Vegas Raiders            -4.305650     18    -5
# Los Angeles Chargers        -16.427342     28     4
# Cincinnati Bengals           -0.114765     19     3
# Jacksonville Jaguars          3.806953     17   -20
# Tampa Bay Buccaneers         -2.434631     11   -14
# Kansas City Chiefs           15.995833     41    31
# Minnesota Vikings            16.427342     24    -4
# Seattle Seahawks              9.049084     37    10
# Buffalo Bills                -2.439155     37    34
# New Orleans Saints           -5.757501     17    -1
# Washington Commanders         2.439155      3   -34
# Cleveland Browns             -4.676306     27    24
# Pittsburgh Steelers           4.305650     23     5
# Carolina Panthers            -9.049084     27   -10
# Dallas Cowboys                7.632815     16   -12
# Green Bay Packers             5.757501     18     1
# Miami Dolphins               -6.732315     70    50
# Atlanta Falcons               8.375476      6   -14
# Denver Broncos                6.732315     20   -50
# New York Jets                 2.263929     10    -5
# Arizona Cardinals            -7.632815     28    12
# Los Angeles Rams              0.114765     16    -3
# San Francisco 49ers         -12.357222     30    18
# Detroit Lions                -8.375476     20    14
# Indianapolis Colts            1.472813     22     3
# Houston Texans               -3.806953     37    20
# Baltimore Ravens             -1.472813     19    -3
# New York Giants              12.357222     12   -18
# Tennessee Titans              4.676306      3   -24

# %% [markdown]
# ### update seasonspreads with last weeks results

# %%
dfseasonspreads.loc[dfseasonspreads_lastweek['Week']==weeks_num[-1],'score'] = dfseasonspreads_lastweek['score']
dfseasonspreads.loc[dfseasonspreads_lastweek['Week']==weeks_num[-1],'diff'] = dfseasonspreads_lastweek['diff']
dfseasonspreads.loc[dfseasonspreads_lastweek['Week']==weeks_num[-1],'spreadscore'] = dfseasonspreads_lastweek['spreadscore']
dfseasonspreads
# Out:
# C:\Users\hogan\AppData\Local\Temp\ipykernel_7312\1855352822.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfseasonspreads.loc[dfseasonspreads_lastweek['Week']==weeks_num[-1],'score'] = dfseasonspreads_lastweek['score']
# C:\Users\hogan\AppData\Local\Temp\ipykernel_7312\1855352822.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfseasonspreads.loc[dfseasonspreads_lastweek['Week']==weeks_num[-1],'diff'] = dfseasonspreads_lastweek['diff']
#                                     opponent  spread  score  diff  Week  Year  \
# Team
# Washington Commanders      Arizona Cardinals    -7.0      3   -34     1  2023
# Chicago Bears              Green Bay Packers    -1.5     10   -31     1  2023
# Arizona Cardinals      Washington Commanders     7.0     28    12     1  2023
# Denver Broncos             Las Vegas Raiders    -3.0     20   -50     1  2023
# Tennessee Titans          New Orleans Saints     3.0      3   -24     1  2023
# ...                                      ...     ...    ...   ...   ...   ...
# Houston Texans          Jacksonville Jaguars     9.5     37    20     3  2023
# Cleveland Browns         Pittsburgh Steelers    -2.5     27    24     2  2023
# Baltimore Ravens          Indianapolis Colts    -7.5     19    -3     3  2023
# New York Giants          San Francisco 49ers    10.0     12   -18     3  2023
# Tennessee Titans            Cleveland Browns     3.0      3   -24     3  2023
#
#                        spreadscore  coverprob  predspread  order  \
# Team
# Washington Commanders        -27.5        NaN         NaN    NaN
# Chicago Bears                -18.5        NaN         NaN    NaN
# Arizona Cardinals             24.0        NaN         NaN    NaN
# Denver Broncos               -43.5        NaN         NaN    NaN
# Tennessee Titans             -21.0        NaN         NaN    NaN
# ...                            ...        ...         ...    ...
# Houston Texans                29.5   0.383856   -4.531844    6.0
# Cleveland Browns              21.0   0.458267    2.221873    NaN
# Baltimore Ravens             -10.5   0.587340   -0.649730    2.0
# New York Giants               -8.0   0.438268    6.049087    0.0
# Tennessee Titans             -21.0   0.574457    4.505132    9.0
#
#                        coverprob_diff  predspread_diff
# Team
# Washington Commanders             NaN              NaN
# Chicago Bears                     NaN              NaN
# Arizona Cardinals                 NaN              NaN
# Denver Broncos                    NaN              NaN
# Tennessee Titans                  NaN              NaN
# ...                               ...              ...
# Houston Texans              -0.047580        -3.806953
# Cleveland Browns                  NaN              NaN
# Baltimore Ravens             0.025605        -1.472813
# New York Giants             -0.008355        12.357222
# Tennessee Titans             0.082704         4.676306
#
# [96 rows x 12 columns]

# %% [markdown]
# ### get next weeks game spreads through api

# %%
import requests

API_KEY = '685f879ea79649c48a2ed648a7876f1f'
url = f'https://api.the-odds-api.com/v4/sports/americanfootball_nfl/odds?regions=us&markets=h2h,spreads,totals&oddsFormat=american&apiKey={API_KEY}'

r = requests.get(url)

r = requests.get(url)
if r.status_code == 200:
    # for p in r.content:
    #     print(p)
  spreaddata = json.loads(r.content)
  print(spreaddata)
# Out:
# [{'id': '934acd8d5f569c955f4a02aa42284fa4', 'sport_key': 'americanfootball_nfl', 'sport_title': 'NFL', 'commence_time': '2023-09-29T00:15:00Z', 'home_team': 'Green Bay Packers', 'away_team': 'Detroit Lions', 'bookmakers': [{'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-09-28T03:24:52Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-28T03:24:52Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -122}, {'name': 'Green Bay Packers', 'price': 104}]}, {'key': 'spreads', 'last_update': '2023-09-28T03:24:52Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -108, 'point': -1.5}, {'name': 'Green Bay Packers', 'price': -112, 'point': 1.5}]}, {'key': 'totals', 'last_update': '2023-09-28T03:24:52Z', 'outcomes': [{'name': 'Over', 'price': -115, 'point': 45.5}, {'name': 'Under', 'price': -105, 'point': 45.5}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-09-28T03:22:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-28T03:22:44Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -120}, {'name': 'Green Bay Packers', 'price': 100}]}, {'key': 'spreads', 'last_update': '2023-09-28T03:22:44Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -108, 'point': -1.5}, {'name': 'Green Bay Packers', 'price': -112, 'point': 1.5}]}, {'key': 'totals', 'last_update': '2023-09-28T03:22:44Z', 'outcomes': [{'name': 'Over', 'price': -112, 'point': 46.0}, {'name': 'Under', 'price': -108, 'point': 46.0}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-09-28T03:24:51Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-28T03:24:51Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -123}, {'name': 'Green Bay Packers', 'price': 101}]}, {'key': 'spreads', 'last_update': '2023-09-28T03:24:51Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': -1.5}, {'name': 'Green Bay Packers', 'price': -110, 'point': 1.5}]}, {'key': 'totals', 'last_update': '2023-09-28T03:24:51Z', 'outcomes': [{'name': 'Over', 'price': -110, 'point': 46.0}, {'name': 'Under', 'price': -110, 'point': 46.0}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2023-09-28T03:24:54Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-28T03:24:54Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -133}, {'name': 'Green Bay Packers', 'price': 113}]}, {'key': 'spreads', 'last_update': '2023-09-28T03:24:54Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -107, 'point': -2.0}, {'name': 'Green Bay Packers', 'price': -103, 'point': 2.0}]}, {'key': 'totals', 'last_update': '2023-09-28T03:24:54Z', 'outcomes': [{'name': 'Over', 'price': -105, 'point': 46.0}, {'name': 'Under', 'price': -109, 'point': 46.0}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2023-09-28T03:24:12Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-28T03:24:12Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -130}, {'name': 'Green Bay Packers', 'price': 110}]}, {'key': 'spreads', 'last_update': '2023-09-28T03:24:12Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -110, 'point': -2.0}, {'name': 'Green Bay Packers', 'price': -110, 'point': 2.0}]}, {'key': 'totals', 'last_update': '2023-09-28T03:24:12Z', 'outcomes': [{'name': 'Over', 'price': -110, 'point': 46.0}, {'name': 'Under', 'price': -110, 'point': 46.0}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-09-28T03:24:52Z', 'markets': [{'key': 'h2h', 'last_update': '2023-09-28T03:24:52Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -133}, {'name': 'Green Bay Packers', 'price': 113}]}, {'key': 'spreads', 'last_update': '2023-09-28T03:24:52Z', 'outcomes': [{'name': 'Detroit Lions', 'price': -112, 'point': -2.0}, {'name': 'Green Bay Packers', 'price': -108, 'point': 2.0}]}, {'key': 'totals', 'last_update': '2023-09-28T03:24:52Z', 'outcomes': [{'name': 'Over', 'price': -110, 'point': 46.0}, {'name': 'Under', 'price': -110, 'point': 46.0}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2023-09-28T03:24:53Z', 'markets': [{'key': 'h2h', 'last_u ...

# %% [markdown]
# ### extract next weeks spreads

# %%
# import datetime
# today  = datetime.datetime.now().date()
# today + datetime.timedelta(days=7)
date_format = '%Y-%m-%dT%H:%M:%SZ'
datetime.datetime.strptime(spreaddata[0]['commence_time'],date_format) < datetime.datetime.today() + datetime.timedelta(days=7)
nextweek = [game for game in spreaddata if datetime.datetime.strptime(game['commence_time'],date_format) < datetime.datetime.today() + datetime.timedelta(days=7)]
games = [game['bookmakers'][0]['markets'] for game in nextweek] #+ [game['bookmakers'][1]['markets'] for game in thisweek]

nextweek_spreads = {}
order = {}
opponent = {}
for i, game in enumerate(games):
    for bet in game:
        if bet['key']=='spreads':
            nextweek_spreads[bet['outcomes'][0]['name']] = bet['outcomes'][0]['point']
            nextweek_spreads[bet['outcomes'][1]['name']] = bet['outcomes'][1]['point']
            order[bet['outcomes'][0]['name']] = i
            order[bet['outcomes'][1]['name']] = i
            opponent[bet['outcomes'][0]['name']] = bet['outcomes'][1]['name']
            opponent[bet['outcomes'][1]['name']] = bet['outcomes'][0]['name']
nextweek_spreads
dfseasonspreads_nextweek = pd.concat([pd.Series(nextweek_spreads,name='spread'),
                                      pd.Series(order,name='order'),
                                      pd.Series(opponent,name='opponent')
                                      ],axis=1)
dfseasonspreads_nextweek
# Out:
#                        spread  order               opponent
# Detroit Lions            -1.5      0      Green Bay Packers
# Green Bay Packers         1.5      0          Detroit Lions
# Atlanta Falcons           3.0      1   Jacksonville Jaguars
# Jacksonville Jaguars     -3.0      1        Atlanta Falcons
# Baltimore Ravens          2.5      2       Cleveland Browns
# Cleveland Browns         -2.5      2       Baltimore Ravens
# Buffalo Bills            -3.0      3         Miami Dolphins
# Miami Dolphins            3.0      3          Buffalo Bills
# Carolina Panthers         4.0      4      Minnesota Vikings
# Minnesota Vikings        -4.0      4      Carolina Panthers
# Chicago Bears             3.5      5         Denver Broncos
# Denver Broncos           -3.5      5          Chicago Bears
# Cincinnati Bengals       -2.5      6       Tennessee Titans
# Tennessee Titans          2.5      6     Cincinnati Bengals
# Houston Texans            3.0      7    Pittsburgh Steelers
# Pittsburgh Steelers      -3.0      7         Houston Texans
# Indianapolis Colts       -1.5      8       Los Angeles Rams
# Los Angeles Rams          1.5      8     Indianapolis Colts
# New Orleans Saints       -3.0      9   Tampa Bay Buccaneers
# Tampa Bay Buccaneers      3.0      9     New Orleans Saints
# Philadelphia Eagles      -8.5     10  Washington Commanders
# Washington Commanders     8.5     10    Philadelphia Eagles
# Las Vegas Raiders         5.5     11   Los Angeles Chargers
# Los Angeles Chargers     -5.5     11      Las Vegas Raiders
# Arizona Cardinals        14.0     12    San Francisco 49ers
# San Francisco 49ers     -14.0     12      Arizona Cardinals
# Dallas Cowboys           -6.5     13   New England Patriots
# New England Patriots      6.5     13         Dallas Cowboys
# Kansas City Chiefs       -9.5     14          New York Jets
# New York Jets             9.5     14     Kansas City Chiefs
# New York Giants          -1.5     15       Seattle Seahawks
# Seattle Seahawks          1.5     15        New York Giants

# %% [markdown]
# ### train models

# %%
def genData(nextweek,nweeks):

    def genFrames(df,startweek,nweeks):
        ytemp = df[startweek+nweeks]
        ytemp = ytemp[ytemp!=0].dropna()
        Xtemp = df[[i for i in range(startweek,startweek+nweeks)]].loc[ytemp.index]
        Xtemp['Week'] = ytemp.name
        Xtemp = Xtemp.droplevel(2).reset_index().set_index(['Team','Year','Week']).rename_axis(None,axis=1)
        # Xtemp['Team'] = Xtemp['Team'].astype('category')
        # Xtemp['Year'] = Xtemp['Year'].astype('category')
        return Xtemp,ytemp#,year,week
    # dfspread = pd.read_csv('data/dfspread.csv',index_col=[0,1,2])
    dfspread = dfbets[dfbets['Bet']=='SpreadScore'].drop(['_id','Bet'],axis=1).set_index(['Team','Year','teamyearid'])
    dfspread.columns = [int(col) if col not in ['Team','Year','teamyearid'] else col for col in dfspread.columns]
    dfmodel = dfspread.loc[pd.IndexSlice[2022] != dfspread.index.get_level_values('Year')]
    dfval = dfspread.loc[pd.IndexSlice[2022] == dfspread.index.get_level_values('Year')]

    # thisweek = weeks_num[0]+1
    # nweeks = min(5,weeks_num[0])

    Xlist = [genFrames(dfmodel,startweek,nweeks)[0].reset_index() for startweek in range(1,nextweek+1-nweeks)]
    ylist = [genFrames(dfmodel,startweek,nweeks)[1] for startweek in range(1,nextweek+1-nweeks)]
    X = pd.DataFrame(np.concatenate(Xlist, axis=0))
    X.columns = ['Team','Year','Week']+list(range(1,nweeks+1))
    for col in X.columns:
        if col in ['Team','Year','Week']:
            X[col] = X[col].astype('category')
        else:
            X[col] = pd.to_numeric(X[col])
    y = pd.Series(np.concatenate(ylist, axis=0))

    from sklearn.model_selection import train_test_split
    import random
    from sklearn.model_selection import cross_val_score
    from xgboost import XGBRegressor,XGBClassifier
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,
                                                        random_state=random.randint(1,100)
                                                        # random_state=42
                                                        )

    Xlist = [genFrames(dfval,startweek,nweeks)[0].reset_index() for startweek in range(1,nextweek+1-nweeks)]
    ylist = [genFrames(dfval,startweek,nweeks)[1] for startweek in range(1,nextweek+1-nweeks)]
    X_val = pd.DataFrame(np.concatenate(Xlist, axis=0))
    X_val.columns = ['Team','Year','Week']+list(range(1,nweeks+1))
    for col in X_val.columns:
        if col in ['Team','Year','Week']:
            X_val[col] = X_val[col].astype('category')
        else:
            X_val[col] = pd.to_numeric(X_val[col])
    y_val = pd.Series(np.concatenate(ylist, axis=0))

    return X_train, X_test, y_train, y_test,X_val,y_val

def fitxgbModel(modeltype):
    from hyperopt import fmin, tpe, hp
    def objective(params):

        # selected_features = [i for i, use_feature in enumerate(params['features']) if use_feature]

        # if not any(params['features']):  # Ensure at least one feature is selected
        #     return 1.0  # Penalize if no features are selected

        params = {
            'learning_rate': params['learning_rate'],
            'max_depth': int(params['max_depth']),
            'n_estimators': int(params['n_estimators']),
            'reg_lambda': params['reg_lambda'],
            'reg_alpha': params['reg_alpha'],
            'min_child_weight': params['min_child_weight'],

            # 'scale_pos_weight': params['scale_pos_weight'],
            # Add more hyperparameters
        }
        modeldict = {'reg':XGBRegressor,'clas':XGBClassifier}
        model = modeldict[modeltype](**params,enable_categorical=True,tree_method="hist")
        from sklearn.preprocessing import LabelEncoder
        y_encoded = LabelEncoder().fit_transform(np.sign(y_train))
        # model = XGBRegressor(**params,enable_categorical=True,tree_method="hist")
        if modeltype=='clas':
            cvscore = cross_val_score(model, X_train, y_encoded, cv=5)
        else:
            cvscore = cross_val_score(model, X_train, y_train, cv=5)

        return 1-cvscore.mean()  # Hyperopt minimizes the objective, so we use negative accuracy

    # Define the search space for hyperparameters
    space = {
        'learning_rate': hp.uniform('learning_rate', 0.01, 0.3),
        'max_depth': hp.quniform('max_depth', 2, 5, 1),
        'n_estimators': hp.quniform('n_estimators', 50, 200, 10),
        'reg_lambda': hp.uniform('reg_lambda', 1, 5),
        'reg_alpha': hp.uniform('reg_alpha', 1, 5),
        'min_child_weight': hp.uniform('min_child_weight', 1, 5),
        # 'scale_pos_weight': hp.quniform('scale_pos_weight', 1, 10, 3),
        # 'features': [hp.choice(f'feature_{i}', [True, False]) for i in range(X[modelcolsall].shape[1])]

        # Add more hyperparameters to optimize
    }

    # Run hyperparameter optimization
    best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=20)
    print("Best hyperparameters:", best)

    def round_whole_numbers(d, decimal_places=2):
        rounded_dict = {}

        for key, value in d.items():
            if isinstance(value, (int, float)) and value.is_integer():
                rounded_value = int(value)
            else:
                rounded_value = value
            rounded_dict[key] = rounded_value

        return rounded_dict

    bestparams = round_whole_numbers(best)
    return bestparams

## create training data
nextweek = weeks_num[0]+1
nweeks = min(5,weeks_num[0])
X_train, X_test, y_train, y_test,X_val,y_val = genData(nextweek,nweeks)

#import xgb models and metrics
from xgboost import XGBRegressor,XGBClassifier
from sklearn.metrics import accuracy_score,f1_score,make_scorer
from sklearn.model_selection import cross_val_score
## create training data
nextweek = weeks_num[-1]+1
nweeks = min(5,weeks_num[-1])
X_train, X_test, y_train, y_test,X_val,y_val = genData(nextweek,nweeks)

## fit best parameters for  reg and clas models
bestparamsreg = fitxgbModel('reg')
bestparamsclas = fitxgbModel('clas')

## train xgb models
reg = XGBRegressor(**bestparamsreg,enable_categorical=True,tree_method="hist")
reg.fit(X_train,y_train)
clas = XGBClassifier(**bestparamsclas,enable_categorical=True,tree_method="hist")
from sklearn.preprocessing import LabelEncoder
y_encoded = LabelEncoder().fit_transform(np.sign(y_train))
clas.fit(X_train,y_encoded)
# Out:
# 100%|██████████| 20/20 [00:13<00:00,  1.46trial/s, best loss: 1.0339314247590567]
# Best hyperparameters: {'learning_rate': 0.014079210276233843, 'max_depth': 3.0, 'min_child_weight': 3.36049044804571, 'n_estimators': 50.0, 'reg_alpha': 3.671044917207988, 'reg_lambda': 2.172066555453631}
# 100%|██████████| 20/20 [00:13<00:00,  1.50trial/s, best loss: 0.48571428571428577]
# Best hyperparameters: {'learning_rate': 0.12573125337300176, 'max_depth': 5.0, 'min_child_weight': 3.39374603045044, 'n_estimators': 130.0, 'reg_alpha': 3.8341768417280253, 'reg_lambda': 1.7208351096544585}
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.12573125337300176,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=3.39374603045044, missing=nan,
#               monotone_constraints=None, n_estimators=130, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None, ...)

# %% [markdown]
# ### predict next weeks spreads

# %%
# Xnextweek = dfseasonspreads_temp[[col for col in dfseasonspreads_temp.columns if 'spreadscore' in col]].copy()
# Xnextweek.columns = [col.split(' ')[1] for col in Xnextweek.columns]
# X = .res/et_index().rename({'index':'Team'},axis=1)#.columns = [int(dfseasonspreads
X = dfseasonspreads.pivot(columns='Week',values='spreadscore')
X.columns = list(range(len(X.columns)+1))[1:]
X = X.reset_index().rename({'index':'Team'},axis=1)
X['Year'] = 2023
X['Week'] = weeks_num[-1]+1
X# .columns[-1].split(' ')[1])-1],'Team','Year','Week']
X = X[['Team','Year','Week']+[col for col in X.columns if col not in ['Team','Year','Week']]]
for col in ['Team','Year','Week']:
    X[col] = X[col].astype('category')
# X = X.set_index(['Team','Year'])
X
dfseasonspreads_temp = pd.concat([X.set_index('Team'),
           pd.DataFrame(clas.predict_proba(X),index=X['Team']).iloc[:,1].rename('coverprob'),
           pd.Series(reg.predict(X),index=X['Team'],name='predspread')],axis=1)
dfseasonspreads_temp = dfseasonspreads_temp[['Year','Week','coverprob','predspread']].join(dfseasonspreads_nextweek)
dfseasonspreads_temp
# Out:
#                        Year Week  coverprob  predspread  spread  order  \
# Team
# Arizona Cardinals      2023    4   0.427438    0.152778    14.0     12
# Atlanta Falcons        2023    4   0.585272    1.940460     3.0      1
# Baltimore Ravens       2023    4   0.600474    2.072983     2.5      2
# Buffalo Bills          2023    4   0.427438   -1.167447    -3.0      3
# Carolina Panthers      2023    4   0.440893   -0.976324     4.0      4
# Chicago Bears          2023    4   0.533678    1.449535     3.5      5
# Cincinnati Bengals     2023    4   0.545683    1.698044    -2.5      6
# Cleveland Browns       2023    4   0.436227    1.196666    -2.5      2
# Dallas Cowboys         2023    4   0.478687   -1.089760    -6.5     13
# Denver Broncos         2023    4   0.478687    0.591706    -3.5      5
# Detroit Lions          2023    4   0.723461    1.795273    -1.5      0
# Green Bay Packers      2023    4   0.455187    2.678364     1.5      0
# Houston Texans         2023    4   0.429010    1.388710     3.0      7
# Indianapolis Colts     2023    4   0.717541    3.061482    -1.5      8
# Jacksonville Jaguars   2023    4   0.452640   -0.706269    -3.0      1
# Kansas City Chiefs     2023    4   0.412615    1.984837    -9.5     14
# Las Vegas Raiders      2023    4   0.611574    1.051717     5.5     11
# Los Angeles Chargers   2023    4   0.628815    1.335097    -5.5     11
# Los Angeles Rams       2023    4   0.218947   -1.387671     1.5      8
# Miami Dolphins         2023    4   0.424273   -1.683642     3.0      3
# Minnesota Vikings      2023    4   0.533205    0.717429    -4.0      4
# New England Patriots   2023    4   0.585482    0.895977     6.5     13
# New Orleans Saints     2023    4   0.385061    2.201501    -3.0      9
# New York Giants        2023    4   0.677029    1.271376    -1.5     15
# New York Jets          2023    4   0.318004   -1.593256     9.5     14
# Philadelphia Eagles    2023    4   0.476115    1.780194    -8.5     10
# Pittsburgh Steelers    2023    4   0.535045    1.374199    -3.0      7
# San Francisco 49ers    2023    4   0.489679    1.897856   -14.0     12
# Seattle Seahawks       2023    4   0.573170    1.196666     1.5     15
# Tampa Bay Buccaneers   2023    4   0.663566    0.200951     3.0      9
# Tennessee Titans       2023    4   0.468811    0.516219     2.5      6
# Washington Commanders  2023    4   0.447734   -0.488299     8.5     10
#
#                                     opponent
# Team
# Arizona Cardinals        San Francisco 49ers
# Atlanta Falcons         Jacksonville Jaguars
# Baltimore Ravens            Cleveland Browns
# Buffalo Bills                 Miami Dolphins
# Carolina Panthers          Minnesota Vikings
# Chicago Bears                 Denver Broncos
# Cincinnati Bengals          Tennessee Titans
# Cleveland Browns            Baltimore Ravens
# Dallas Cowboys          New England Patriots
# Denver Broncos                 Chicago Bears
# Detroit Lions              Green Bay Packers
# Green Bay Packers              Detroit Lions
# Houston Texans           Pittsburgh Steelers
# Indianapolis Colts          Los Angeles Rams
# Jacksonville Jaguars         Atlanta Falcons
# Kansas City Chiefs             New York Jets
# Las Vegas Raiders       Los Angeles Chargers
# Los Angeles Chargers       Las Vegas Raiders
# Los Angeles Rams          Indianapolis Colts
# Miami Dolphins                 Buffalo Bills
# Minnesota Vikings          Carolina Panthers
# New England Patriots          Dallas Cowboys
# New Orleans Saints      Tampa Bay Buccaneers
# New York Giants             Seattle Seahawks
# New York Jets             Kansas City Chiefs
# Philadelphia Eagles    Washington Commanders
# Pittsburgh Steelers           Houston Texans
# San Francisco 49ers        Arizona Cardinals
# Seattle Seahawks             New York Giants
# Tampa Bay Buccaneers      New Orleans Saints
# Tennessee Titans          Cincinnati Bengals
# Washington Commanders    Philadelphia Eagles

# %%
dfseasonspreads_temp['coverprob_diff'] = dfseasonspreads_temp.apply(lambda row: row['coverprob'] - dfseasonspreads_temp.loc[row['opponent']]['coverprob'],axis=1)
dfseasonspreads_temp['predspread_diff'] = dfseasonspreads_temp.apply(lambda row: row['predspread'] - dfseasonspreads_temp.loc[row['opponent']]['predspread'],axis=1)
dfseasonspreads_temp
# Out:
#                        Year Week  coverprob  predspread  spread  order  \
# Team
# Arizona Cardinals      2023    4   0.427438    0.152778    14.0     12
# Atlanta Falcons        2023    4   0.585272    1.940460     3.0      1
# Baltimore Ravens       2023    4   0.600474    2.072983     2.5      2
# Buffalo Bills          2023    4   0.427438   -1.167447    -3.0      3
# Carolina Panthers      2023    4   0.440893   -0.976324     4.0      4
# Chicago Bears          2023    4   0.533678    1.449535     3.5      5
# Cincinnati Bengals     2023    4   0.545683    1.698044    -2.5      6
# Cleveland Browns       2023    4   0.436227    1.196666    -2.5      2
# Dallas Cowboys         2023    4   0.478687   -1.089760    -6.5     13
# Denver Broncos         2023    4   0.478687    0.591706    -3.5      5
# Detroit Lions          2023    4   0.723461    1.795273    -1.5      0
# Green Bay Packers      2023    4   0.455187    2.678364     1.5      0
# Houston Texans         2023    4   0.429010    1.388710     3.0      7
# Indianapolis Colts     2023    4   0.717541    3.061482    -1.5      8
# Jacksonville Jaguars   2023    4   0.452640   -0.706269    -3.0      1
# Kansas City Chiefs     2023    4   0.412615    1.984837    -9.5     14
# Las Vegas Raiders      2023    4   0.611574    1.051717     5.5     11
# Los Angeles Chargers   2023    4   0.628815    1.335097    -5.5     11
# Los Angeles Rams       2023    4   0.218947   -1.387671     1.5      8
# Miami Dolphins         2023    4   0.424273   -1.683642     3.0      3
# Minnesota Vikings      2023    4   0.533205    0.717429    -4.0      4
# New England Patriots   2023    4   0.585482    0.895977     6.5     13
# New Orleans Saints     2023    4   0.385061    2.201501    -3.0      9
# New York Giants        2023    4   0.677029    1.271376    -1.5     15
# New York Jets          2023    4   0.318004   -1.593256     9.5     14
# Philadelphia Eagles    2023    4   0.476115    1.780194    -8.5     10
# Pittsburgh Steelers    2023    4   0.535045    1.374199    -3.0      7
# San Francisco 49ers    2023    4   0.489679    1.897856   -14.0     12
# Seattle Seahawks       2023    4   0.573170    1.196666     1.5     15
# Tampa Bay Buccaneers   2023    4   0.663566    0.200951     3.0      9
# Tennessee Titans       2023    4   0.468811    0.516219     2.5      6
# Washington Commanders  2023    4   0.447734   -0.488299     8.5     10
#
#                                     opponent  coverprob_diff  predspread_diff
# Team
# Arizona Cardinals        San Francisco 49ers       -0.062241        -1.745077
# Atlanta Falcons         Jacksonville Jaguars        0.132632         2.646730
# Baltimore Ravens            Cleveland Browns        0.164248         0.876317
# Buffalo Bills                 Miami Dolphins        0.003165         0.516195
# Carolina Panthers          Minnesota Vikings       -0.092312        -1.693753
# Chicago Bears                 Denver Broncos        0.054991         0.857830
# Cincinnati Bengals          Tennessee Titans        0.076871         1.181825
# Cleveland Browns            Baltimore Ravens       -0.164248        -0.876317
# Dallas Cowboys          New England Patriots       -0.106796        -1.985737
# Denver Broncos                 Chicago Bears       -0.054991        -0.857830
# Detroit Lions              Green Bay Packers        0.268274        -0.883091
# Green Bay Packers              Detroit Lions       -0.268274         0.883091
# Houston Texans           Pittsburgh Steelers       -0.106035         0.014511
# Indianapolis Colts          Los Angeles Rams        0.498594         4.449153
# Jacksonville Jaguars         Atlanta Falcons       -0.132632        -2.646730
# Kansas City Chiefs             New York Jets        0.094611         3.578092
# Las Vegas Raiders       Los Angeles Chargers       -0.017240        -0.283380
# Los Angeles Chargers       Las Vegas Raiders        0.017240         0.283380
# Los Angeles Rams          Indianapolis Colts       -0.498594        -4.449153
# Miami Dolphins                 Buffalo Bills       -0.003165        -0.516195
# Minnesota Vikings          Carolina Panthers        0.092312         1.693753
# New England Patriots          Dallas Cowboys        0.106796         1.985737
# New Orleans Saints      Tampa Bay Buccaneers       -0.278505         2.000549
# New York Giants             Seattle Seahawks        0.103859         0.074710
# New York Jets             Kansas City Chiefs       -0.094611        -3.578092
# Philadelphia Eagles    Washington Commanders        0.028381         2.268493
# Pittsburgh Steelers           Houston Texans        0.106035        -0.014511
# San Francisco 49ers        Arizona Cardinals        0.062241         1.745077
# Seattle Seahawks             New York Giants       -0.103859        -0.074710
# Tampa Bay Buccaneers      New Orleans Saints        0.278505        -2.000549
# Tennessee Titans          Cincinnati Bengals       -0.076871        -1.181825
# Washington Commanders    Philadelphia Eagles       -0.028381        -2.268493

# %%
pd.concat([dfseasonspreads,dfseasonspreads_temp])
# Out:
#                                     opponent  spread  score  diff  Week  Year  \
# Team
# Washington Commanders      Arizona Cardinals    -7.0    3.0 -34.0     1  2023
# Chicago Bears              Green Bay Packers    -1.5   10.0 -31.0     1  2023
# Arizona Cardinals      Washington Commanders     7.0   28.0  12.0     1  2023
# Denver Broncos             Las Vegas Raiders    -3.0   20.0 -50.0     1  2023
# Tennessee Titans          New Orleans Saints     3.0    3.0 -24.0     1  2023
# ...                                      ...     ...    ...   ...   ...   ...
# San Francisco 49ers        Arizona Cardinals   -14.0    NaN   NaN     4  2023
# Seattle Seahawks             New York Giants     1.5    NaN   NaN     4  2023
# Tampa Bay Buccaneers      New Orleans Saints     3.0    NaN   NaN     4  2023
# Tennessee Titans          Cincinnati Bengals     2.5    NaN   NaN     4  2023
# Washington Commanders    Philadelphia Eagles     8.5    NaN   NaN     4  2023
#
#                        spreadscore  coverprob  predspread  order  \
# Team
# Washington Commanders        -27.5        NaN         NaN    NaN
# Chicago Bears                -18.5        NaN         NaN    NaN
# Arizona Cardinals             24.0        NaN         NaN    NaN
# Denver Broncos               -43.5        NaN         NaN    NaN
# Tennessee Titans             -21.0        NaN         NaN    NaN
# ...                            ...        ...         ...    ...
# San Francisco 49ers            NaN   0.489679    1.897856   12.0
# Seattle Seahawks               NaN   0.573170    1.196666   15.0
# Tampa Bay Buccaneers           NaN   0.663566    0.200951    9.0
# Tennessee Titans               NaN   0.468811    0.516219    6.0
# Washington Commanders          NaN   0.447734   -0.488299   10.0
#
#                       coverprob_diff  predspread_diff
# Team
# Washington Commanders            NaN              NaN
# Chicago Bears                    NaN              NaN
# Arizona Cardinals                NaN              NaN
# Denver Broncos                   NaN              NaN
# Tennessee Titans                 NaN              NaN
# ...                              ...              ...
# San Francisco 49ers         0.062241         1.745077
# Seattle Seahawks           -0.103859        -0.074710
# Tampa Bay Buccaneers        0.278505        -2.000549
# Tennessee Titans           -0.076871        -1.181825
# Washington Commanders      -0.028381        -2.268493
#
# [128 rows x 12 columns]

# %%
dfseasonspreads_new = pd.concat([dfseasonspreads,dfseasonspreads_temp])

dfseasonspreads_new.to_csv('data/Season_spreads.csv')
dfseasonspreads_temp.to_csv(f'data/Season_spreads {nextweekstr}.csv')

# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://non-profit:retire@cluster0.ml8jvfc.mongodb.net/?retryWrites=true&w=majority&appName=AtlasApp"
# Create a new client and connect to the server
client = MongoClient(uri)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
mongo_db = 'withTheSpread'  # Replace with your desired database name
mongo_collection = 'season_spreads'  # Replace with your desired collection name

# Create the database
db = client[mongo_db]
# Create the collection
collection = db[mongo_collection]

# %%
dfseasonspreads.groupby('Week').count()
# Out:
#       Team  opponent  spread  score  diff  Year  spreadscore  coverprob  \
# Week
# 1       32        32      32     32    32    32           32          0
# 2       32        32      32     32    32    32           32         32
# 3       32        32      32     32    32    32           32         32
# 4       32        32      32      0     0    32            0         32
#
#       predspread  order  coverprob_diff  predspread_diff
# Week
# 1              0      0               0                0
# 2             32      0              32                0
# 3             32     32              32               32
# 4             32     32              32               32

# %%
data = dfseasonspreads.to_dict(orient='records')
data
# Out:
# [{'Team': 'Washington Commanders',
#   'Week': 1,
#   'opponent': 'Arizona Cardinals',
#   'spread': -7.0,
#   'score': 20.0,
#   'diff': 4.0,
#   'Year': 2023,
#   'spreadscore': -3.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Chicago Bears',
#   'Week': 1,
#   'opponent': 'Green Bay Packers',
#   'spread': -1.5,
#   'score': 20.0,
#   'diff': -18.0,
#   'Year': 2023,
#   'spreadscore': -19.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Arizona Cardinals',
#   'Week': 1,
#   'opponent': 'Washington Commanders',
#   'spread': 7.0,
#   'score': 16.0,
#   'diff': -4.0,
#   'Year': 2023,
#   'spreadscore': 3.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Denver Broncos',
#   'Week': 1,
#   'opponent': 'Las Vegas Raiders',
#   'spread': -3.0,
#   'score': 16.0,
#   'diff': -1.0,
#   'Year': 2023,
#   'spreadscore': -4.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Tennessee Titans',
#   'Week': 1,
#   'opponent': 'New Orleans Saints',
#   'spread': 3.0,
#   'score': 15.0,
#   'diff': -1.0,
#   'Year': 2023,
#   'spreadscore': 2.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Houston Texans',
#   'Week': 2,
#   'opponent': 'Indianapolis Colts',
#   'spread': -1.0,
#   'score': 20.0,
#   'diff': -11.0,
#   'Year': 2023,
#   'spreadscore': -12.0,
#   'coverprob': 0.3685705,
#   'predspread': -1.0498883,
#   'order': nan,
#   'coverprob_diff': 0.0,
#   'predspread_diff': nan},
#  {'Team': 'Kansas City Chiefs',
#   'Week': 2,
#   'opponent': 'Jacksonville Jaguars',
#   'spread': -3.5,
#   'score': 17.0,
#   'diff': 8.0,
#   'Year': 2023,
#   'spreadscore': 4.5,
#   'coverprob': 0.33910227000000004,
#   'predspread': -7.991736,
#   'order': nan,
#   'coverprob_diff': -0.14993976999999992,
#   'predspread_diff': nan},
#  {'Team': 'New England Patriots',
#   'Week': 3,
#   'opponent': 'New York Jets',
#   'spread': -3.0,
#   'score': 15.0,
#   'diff': 5.0,
#   'Year': 2023,
#   'spreadscore': 2.0,
#   'coverprob': 0.5012972950935364,
#   'predspread': -2.8531808853149414,
#   'order': 8.0,
#   'coverprob_diff': -0.10392338037490845,
#   'predspread_diff': -2.2639294266700745},
#  {'Team': 'Philadelphia Eagles',
#   'Week': 3,
#   'opponent': 'Tampa Bay Buccaneers',
#   'spread': -5.0,
#   'score': 25.0,
#   'diff': 14.0,
#   'Year': 2023,
#   'spreadscore': 9.0,
#   'coverprob': 0.5228101015090942,
#   'predspread': 0.6308770775794983,
#   'order': 14.0,
#   'coverprob_diff': 0.0972675085067749,
#   'predspread_diff': 2.434630811214447},
#  {'Team': 'Baltimore Ravens',
#   'Week': 2,
#   'opponent': 'Cincinnati Bengals',
#   'spread': 3.5,
#   'score': 27.0,
#   'diff': 3.0,
#   'Year': 2023,
#   'spreadscore': 6.5,
#   'coverprob': 0.49946325999999996,
#   'predspread': -4.365124,
#   'order': nan,
#   'coverprob_diff': 0.09399610999999997,
#   'predspread_diff': nan},
#  {'Team': 'Carolina Panthers',
#   'Week': 2,
#   'opponent': 'New Orleans Saints',
#   'spread': 3.0,
#   'score': 17.0,
#   'diff': -3.0,
#   'Year': 2023,
#   'spreadscore': 0.0,
#   'coverprob': 0.4683058,
#   'predspread': 0.2631465,
#   'order': nan,
#   'coverprob_diff': 0.06643995999999996,
#   'predspread_diff': nan},
#  {'Team': 'Chicago Bears',
#   'Week': 2,
#   'opponent': 'Tampa Bay Buccaneers',
#   'spread': 2.5,
#   'score': 17.0,
#   'diff': -10.0,
#   'Year': 2023,
#   'spreadscore': -7.5,
#   'coverprob': 0.40546715,
#   'predspread': -7.5787063,
#   'order': nan,
#   'coverprob_diff': -0.10373768000000005,
#   'predspread_diff': nan},
#  {'Team': 'Detroit Lions',
#   'Week': 2,
#   'opponent': 'Seattle Seahawks',
#   'spread': -4.5,
#   'score': 31.0,
#   'diff': -6.0,
#   'Year': 2023,
#   'spreadscore': -10.5,
#   'coverprob': 0.48904203999999996,
#   'predspread': -4.9223504,
#   'order': nan,
#   'coverprob_diff': 0.053100539999999974,
#   'predspread_diff': nan},
#  {'Team': 'Chicago Bears',
#   'Week': 3,
#   'opponent': 'Kansas City Chiefs',
#   'spread': 12.5,
#   'score': 10.0,
#   'diff': -31.0,
#   'Year': 2023,
#   'spreadscore': -18.5,
#   'coverprob': 0.5070813894271851,
#   'predspread': -7.284313201904297,
#   'order': 12.0,
#   'coverprob_diff': 0.06682705879211426,
#   'predspread_diff': -15.995833396911621},
#  {'Team': 'Las Vegas Raiders',
#   'Week': 3,
#   'opponent': 'Pittsburgh Steelers',
#   'spread': -2.5,
#   'score': 18.0,
#   'diff': -5.0,
#   'Year': 2023,
#   'spreadscore': -7.5,
#   'coverprob': 0.5295687317848206,
#   'predspread': -4.212704181671143,
#   'order': 13.0,
#   'coverprob_diff': 0.11373525857925415,
#   'predspread_diff': -4.305650234222412},
#  {'Team': 'Los Angeles Chargers',
#   'Week': 3,
#   'opponent': 'Minnesota Vikings',
#   'spread': 1.0,
#   'score': 28.0,
#   'diff': 4.0,
#   'Year': 2023,
#   'spreadscore': 5.0,
#   'coverprob': 0.5012972950935364,
#   'predspread': -5.450742244720459,
#   'order': 7.0,
#   'coverprob_diff': -0.06043428182601929,
#   'predspread_diff': -16.4273419380188},
#  {'Team': 'Los Angeles Rams',
#   'Week': 2,
#   'opponent': 'San Francisco 49ers',
#   'spread': 7.5,
#   'score': 23.0,
#   'diff': -7.0,
#   'Year': 2023,
#   'spreadscore': 0.5,
#   'coverprob': 0.54173264,
#   'predspread': -3.2521782,
#   'order': nan,
#   'coverprob_diff': 0.013134210000000035,
#   'predspread_diff': nan},
#  {'Team': 'Cincinnati Bengals',
#   'Week': 3,
#   'opponent': 'Los Angeles Rams',
#   'spread': -1.5,
#   'score': 19.0,
#   'diff': 3.0,
#   'Year': 2023,
#   'spreadscore': 1.5,
#   'coverprob': 0.5070813894271851,
#   'predspread': -1.6331864595413208,
#   'order': 15.0,
#   'coverprob_diff': -0.01572871208190918,
#   'predspread_diff': -0.11476492881774902},
#  {'Team': 'Jacksonville Jaguars',
#   'Week': 3,
#   'opponent': 'Houston Texans',
#   'spread': -9.5,
#   'score': 17.0,
#   'diff': -20.0,
#   'Year': 2023,
#   'spreadscore': -29.5,
#   'coverprob': 0.5685635209083557,
#   'predspread': -0.7248910665512085,
#   'order': 6.0,
#   'coverprob_diff': -0.04758036136627197,
#   'predspread_diff': 3.8069530725479126},
#  {'Team': 'Tampa Bay Buccaneers',
#   'Week': 3,
#   'opponent': 'Philadelphia Eagles',
#   'spread': 5.0,
#   'score': 11.0,
#   'diff': -14.0,
#   'Year': 2023,
#   'spreadscore': -9.0,
#   'coverprob': 0.42554259300231934,
#   'predspread': -1.8037537336349487,
#   'order': 14.0,
#   'coverprob_diff': -0.0972675085067749,
#   'predspread_diff': -2.434630811214447},
#  {'Team': 'Las Vegas Raiders',
#   'Week': 1,
#   'opponent': 'Denver Broncos',
#   'spread': 3.0,
#   'score': 17.0,
#   'diff': 1.0,
#   'Year': 2023,
#   'spreadscore': 4.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Baltimore Ravens',
#   'Week': 1,
#   'opponent': 'Houston Texans',
#   'spread': -9.5,
#   'score': 25.0,
#   'diff': 16.0,
#   'Year': 2023,
#   'spreadscore': 6.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Dallas Cowboys',
#   'Week': 2,
#   'opponent': 'New York Jets',
#   'spread': -10.5,
#   'score': 30.0,
#   'diff': 20.0,
#   'Year': 2023,
#   'spreadscore': 9.5,
#   'coverprob': 0.4830044,
#   'predspread': -1.6593721,
#   'order': nan,
#   'coverprob_diff': -0.04296933999999997,
#   'predspread_diff': nan},
#  {'Team': 'Green Bay Packers',
#   'Week': 2,
#   'opponent': 'Atlanta Falcons',
#   'spread': 3.0,
#   'score': 24.0,
#   'diff': -1.0,
#   'Year': 2023,
#   'spreadscore': 2.0,
#   'coverprob': 0.54173264,
#   'predspread': 2.3815944,
#   'order': nan,
#   'coverprob_diff': 0.025524199999999997,
#   'predspread_diff': nan},
#  {'Team': 'Miami Dolphins',
#   'Week': 2,
#   'opponent': 'New England Patriots',
#   'spread': -1.5,
#   'score': 24.0,
#   'diff': 7.0,
#   'Year': 2023,
#   'spreadscore': 5.5,
#   'coverprob': 0.48904203999999996,
#   'predspread': -5.698251,
#   'order': nan,
#   'coverprob_diff': 0.08717619999999993,
#   'predspread_diff': nan},
#  {'Team': 'Kansas City Chiefs',
#   'Week': 3,
#   'opponent': 'Chicago Bears',
#   'spread': -12.5,
#   'score': 41.0,
#   'diff': 31.0,
#   'Year': 2023,
#   'spreadscore': 18.5,
#   'coverprob': 0.4402543306350708,
#   'predspread': 8.711520195007324,
#   'order': 12.0,
#   'coverprob_diff': -0.06682705879211426,
#   'predspread_diff': 15.995833396911621},
#  {'Team': 'Minnesota Vikings',
#   'Week': 3,
#   'opponent': 'Los Angeles Chargers',
#   'spread': -1.0,
#   'score': 24.0,
#   'diff': -4.0,
#   'Year': 2023,
#   'spreadscore': -5.0,
#   'coverprob': 0.5617315769195557,
#   'predspread': 10.97659969329834,
#   'order': 7.0,
#   'coverprob_diff': 0.06043428182601929,
#   'predspread_diff': 16.4273419380188},
#  {'Team': 'Seattle Seahawks',
#   'Week': 3,
#   'opponent': 'Carolina Panthers',
#   'spread': -6.0,
#   'score': 37.0,
#   'diff': 10.0,
#   'Year': 2023,
#   'spreadscore': 4.0,
#   'coverprob': 0.42554259300231934,
#   'predspread': 7.257826328277588,
#   'order': 10.0,
#   'coverprob_diff': -0.12529683113098145,
#   'predspread_diff': 9.049084305763245},
#  {'Team': 'Atlanta Falcons',
#   'Week': 2,
#   'opponent': 'Green Bay Packers',
#   'spread': -3.0,
#   'score': 25.0,
#   'diff': 1.0,
#   'Year': 2023,
#   'spreadscore': -2.0,
#   'coverprob': 0.51620844,
#   'predspread': -4.5398464,
#   'order': nan,
#   'coverprob_diff': -0.025524199999999997,
#   'predspread_diff': nan},
#  {'Team': 'Jacksonville Jaguars',
#   'Week': 1,
#   'opponent': 'Indianapolis Colts',
#   'spread': -4.5,
#   'score': 31.0,
#   'diff': 10.0,
#   'Year': 2023,
#   'spreadscore': 5.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Los Angeles Rams',
#   'Week': 1,
#   'opponent': 'Seattle Seahawks',
#   'spread': 4.5,
#   'score': 30.0,
#   'diff': 17.0,
#   'Year': 2023,
#   'spreadscore': 21.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Buffalo Bills',
#   'Week': 2,
#   'opponent': 'Las Vegas Raiders',
#   'spread': -7.5,
#   'score': 38.0,
#   'diff': 28.0,
#   'Year': 2023,
#   'spreadscore': 20.5,
#   'coverprob': 0.50058067,
#   'predspread': 2.5626204,
#   'order': nan,
#   'coverprob_diff': 0.011538629999999994,
#   'predspread_diff': nan},
#  {'Team': 'Buffalo Bills',
#   'Week': 3,
#   'opponent': 'Washington Commanders',
#   'spread': -6.5,
#   'score': 37.0,
#   'diff': 34.0,
#   'Year': 2023,
#   'spreadscore': 27.5,
#   'coverprob': 0.4428364038467407,
#   'predspread': -5.53641414642334,
#   'order': 3.0,
#   'coverprob_diff': 0.017293810844421387,
#   'predspread_diff': -2.439154624938965},
#  {'Team': 'New Orleans Saints',
#   'Week': 3,
#   'opponent': 'Green Bay Packers',
#   'spread': 2.0,
#   'score': 17.0,
#   'diff': -1.0,
#   'Year': 2023,
#   'spreadscore': 1.0,
#   'coverprob': 0.5439226031303406,
#   'predspread': 0.01796538755297661,
#   'order': 5.0,
#   'coverprob_diff': 0.012991189956665039,
#   'predspread_diff': -5.757501054555178},
#  {'Team': 'Washington Commanders',
#   'Week': 3,
#   'opponent': 'Buffalo Bills',
#   'spread': 6.5,
#   'score': 3.0,
#   'diff': -34.0,
#   'Year': 2023,
#   'spreadscore': -27.5,
#   'coverprob': 0.42554259300231934,
#   'predspread': -3.097259521484375,
#   'order': 3.0,
#   'coverprob_diff': -0.017293810844421387,
#   'predspread_diff': 2.439154624938965},
#  {'Team': 'Carolina Panthers',
#   'Week': 1,
#   'opponent': 'Atlanta Falcons',
#   'spread': 3.5,
#   'score': 10.0,
#   'diff': -14.0,
#   'Year': 2023,
#   'spreadscore': -10.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Indianapolis Colts',
#   'Week': 1,
#   'opponent': 'Jacksonville Jaguars',
#   'spread': 4.5,
#   'score': 21.0,
#   'diff': -10.0,
#   'Year': 2023,
#   'spreadscore': -5.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Jacksonville Jaguars',
#   'Week': 2,
#   'opponent': 'Kansas City Chiefs',
#   'spread': 3.5,
#   'score': 9.0,
#   'diff': -8.0,
#   'Year': 2023,
#   'spreadscore': -4.5,
#   'coverprob': 0.48904203999999996,
#   'predspread': -1.7138896,
#   'order': nan,
#   'coverprob_diff': 0.14993976999999992,
#   'predspread_diff': nan},
#  {'Team': 'New York Giants',
#   'Week': 2,
#   'opponent': 'Arizona Cardinals',
#   'spread': -4.5,
#   'score': 31.0,
#   'diff': 3.0,
#   'Year': 2023,
#   'spreadscore': -1.5,
#   'coverprob': 0.48722200000000004,
#   'predspread': 0.09895373,
#   'order': nan,
#   'coverprob_diff': 0.013880100000000062,
#   'predspread_diff': nan},
#  {'Team': 'Cleveland Browns',
#   'Week': 3,
#   'opponent': 'Tennessee Titans',
#   'spread': -3.0,
#   'score': 27.0,
#   'diff': 24.0,
#   'Year': 2023,
#   'spreadscore': 21.0,
#   'coverprob': 0.5082466006278992,
#   'predspread': -0.17117337882518768,
#   'order': 9.0,
#   'coverprob_diff': 0.08270400762557983,
#   'predspread_diff': -4.676305577158928},
#  {'Team': 'Pittsburgh Steelers',
#   'Week': 3,
#   'opponent': 'Las Vegas Raiders',
#   'spread': 2.5,
#   'score': 23.0,
#   'diff': 5.0,
#   'Year': 2023,
#   'spreadscore': 7.5,
#   'coverprob': 0.4158334732055664,
#   'predspread': 0.09294605255126953,
#   'order': 13.0,
#   'coverprob_diff': -0.11373525857925415,
#   'predspread_diff': 4.305650234222412},
#  {'Team': 'Cincinnati Bengals',
#   'Week': 1,
#   'opponent': 'Cleveland Browns',
#   'spread': -2.0,
#   'score': 3.0,
#   'diff': -21.0,
#   'Year': 2023,
#   'spreadscore': -23.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Los Angeles Chargers',
#   'Week': 1,
#   'opponent': 'Miami Dolphins',
#   'spread': -3.0,
#   'score': 34.0,
#   'diff': -2.0,
#   'Year': 2023,
#   'spreadscore': -5.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Houston Texans',
#   'Week': 1,
#   'opponent': 'Baltimore Ravens',
#   'spread': 9.5,
#   'score': 9.0,
#   'diff': -16.0,
#   'Year': 2023,
#   'spreadscore': -6.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Miami Dolphins',
#   'Week': 1,
#   'opponent': 'Los Angeles Chargers',
#   'spread': 3.0,
#   'score': 36.0,
#   'diff': 2.0,
#   'Year': 2023,
#   'spreadscore': 5.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Minnesota Vikings',
#   'Week': 1,
#   'opponent': 'Tampa Bay Buccaneers',
#   'spread': -4.5,
#   'score': 17.0,
#   'diff': -3.0,
#   'Year': 2023,
#   'spreadscore': -7.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Carolina Panthers',
#   'Week': 3,
#   'opponent': 'Seattle Seahawks',
#   'spread': 6.0,
#   'score': 27.0,
#   'diff': -10.0,
#   'Year': 2023,
#   'spreadscore': -4.0,
#   'coverprob': 0.5508394241333008,
#   'predspread': -1.7912579774856567,
#   'order': 10.0,
#   'coverprob_diff': 0.12529683113098145,
#   'predspread_diff': -9.049084305763245},
#  {'Team': 'New England Patriots',
#   'Week': 1,
#   'opponent': 'Philadelphia Eagles',
#   'spread': 3.5,
#   'score': 20.0,
#   'diff': -5.0,
#   'Year': 2023,
#   'spreadscore': -1.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Dallas Cowboys',
#   'Week': 3,
#   'opponent': 'Arizona Cardinals',
#   'spread': -12.0,
#   'score': 16.0,
#   'diff': -12.0,
#   'Year': 2023,
#   'spreadscore': -24.0,
#   'coverprob': 0.4293907880783081,
#   'predspread': 7.563697814941406,
#   'order': 11.0,
#   'coverprob_diff': -0.10037946701049805,
#   'predspread_diff': 7.632815442979336},
#  {'Team': 'Green Bay Packers',
#   'Week': 3,
#   'opponent': 'New Orleans Saints',
#   'spread': -2.0,
#   'score': 18.0,
#   'diff': 1.0,
#   'Year': 2023,
#   'spreadscore': -1.0,
#   'coverprob': 0.5309314131736755,
#   'predspread': 5.775466442108154,
#   'order': 5.0,
#   'coverprob_diff': -0.012991189956665039,
#   'predspread_diff': 5.757501054555178},
#  {'Team': 'New York Giants',
#   'Week': 1,
#   'opponent': 'Dallas Cowboys',
#   'spread': 2.5,
#   'score': 0.0,
#   'diff': -40.0,
#   'Year': 2023,
#   'spreadscore': -37.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'San Francisco 49ers',
#   'Week': 1,
#   'opponent': 'Pittsburgh Steelers',
#   'spread': -2.0,
#   'score': 30.0,
#   'diff': 23.0,
#   'Year': 2023,
#   'spreadscore': 21.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Miami Dolphins',
#   'Week': 3,
#   'opponent': 'Denver Broncos',
#   'spread': -6.5,
#   'score': 70.0,
#   'diff': 50.0,
#   'Year': 2023,
#   'spreadscore': 43.5,
#   'coverprob': 0.4158334732055664,
#   'predspread': 1.624570608139038,
#   'order': 4.0,
#   'coverprob_diff': -0.09241312742233276,
#   'predspread_diff': -6.732315301895142},
#  {'Team': 'Minnesota Vikings',
#   'Week': 2,
#   'opponent': 'Philadelphia Eagles',
#   'spread': 5.6,
#   'score': 28.0,
#   'diff': -6.0,
#   'Year': 2023,
#   'spreadscore': -0.40000000000000036,
#   'coverprob': 0.44116074000000005,
#   'predspread': -3.2314384,
#   'order': nan,
#   'coverprob_diff': -0.020097359999999953,
#   'predspread_diff': nan},
#  {'Team': 'Philadelphia Eagles',
#   'Week': 2,
#   'opponent': 'Minnesota Vikings',
#   'spread': -5.5,
#   'score': 34.0,
#   'diff': 6.0,
#   'Year': 2023,
#   'spreadscore': 0.5,
#   'coverprob': 0.4612581,
#   'predspread': -4.5719843,
#   'order': nan,
#   'coverprob_diff': 0.020097359999999953,
#   'predspread_diff': nan},
#  {'Team': 'San Francisco 49ers',
#   'Week': 2,
#   'opponent': 'Los Angeles Rams',
#   'spread': -7.5,
#   'score': 30.0,
#   'diff': 7.0,
#   'Year': 2023,
#   'spreadscore': -0.5,
#   'coverprob': 0.52859843,
#   'predspread': -4.5766325,
#   'order': nan,
#   'coverprob_diff': -0.013134210000000035,
#   'predspread_diff': nan},
#  {'Team': 'Kansas City Chiefs',
#   'Week': 1,
#   'opponent': 'Detroit Lions',
#   'spread': -4.0,
#   'score': 20.0,
#   'diff': -1.0,
#   'Year': 2023,
#   'spreadscore': -5.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Pittsburgh Steelers',
#   'Week': 1,
#   'opponent': 'San Francisco 49ers',
#   'spread': 2.0,
#   'score': 7.0,
#   'diff': -23.0,
#   'Year': 2023,
#   'spreadscore': -21.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Cincinnati Bengals',
#   'Week': 2,
#   'opponent': 'Baltimore Ravens',
#   'spread': -3.5,
#   'score': 24.0,
#   'diff': -3.0,
#   'Year': 2023,
#   'spreadscore': -6.5,
#   'coverprob': 0.40546715,
#   'predspread': -5.688749,
#   'order': nan,
#   'coverprob_diff': -0.09399610999999997,
#   'predspread_diff': nan},
#  {'Team': 'Las Vegas Raiders',
#   'Week': 2,
#   'opponent': 'Buffalo Bills',
#   'spread': 7.5,
#   'score': 10.0,
#   'diff': -28.0,
#   'Year': 2023,
#   'spreadscore': -20.5,
#   'coverprob': 0.48904203999999996,
#   'predspread': -2.2871656,
#   'order': nan,
#   'coverprob_diff': -0.011538629999999994,
#   'predspread_diff': nan},
#  {'Team': 'New England Patriots',
#   'Week': 2,
#   'opponent': 'Miami Dolphins',
#   'spread': 1.5,
#   'score': 17.0,
#   'diff': -7.0,
#   'Year': 2023,
#   'spreadscore': -5.5,
#   'coverprob': 0.40186584000000003,
#   'predspread': 5.371616,
#   'order': nan,
#   'coverprob_diff': -0.08717619999999993,
#   'predspread_diff': nan},
#  {'Team': 'Washington Commanders',
#   'Week': 2,
#   'opponent': 'Denver Broncos',
#   'spread': 3.5,
#   'score': 35.0,
#   'diff': 2.0,
#   'Year': 2023,
#   'spreadscore': 5.5,
#   'coverprob': 0.412288,
#   'predspread': -4.1413984,
#   'order': nan,
#   'coverprob_diff': 0.05026140000000001,
#   'predspread_diff': nan},
#  {'Team': 'Atlanta Falcons',
#   'Week': 3,
#   'opponent': 'Detroit Lions',
#   'spread': 3.0,
#   'score': 6.0,
#   'diff': -14.0,
#   'Year': 2023,
#   'spreadscore': -11.0,
#   'coverprob': 0.5674195885658264,
#   'predspread': 9.257000923156738,
#   'order': 1.0,
#   'coverprob_diff': -0.04872429370880127,
#   'predspread_diff': 8.375475525856018},
#  {'Team': 'Denver Broncos',
#   'Week': 3,
#   'opponent': 'Miami Dolphins',
#   'spread': 6.5,
#   'score': 20.0,
#   'diff': -50.0,
#   'Year': 2023,
#   'spreadscore': -43.5,
#   'coverprob': 0.5082466006278992,
#   'predspread': 8.35688591003418,
#   'order': 4.0,
#   'coverprob_diff': 0.09241312742233276,
#   'predspread_diff': 6.732315301895142},
#  {'Team': 'Detroit Lions',
#   'Week': 1,
#   'opponent': 'Kansas City Chiefs',
#   'spread': 4.0,
#   'score': 21.0,
#   'diff': 1.0,
#   'Year': 2023,
#   'spreadscore': 5.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Cleveland Browns',
#   'Week': 1,
#   'opponent': 'Cincinnati Bengals',
#   'spread': 2.0,
#   'score': 24.0,
#   'diff': 21.0,
#   'Year': 2023,
#   'spreadscore': 23.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Dallas Cowboys',
#   'Week': 1,
#   'opponent': 'New York Giants',
#   'spread': -3.0,
#   'score': 40.0,
#   'diff': 40.0,
#   'Year': 2023,
#   'spreadscore': 37.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Buffalo Bills',
#   'Week': 1,
#   'opponent': 'New York Jets',
#   'spread': -2.5,
#   'score': 16.0,
#   'diff': -6.0,
#   'Year': 2023,
#   'spreadscore': -8.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Philadelphia Eagles',
#   'Week': 1,
#   'opponent': 'New England Patriots',
#   'spread': -3.5,
#   'score': 25.0,
#   'diff': 5.0,
#   'Year': 2023,
#   'spreadscore': 1.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Seattle Seahawks',
#   'Week': 1,
#   'opponent': 'Los Angeles Rams',
#   'spread': -4.5,
#   'score': 13.0,
#   'diff': -17.0,
#   'Year': 2023,
#   'spreadscore': -21.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Tennessee Titans',
#   'Week': 2,
#   'opponent': 'Los Angeles Chargers',
#   'spread': 2.5,
#   'score': 27.0,
#   'diff': 3.0,
#   'Year': 2023,
#   'spreadscore': 5.5,
#   'coverprob': 0.45447230000000005,
#   'predspread': -6.5363617,
#   'order': nan,
#   'coverprob_diff': 0.11537003000000001,
#   'predspread_diff': nan},
#  {'Team': 'New York Jets',
#   'Week': 3,
#   'opponent': 'New England Patriots',
#   'spread': 3.0,
#   'score': 10.0,
#   'diff': -5.0,
#   'Year': 2023,
#   'spreadscore': -2.0,
#   'coverprob': 0.6052206754684448,
#   'predspread': -0.5892514586448669,
#   'order': 8.0,
#   'coverprob_diff': 0.10392338037490845,
#   'predspread_diff': 2.2639294266700745},
#  {'Team': 'Denver Broncos',
#   'Week': 2,
#   'opponent': 'Washington Commanders',
#   'spread': -3.5,
#   'score': 33.0,
#   'diff': -2.0,
#   'Year': 2023,
#   'spreadscore': -5.5,
#   'coverprob': 0.3620266,
#   'predspread': 5.8627305,
#   'order': nan,
#   'coverprob_diff': -0.05026140000000001,
#   'predspread_diff': nan},
#  {'Team': 'Arizona Cardinals',
#   'Week': 3,
#   'opponent': 'Dallas Cowboys',
#   'spread': 12.0,
#   'score': 28.0,
#   'diff': 12.0,
#   'Year': 2023,
#   'spreadscore': 24.0,
#   'coverprob': 0.5297702550888062,
#   'predspread': -0.06911762803792953,
#   'order': 11.0,
#   'coverprob_diff': 0.10037946701049805,
#   'predspread_diff': -7.632815442979336},
#  {'Team': 'Los Angeles Rams',
#   'Week': 3,
#   'opponent': 'Cincinnati Bengals',
#   'spread': 1.5,
#   'score': 16.0,
#   'diff': -3.0,
#   'Year': 2023,
#   'spreadscore': -1.5,
#   'coverprob': 0.5228101015090942,
#   'predspread': -1.5184215307235718,
#   'order': 15.0,
#   'coverprob_diff': 0.01572871208190918,
#   'predspread_diff': 0.11476492881774902},
#  {'Team': 'Green Bay Packers',
#   'Week': 1,
#   'opponent': 'Chicago Bears',
#   'spread': 1.5,
#   'score': 38.0,
#   'diff': 18.0,
#   'Year': 2023,
#   'spreadscore': 19.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'New York Jets',
#   'Week': 1,
#   'opponent': 'Buffalo Bills',
#   'spread': 3.0,
#   'score': 22.0,
#   'diff': 6.0,
#   'Year': 2023,
#   'spreadscore': 9.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Tampa Bay Buccaneers',
#   'Week': 1,
#   'opponent': 'Minnesota Vikings',
#   'spread': 4.5,
#   'score': 20.0,
#   'diff': 3.0,
#   'Year': 2023,
#   'spreadscore': 7.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Indianapolis Colts',
#   'Week': 2,
#   'opponent': 'Houston Texans',
#   'spread': 1.0,
#   'score': 31.0,
#   'diff': 11.0,
#   'Year': 2023,
#   'spreadscore': 12.0,
#   'coverprob': 0.3685705,
#   'predspread': -3.1246805,
#   'order': nan,
#   'coverprob_diff': 0.0,
#   'predspread_diff': nan},
#  {'Team': 'New York Jets',
#   'Week': 2,
#   'opponent': 'Dallas Cowboys',
#   'spread': 8.5,
#   'score': 10.0,
#   'diff': -20.0,
#   'Year': 2023,
#   'spreadscore': -11.5,
#   'coverprob': 0.52597374,
#   'predspread': -7.41571,
#   'order': nan,
#   'coverprob_diff': 0.04296933999999997,
#   'predspread_diff': nan},
#  {'Team': 'Seattle Seahawks',
#   'Week': 2,
#   'opponent': 'Detroit Lions',
#   'spread': 4.5,
#   'score': 37.0,
#   'diff': 6.0,
#   'Year': 2023,
#   'spreadscore': 10.5,
#   'coverprob': 0.4359415,
#   'predspread': 2.564864,
#   'order': nan,
#   'coverprob_diff': -0.053100539999999974,
#   'predspread_diff': nan},
#  {'Team': 'San Francisco 49ers',
#   'Week': 3,
#   'opponent': 'New York Giants',
#   'spread': -10.0,
#   'score': 30.0,
#   'diff': 18.0,
#   'Year': 2023,
#   'spreadscore': 8.0,
#   'coverprob': 0.5533764362335205,
#   'predspread': -6.308135032653809,
#   'order': 0.0,
#   'coverprob_diff': -0.008355140686035156,
#   'predspread_diff': -12.357222080230713},
#  {'Team': 'New Orleans Saints',
#   'Week': 1,
#   'opponent': 'Tennessee Titans',
#   'spread': -3.0,
#   'score': 16.0,
#   'diff': 1.0,
#   'Year': 2023,
#   'spreadscore': -2.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Pittsburgh Steelers',
#   'Week': 2,
#   'opponent': 'Cleveland Browns',
#   'spread': 2.5,
#   'score': 26.0,
#   'diff': 4.0,
#   'Year': 2023,
#   'spreadscore': 6.5,
#   'coverprob': 0.4359415,
#   'predspread': -4.873276,
#   'order': nan,
#   'coverprob_diff': -0.10579114,
#   'predspread_diff': nan},
#  {'Team': 'Detroit Lions',
#   'Week': 3,
#   'opponent': 'Atlanta Falcons',
#   'spread': -3.0,
#   'score': 20.0,
#   'diff': 14.0,
#   'Year': 2023,
#   'spreadscore': 11.0,
#   'coverprob': 0.6161438822746277,
#   'predspread': 0.8815253973007202,
#   'order': 1.0,
#   'coverprob_diff': 0.04872429370880127,
#   'predspread_diff': -8.375475525856018},
#  {'Team': 'Indianapolis Colts',
#   'Week': 3,
#   'opponent': 'Baltimore Ravens',
#   'spread': 7.5,
#   'score': 22.0,
#   'diff': 3.0,
#   'Year': 2023,
#   'spreadscore': 10.5,
#   'coverprob': 0.4382648468017578,
#   'predspread': 0.8230835199356079,
#   'order': 2.0,
#   'coverprob_diff': 0.025605320930480957,
#   'predspread_diff': 1.472813367843628},
#  {'Team': 'Atlanta Falcons',
#   'Week': 1,
#   'opponent': 'Carolina Panthers',
#   'spread': -3.5,
#   'score': 24.0,
#   'diff': 14.0,
#   'Year': 2023,
#   'spreadscore': 10.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Arizona Cardinals',
#   'Week': 2,
#   'opponent': 'New York Giants',
#   'spread': 4.5,
#   'score': 28.0,
#   'diff': -3.0,
#   'Year': 2023,
#   'spreadscore': 1.5,
#   'coverprob': 0.4733419,
#   'predspread': 0.14908272,
#   'order': nan,
#   'coverprob_diff': -0.013880100000000062,
#   'predspread_diff': nan},
#  {'Team': 'Los Angeles Chargers',
#   'Week': 2,
#   'opponent': 'Tennessee Titans',
#   'spread': -2.5,
#   'score': 24.0,
#   'diff': -3.0,
#   'Year': 2023,
#   'spreadscore': -5.5,
#   'coverprob': 0.33910227000000004,
#   'predspread': -5.080024,
#   'order': nan,
#   'coverprob_diff': -0.11537003000000001,
#   'predspread_diff': nan},
#  {'Team': 'New Orleans Saints',
#   'Week': 2,
#   'opponent': 'Carolina Panthers',
#   'spread': -3.0,
#   'score': 20.0,
#   'diff': 3.0,
#   'Year': 2023,
#   'spreadscore': 0.0,
#   'coverprob': 0.40186584000000003,
#   'predspread': -4.929265,
#   'order': nan,
#   'coverprob_diff': -0.06643995999999996,
#   'predspread_diff': nan},
#  {'Team': 'Tampa Bay Buccaneers',
#   'Week': 2,
#   'opponent': 'Chicago Bears',
#   'spread': -2.5,
#   'score': 27.0,
#   'diff': 10.0,
#   'Year': 2023,
#   'spreadscore': 7.5,
#   'coverprob': 0.50920483,
#   'predspread': 7.881182,
#   'order': nan,
#   'coverprob_diff': 0.10373768000000005,
#   'predspread_diff': nan},
#  {'Team': 'Houston Texans',
#   'Week': 3,
#   'opponent': 'Jacksonville Jaguars',
#   'spread': 9.5,
#   'score': 37.0,
#   'diff': 20.0,
#   'Year': 2023,
#   'spreadscore': 29.5,
#   'coverprob': 0.6161438822746277,
#   'predspread': -4.531844139099121,
#   'order': 6.0,
#   'coverprob_diff': 0.04758036136627197,
#   'predspread_diff': -3.8069530725479126},
#  {'Team': 'Cleveland Browns',
#   'Week': 2,
#   'opponent': 'Pittsburgh Steelers',
#   'spread': -2.5,
#   'score': 22.0,
#   'diff': -4.0,
#   'Year': 2023,
#   'spreadscore': -6.5,
#   'coverprob': 0.54173264,
#   'predspread': 2.221873,
#   'order': nan,
#   'coverprob_diff': 0.10579114,
#   'predspread_diff': nan},
#  {'Team': 'Baltimore Ravens',
#   'Week': 3,
#   'opponent': 'Indianapolis Colts',
#   'spread': -7.5,
#   'score': 19.0,
#   'diff': -3.0,
#   'Year': 2023,
#   'spreadscore': -10.5,
#   'coverprob': 0.41265952587127686,
#   'predspread': -0.64972984790802,
#   'order': 2.0,
#   'coverprob_diff': -0.025605320930480957,
#   'predspread_diff': -1.472813367843628},
#  {'Team': 'New York Giants',
#   'Week': 3,
#   'opponent': 'San Francisco 49ers',
#   'spread': 10.0,
#   'score': 12.0,
#   'diff': -18.0,
#   'Year': 2023,
#   'spreadscore': -8.0,
#   'coverprob': 0.5617315769195557,
#   'predspread': 6.049087047576904,
#   'order': 0.0,
#   'coverprob_diff': 0.008355140686035156,
#   'predspread_diff': 12.357222080230713},
#  {'Team': 'Tennessee Titans',
#   'Week': 3,
#   'opponent': 'Cleveland Browns',
#   'spread': 3.0,
#   'score': 3.0,
#   'diff': -24.0,
#   'Year': 2023,
#   'spreadscore': -21.0,
#   'coverprob': 0.42554259300231934,
#   'predspread': 4.50513219833374,
#   'order': 9.0,
#   'coverprob_diff': -0.08270400762557983,
#   'predspread_diff': 4.676305577158928},
#  {'Team': 'Arizona Cardinals',
#   'Week': 4,
#   'opponent': 'San Francisco 49ers',
#   'spread': 14.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.42743828892707825,
#   'predspread': 0.1527784913778305,
#   'order': 12.0,
#   'coverprob_diff': -0.062240660190582275,
#   'predspread_diff': -1.7450771480798721},
#  {'Team': 'Atlanta Falcons',
#   'Week': 4,
#   'opponent': 'Jacksonville Jaguars',
#   'spread': 3.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5852723717689514,
#   'predspread': 1.940460443496704,
#   'order': 1.0,
#   'coverprob_diff': 0.13263195753097534,
#   'predspread_diff': 2.6467296481132507},
#  {'Team': 'Baltimore Ravens',
#   'Week': 4,
#   'opponent': 'Cleveland Browns',
#   'spread': 2.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6004742383956909,
#   'predspread': 2.0729827880859375,
#   'order': 2.0,
#   'coverprob_diff': 0.1642475724220276,
#   'predspread_diff': 0.8763167858123779},
#  {'Team': 'Buffalo Bills',
#   'Week': 4,
#   'opponent': 'Miami Dolphins',
#   'spread': -3.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.42743828892707825,
#   'predspread': -1.1674468517303467,
#   'order': 3.0,
#   'coverprob_diff': 0.0031648874282836914,
#   'predspread_diff': 0.5161949396133423},
#  {'Team': 'Carolina Panthers',
#   'Week': 4,
#   'opponent': 'Minnesota Vikings',
#   'spread': 4.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4408930838108063,
#   'predspread': -0.9763240814208984,
#   'order': 4.0,
#   'coverprob_diff': -0.09231188893318176,
#   'predspread_diff': -1.6937532424926758},
#  {'Team': 'Chicago Bears',
#   'Week': 4,
#   'opponent': 'Denver Broncos',
#   'spread': 3.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5336779356002808,
#   'predspread': 1.4495354890823364,
#   'order': 5.0,
#   'coverprob_diff': 0.05499139428138733,
#   'predspread_diff': 0.8578299880027771},
#  {'Team': 'Cincinnati Bengals',
#   'Week': 4,
#   'opponent': 'Tennessee Titans',
#   'spread': -2.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5456827878952026,
#   'predspread': 1.698043704032898,
#   'order': 6.0,
#   'coverprob_diff': 0.0768713653087616,
#   'predspread_diff': 1.1818246245384216},
#  {'Team': 'Cleveland Browns',
#   'Week': 4,
#   'opponent': 'Baltimore Ravens',
#   'spread': -2.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.43622666597366333,
#   'predspread': 1.1966660022735596,
#   'order': 2.0,
#   'coverprob_diff': -0.1642475724220276,
#   'predspread_diff': -0.8763167858123779},
#  {'Team': 'Dallas Cowboys',
#   'Week': 4,
#   'opponent': 'New England Patriots',
#   'spread': -6.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.47868654131889343,
#   'predspread': -1.0897595882415771,
#   'order': 13.0,
#   'coverprob_diff': -0.10679551959037781,
#   'predspread_diff': -1.9857370257377625},
#  {'Team': 'Denver Broncos',
#   'Week': 4,
#   'opponent': 'Chicago Bears',
#   'spread': -3.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.47868654131889343,
#   'predspread': 0.5917055010795593,
#   'order': 5.0,
#   'coverprob_diff': -0.05499139428138733,
#   'predspread_diff': -0.8578299880027771},
#  {'Team': 'Detroit Lions',
#   'Week': 4,
#   'opponent': 'Green Bay Packers',
#   'spread': -1.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.7234614491462708,
#   'predspread': 1.7952731847763062,
#   'order': 0.0,
#   'coverprob_diff': 0.2682742774486542,
#   'predspread_diff': -0.8830910921096802},
#  {'Team': 'Green Bay Packers',
#   'Week': 4,
#   'opponent': 'Detroit Lions',
#   'spread': 1.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4551871716976166,
#   'predspread': 2.6783642768859863,
#   'order': 0.0,
#   'coverprob_diff': -0.2682742774486542,
#   'predspread_diff': 0.8830910921096802},
#  {'Team': 'Houston Texans',
#   'Week': 4,
#   'opponent': 'Pittsburgh Steelers',
#   'spread': 3.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4290100336074829,
#   'predspread': 1.3887099027633667,
#   'order': 7.0,
#   'coverprob_diff': -0.10603493452072144,
#   'predspread_diff': 0.014510631561279297},
#  {'Team': 'Indianapolis Colts',
#   'Week': 4,
#   'opponent': 'Los Angeles Rams',
#   'spread': -1.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.7175409197807312,
#   'predspread': 3.0614824295043945,
#   'order': 8.0,
#   'coverprob_diff': 0.49859440326690674,
#   'predspread_diff': 4.449153304100037},
#  {'Team': 'Jacksonville Jaguars',
#   'Week': 4,
#   'opponent': 'Atlanta Falcons',
#   'spread': -3.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4526404142379761,
#   'predspread': -0.7062692046165466,
#   'order': 1.0,
#   'coverprob_diff': -0.13263195753097534,
#   'predspread_diff': -2.6467296481132507},
#  {'Team': 'Kansas City Chiefs',
#   'Week': 4,
#   'opponent': 'New York Jets',
#   'spread': -9.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.41261523962020874,
#   'predspread': 1.9848369359970093,
#   'order': 14.0,
#   'coverprob_diff': 0.094611257314682,
#   'predspread_diff': 3.5780924558639526},
#  {'Team': 'Las Vegas Raiders',
#   'Week': 4,
#   'opponent': 'Los Angeles Chargers',
#   'spread': 5.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6115743517875671,
#   'predspread': 1.0517170429229736,
#   'order': 11.0,
#   'coverprob_diff': -0.017240405082702637,
#   'predspread_diff': -0.2833799123764038},
#  {'Team': 'Los Angeles Chargers',
#   'Week': 4,
#   'opponent': 'Las Vegas Raiders',
#   'spread': -5.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6288147568702698,
#   'predspread': 1.3350969552993774,
#   'order': 11.0,
#   'coverprob_diff': 0.017240405082702637,
#   'predspread_diff': 0.2833799123764038},
#  {'Team': 'Los Angeles Rams',
#   'Week': 4,
#   'opponent': 'Indianapolis Colts',
#   'spread': 1.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.21894651651382446,
#   'predspread': -1.387670874595642,
#   'order': 8.0,
#   'coverprob_diff': -0.49859440326690674,
#   'predspread_diff': -4.449153304100037},
#  {'Team': 'Miami Dolphins',
#   'Week': 4,
#   'opponent': 'Buffalo Bills',
#   'spread': 3.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.42427340149879456,
#   'predspread': -1.683641791343689,
#   'order': 3.0,
#   'coverprob_diff': -0.0031648874282836914,
#   'predspread_diff': -0.5161949396133423},
#  {'Team': 'Minnesota Vikings',
#   'Week': 4,
#   'opponent': 'Carolina Panthers',
#   'spread': -4.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.533204972743988,
#   'predspread': 0.7174291610717773,
#   'order': 4.0,
#   'coverprob_diff': 0.09231188893318176,
#   'predspread_diff': 1.6937532424926758},
#  {'Team': 'New England Patriots',
#   'Week': 4,
#   'opponent': 'Dallas Cowboys',
#   'spread': 6.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5854820609092712,
#   'predspread': 0.8959774374961853,
#   'order': 13.0,
#   'coverprob_diff': 0.10679551959037781,
#   'predspread_diff': 1.9857370257377625},
#  {'Team': 'New Orleans Saints',
#   'Week': 4,
#   'opponent': 'Tampa Bay Buccaneers',
#   'spread': -3.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.38506144285202026,
#   'predspread': 2.20150089263916,
#   'order': 9.0,
#   'coverprob_diff': -0.27850502729415894,
#   'predspread_diff': 2.0005494952201843},
#  {'Team': 'New York Giants',
#   'Week': 4,
#   'opponent': 'Seattle Seahawks',
#   'spread': -1.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6770291924476624,
#   'predspread': 1.2713764905929565,
#   'order': 15.0,
#   'coverprob_diff': 0.1038593053817749,
#   'predspread_diff': 0.07471048831939697},
#  {'Team': 'New York Jets',
#   'Week': 4,
#   'opponent': 'Kansas City Chiefs',
#   'spread': 9.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.31800398230552673,
#   'predspread': -1.5932555198669434,
#   'order': 14.0,
#   'coverprob_diff': -0.094611257314682,
#   'predspread_diff': -3.5780924558639526},
#  {'Team': 'Philadelphia Eagles',
#   'Week': 4,
#   'opponent': 'Washington Commanders',
#   'spread': -8.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.47611546516418457,
#   'predspread': 1.7801939249038696,
#   'order': 10.0,
#   'coverprob_diff': 0.028380990028381348,
#   'predspread_diff': 2.268492817878723},
#  {'Team': 'Pittsburgh Steelers',
#   'Week': 4,
#   'opponent': 'Houston Texans',
#   'spread': -3.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5350449681282043,
#   'predspread': 1.3741992712020874,
#   'order': 7.0,
#   'coverprob_diff': 0.10603493452072144,
#   'predspread_diff': -0.014510631561279297},
#  {'Team': 'San Francisco 49ers',
#   'Week': 4,
#   'opponent': 'Arizona Cardinals',
#   'spread': -14.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4896789491176605,
#   'predspread': 1.8978556394577026,
#   'order': 12.0,
#   'coverprob_diff': 0.062240660190582275,
#   'predspread_diff': 1.7450771480798721},
#  {'Team': 'Seattle Seahawks',
#   'Week': 4,
#   'opponent': 'New York Giants',
#   'spread': 1.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5731698870658875,
#   'predspread': 1.1966660022735596,
#   'order': 15.0,
#   'coverprob_diff': -0.1038593053817749,
#   'predspread_diff': -0.07471048831939697},
#  {'Team': 'Tampa Bay Buccaneers',
#   'Week': 4,
#   'opponent': 'New Orleans Saints',
#   'spread': 3.0,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6635664701461792,
#   'predspread': 0.20095139741897583,
#   'order': 9.0,
#   'coverprob_diff': 0.27850502729415894,
#   'predspread_diff': -2.0005494952201843},
#  {'Team': 'Tennessee Titans',
#   'Week': 4,
#   'opponent': 'Cincinnati Bengals',
#   'spread': 2.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.46881142258644104,
#   'predspread': 0.5162190794944763,
#   'order': 6.0,
#   'coverprob_diff': -0.0768713653087616,
#   'predspread_diff': -1.1818246245384216},
#  {'Team': 'Washington Commanders',
#   'Week': 4,
#   'opponent': 'Philadelphia Eagles',
#   'spread': 8.5,
#   'score': nan,
#   'diff': nan,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4477344751358032,
#   'predspread': -0.4882988929748535,
#   'order': 10.0,
#   'coverprob_diff': -0.028380990028381348,
#   'predspread_diff': -2.268492817878723}]

# %%
# Convert the DataFrame to a list of dictionaries (one dictionary per row)
data = dfseasonspreads_new.reset_index().rename(columns={'index':'Team'}).to_dict(orient='records')
# inspect data
data
# Out:
# [{'Team': 'Washington Commanders',
#   'opponent': 'Arizona Cardinals',
#   'spread': -7.0,
#   'score': 3.0,
#   'diff': -34.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -27.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Chicago Bears',
#   'opponent': 'Green Bay Packers',
#   'spread': -1.5,
#   'score': 10.0,
#   'diff': -31.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -18.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Arizona Cardinals',
#   'opponent': 'Washington Commanders',
#   'spread': 7.0,
#   'score': 28.0,
#   'diff': 12.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 24.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Denver Broncos',
#   'opponent': 'Las Vegas Raiders',
#   'spread': -3.0,
#   'score': 20.0,
#   'diff': -50.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -43.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Tennessee Titans',
#   'opponent': 'New Orleans Saints',
#   'spread': 3.0,
#   'score': 3.0,
#   'diff': -24.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -21.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Houston Texans',
#   'opponent': 'Indianapolis Colts',
#   'spread': -1.0,
#   'score': 37.0,
#   'diff': 20.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 29.5,
#   'coverprob': 0.3685705,
#   'predspread': -1.0498883,
#   'order': nan,
#   'coverprob_diff': 0.0,
#   'predspread_diff': nan},
#  {'Team': 'Kansas City Chiefs',
#   'opponent': 'Jacksonville Jaguars',
#   'spread': -3.5,
#   'score': 41.0,
#   'diff': 31.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 18.5,
#   'coverprob': 0.33910227000000004,
#   'predspread': -7.991736,
#   'order': nan,
#   'coverprob_diff': -0.14993976999999992,
#   'predspread_diff': nan},
#  {'Team': 'New England Patriots',
#   'opponent': 'New York Jets',
#   'spread': -3.0,
#   'score': 15.0,
#   'diff': 5.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 2.0,
#   'coverprob': 0.5012972950935364,
#   'predspread': -2.8531808853149414,
#   'order': 8.0,
#   'coverprob_diff': -0.10392338037490845,
#   'predspread_diff': -2.2639294266700745},
#  {'Team': 'Philadelphia Eagles',
#   'opponent': 'Tampa Bay Buccaneers',
#   'spread': -5.0,
#   'score': 25.0,
#   'diff': 14.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 9.0,
#   'coverprob': 0.5228101015090942,
#   'predspread': 0.6308770775794983,
#   'order': 14.0,
#   'coverprob_diff': 0.0972675085067749,
#   'predspread_diff': 2.434630811214447},
#  {'Team': 'Baltimore Ravens',
#   'opponent': 'Cincinnati Bengals',
#   'spread': 3.5,
#   'score': 19.0,
#   'diff': -3.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -10.5,
#   'coverprob': 0.49946325999999996,
#   'predspread': -4.365124,
#   'order': nan,
#   'coverprob_diff': 0.09399610999999997,
#   'predspread_diff': nan},
#  {'Team': 'Carolina Panthers',
#   'opponent': 'New Orleans Saints',
#   'spread': 3.0,
#   'score': 27.0,
#   'diff': -10.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -4.0,
#   'coverprob': 0.4683058,
#   'predspread': 0.2631465,
#   'order': nan,
#   'coverprob_diff': 0.06643995999999996,
#   'predspread_diff': nan},
#  {'Team': 'Chicago Bears',
#   'opponent': 'Tampa Bay Buccaneers',
#   'spread': 2.5,
#   'score': 10.0,
#   'diff': -31.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -18.5,
#   'coverprob': 0.40546715,
#   'predspread': -7.5787063,
#   'order': nan,
#   'coverprob_diff': -0.10373768000000005,
#   'predspread_diff': nan},
#  {'Team': 'Detroit Lions',
#   'opponent': 'Seattle Seahawks',
#   'spread': -4.5,
#   'score': 20.0,
#   'diff': 14.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 11.0,
#   'coverprob': 0.48904203999999996,
#   'predspread': -4.9223504,
#   'order': nan,
#   'coverprob_diff': 0.053100539999999974,
#   'predspread_diff': nan},
#  {'Team': 'Chicago Bears',
#   'opponent': 'Kansas City Chiefs',
#   'spread': 12.5,
#   'score': 10.0,
#   'diff': -31.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -18.5,
#   'coverprob': 0.5070813894271851,
#   'predspread': -7.284313201904297,
#   'order': 12.0,
#   'coverprob_diff': 0.06682705879211426,
#   'predspread_diff': -15.995833396911621},
#  {'Team': 'Las Vegas Raiders',
#   'opponent': 'Pittsburgh Steelers',
#   'spread': -2.5,
#   'score': 18.0,
#   'diff': -5.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -7.5,
#   'coverprob': 0.5295687317848206,
#   'predspread': -4.212704181671143,
#   'order': 13.0,
#   'coverprob_diff': 0.11373525857925415,
#   'predspread_diff': -4.305650234222412},
#  {'Team': 'Los Angeles Chargers',
#   'opponent': 'Minnesota Vikings',
#   'spread': 1.0,
#   'score': 28.0,
#   'diff': 4.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 5.0,
#   'coverprob': 0.5012972950935364,
#   'predspread': -5.450742244720459,
#   'order': 7.0,
#   'coverprob_diff': -0.06043428182601929,
#   'predspread_diff': -16.4273419380188},
#  {'Team': 'Los Angeles Rams',
#   'opponent': 'San Francisco 49ers',
#   'spread': 7.5,
#   'score': 16.0,
#   'diff': -3.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -1.5,
#   'coverprob': 0.54173264,
#   'predspread': -3.2521782,
#   'order': nan,
#   'coverprob_diff': 0.013134210000000035,
#   'predspread_diff': nan},
#  {'Team': 'Cincinnati Bengals',
#   'opponent': 'Los Angeles Rams',
#   'spread': -1.5,
#   'score': 19.0,
#   'diff': 3.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 1.5,
#   'coverprob': 0.5070813894271851,
#   'predspread': -1.6331864595413208,
#   'order': 15.0,
#   'coverprob_diff': -0.01572871208190918,
#   'predspread_diff': -0.11476492881774902},
#  {'Team': 'Jacksonville Jaguars',
#   'opponent': 'Houston Texans',
#   'spread': -9.5,
#   'score': 17.0,
#   'diff': -20.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -29.5,
#   'coverprob': 0.5685635209083557,
#   'predspread': -0.7248910665512085,
#   'order': 6.0,
#   'coverprob_diff': -0.04758036136627197,
#   'predspread_diff': 3.8069530725479126},
#  {'Team': 'Tampa Bay Buccaneers',
#   'opponent': 'Philadelphia Eagles',
#   'spread': 5.0,
#   'score': 11.0,
#   'diff': -14.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -9.0,
#   'coverprob': 0.42554259300231934,
#   'predspread': -1.8037537336349487,
#   'order': 14.0,
#   'coverprob_diff': -0.0972675085067749,
#   'predspread_diff': -2.434630811214447},
#  {'Team': 'Las Vegas Raiders',
#   'opponent': 'Denver Broncos',
#   'spread': 3.0,
#   'score': 18.0,
#   'diff': -5.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -7.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Baltimore Ravens',
#   'opponent': 'Houston Texans',
#   'spread': -9.5,
#   'score': 19.0,
#   'diff': -3.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -10.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Dallas Cowboys',
#   'opponent': 'New York Jets',
#   'spread': -10.5,
#   'score': 16.0,
#   'diff': -12.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -24.0,
#   'coverprob': 0.4830044,
#   'predspread': -1.6593721,
#   'order': nan,
#   'coverprob_diff': -0.04296933999999997,
#   'predspread_diff': nan},
#  {'Team': 'Green Bay Packers',
#   'opponent': 'Atlanta Falcons',
#   'spread': 3.0,
#   'score': 18.0,
#   'diff': 1.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -1.0,
#   'coverprob': 0.54173264,
#   'predspread': 2.3815944,
#   'order': nan,
#   'coverprob_diff': 0.025524199999999997,
#   'predspread_diff': nan},
#  {'Team': 'Miami Dolphins',
#   'opponent': 'New England Patriots',
#   'spread': -1.5,
#   'score': 70.0,
#   'diff': 50.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 43.5,
#   'coverprob': 0.48904203999999996,
#   'predspread': -5.698251,
#   'order': nan,
#   'coverprob_diff': 0.08717619999999993,
#   'predspread_diff': nan},
#  {'Team': 'Kansas City Chiefs',
#   'opponent': 'Chicago Bears',
#   'spread': -12.5,
#   'score': 41.0,
#   'diff': 31.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 18.5,
#   'coverprob': 0.4402543306350708,
#   'predspread': 8.711520195007324,
#   'order': 12.0,
#   'coverprob_diff': -0.06682705879211426,
#   'predspread_diff': 15.995833396911621},
#  {'Team': 'Minnesota Vikings',
#   'opponent': 'Los Angeles Chargers',
#   'spread': -1.0,
#   'score': 24.0,
#   'diff': -4.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -5.0,
#   'coverprob': 0.5617315769195557,
#   'predspread': 10.97659969329834,
#   'order': 7.0,
#   'coverprob_diff': 0.06043428182601929,
#   'predspread_diff': 16.4273419380188},
#  {'Team': 'Seattle Seahawks',
#   'opponent': 'Carolina Panthers',
#   'spread': -6.0,
#   'score': 37.0,
#   'diff': 10.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 4.0,
#   'coverprob': 0.42554259300231934,
#   'predspread': 7.257826328277588,
#   'order': 10.0,
#   'coverprob_diff': -0.12529683113098145,
#   'predspread_diff': 9.049084305763245},
#  {'Team': 'Atlanta Falcons',
#   'opponent': 'Green Bay Packers',
#   'spread': -3.0,
#   'score': 6.0,
#   'diff': -14.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -11.0,
#   'coverprob': 0.51620844,
#   'predspread': -4.5398464,
#   'order': nan,
#   'coverprob_diff': -0.025524199999999997,
#   'predspread_diff': nan},
#  {'Team': 'Jacksonville Jaguars',
#   'opponent': 'Indianapolis Colts',
#   'spread': -4.5,
#   'score': 17.0,
#   'diff': -20.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -29.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Los Angeles Rams',
#   'opponent': 'Seattle Seahawks',
#   'spread': 4.5,
#   'score': 16.0,
#   'diff': -3.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -1.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Buffalo Bills',
#   'opponent': 'Las Vegas Raiders',
#   'spread': -7.5,
#   'score': 37.0,
#   'diff': 34.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 27.5,
#   'coverprob': 0.50058067,
#   'predspread': 2.5626204,
#   'order': nan,
#   'coverprob_diff': 0.011538629999999994,
#   'predspread_diff': nan},
#  {'Team': 'Buffalo Bills',
#   'opponent': 'Washington Commanders',
#   'spread': -6.5,
#   'score': 37.0,
#   'diff': 34.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 27.5,
#   'coverprob': 0.4428364038467407,
#   'predspread': -5.53641414642334,
#   'order': 3.0,
#   'coverprob_diff': 0.017293810844421387,
#   'predspread_diff': -2.439154624938965},
#  {'Team': 'New Orleans Saints',
#   'opponent': 'Green Bay Packers',
#   'spread': 2.0,
#   'score': 17.0,
#   'diff': -1.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 1.0,
#   'coverprob': 0.5439226031303406,
#   'predspread': 0.01796538755297661,
#   'order': 5.0,
#   'coverprob_diff': 0.012991189956665039,
#   'predspread_diff': -5.757501054555178},
#  {'Team': 'Washington Commanders',
#   'opponent': 'Buffalo Bills',
#   'spread': 6.5,
#   'score': 3.0,
#   'diff': -34.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -27.5,
#   'coverprob': 0.42554259300231934,
#   'predspread': -3.097259521484375,
#   'order': 3.0,
#   'coverprob_diff': -0.017293810844421387,
#   'predspread_diff': 2.439154624938965},
#  {'Team': 'Carolina Panthers',
#   'opponent': 'Atlanta Falcons',
#   'spread': 3.5,
#   'score': 27.0,
#   'diff': -10.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -4.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Indianapolis Colts',
#   'opponent': 'Jacksonville Jaguars',
#   'spread': 4.5,
#   'score': 22.0,
#   'diff': 3.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 10.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Jacksonville Jaguars',
#   'opponent': 'Kansas City Chiefs',
#   'spread': 3.5,
#   'score': 17.0,
#   'diff': -20.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -29.5,
#   'coverprob': 0.48904203999999996,
#   'predspread': -1.7138896,
#   'order': nan,
#   'coverprob_diff': 0.14993976999999992,
#   'predspread_diff': nan},
#  {'Team': 'New York Giants',
#   'opponent': 'Arizona Cardinals',
#   'spread': -4.5,
#   'score': 12.0,
#   'diff': -18.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -8.0,
#   'coverprob': 0.48722200000000004,
#   'predspread': 0.09895373,
#   'order': nan,
#   'coverprob_diff': 0.013880100000000062,
#   'predspread_diff': nan},
#  {'Team': 'Cleveland Browns',
#   'opponent': 'Tennessee Titans',
#   'spread': -3.0,
#   'score': 27.0,
#   'diff': 24.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 21.0,
#   'coverprob': 0.5082466006278992,
#   'predspread': -0.17117337882518768,
#   'order': 9.0,
#   'coverprob_diff': 0.08270400762557983,
#   'predspread_diff': -4.676305577158928},
#  {'Team': 'Pittsburgh Steelers',
#   'opponent': 'Las Vegas Raiders',
#   'spread': 2.5,
#   'score': 23.0,
#   'diff': 5.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 7.5,
#   'coverprob': 0.4158334732055664,
#   'predspread': 0.09294605255126953,
#   'order': 13.0,
#   'coverprob_diff': -0.11373525857925415,
#   'predspread_diff': 4.305650234222412},
#  {'Team': 'Cincinnati Bengals',
#   'opponent': 'Cleveland Browns',
#   'spread': -2.0,
#   'score': 19.0,
#   'diff': 3.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 1.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Los Angeles Chargers',
#   'opponent': 'Miami Dolphins',
#   'spread': -3.0,
#   'score': 28.0,
#   'diff': 4.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 5.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Houston Texans',
#   'opponent': 'Baltimore Ravens',
#   'spread': 9.5,
#   'score': 37.0,
#   'diff': 20.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 29.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Miami Dolphins',
#   'opponent': 'Los Angeles Chargers',
#   'spread': 3.0,
#   'score': 70.0,
#   'diff': 50.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 43.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Minnesota Vikings',
#   'opponent': 'Tampa Bay Buccaneers',
#   'spread': -4.5,
#   'score': 24.0,
#   'diff': -4.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -5.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Carolina Panthers',
#   'opponent': 'Seattle Seahawks',
#   'spread': 6.0,
#   'score': 27.0,
#   'diff': -10.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -4.0,
#   'coverprob': 0.5508394241333008,
#   'predspread': -1.7912579774856567,
#   'order': 10.0,
#   'coverprob_diff': 0.12529683113098145,
#   'predspread_diff': -9.049084305763245},
#  {'Team': 'New England Patriots',
#   'opponent': 'Philadelphia Eagles',
#   'spread': 3.5,
#   'score': 15.0,
#   'diff': 5.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 2.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Dallas Cowboys',
#   'opponent': 'Arizona Cardinals',
#   'spread': -12.0,
#   'score': 16.0,
#   'diff': -12.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -24.0,
#   'coverprob': 0.4293907880783081,
#   'predspread': 7.563697814941406,
#   'order': 11.0,
#   'coverprob_diff': -0.10037946701049805,
#   'predspread_diff': 7.632815442979336},
#  {'Team': 'Green Bay Packers',
#   'opponent': 'New Orleans Saints',
#   'spread': -2.0,
#   'score': 18.0,
#   'diff': 1.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -1.0,
#   'coverprob': 0.5309314131736755,
#   'predspread': 5.775466442108154,
#   'order': 5.0,
#   'coverprob_diff': -0.012991189956665039,
#   'predspread_diff': 5.757501054555178},
#  {'Team': 'New York Giants',
#   'opponent': 'Dallas Cowboys',
#   'spread': 2.5,
#   'score': 12.0,
#   'diff': -18.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -8.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'San Francisco 49ers',
#   'opponent': 'Pittsburgh Steelers',
#   'spread': -2.0,
#   'score': 30.0,
#   'diff': 18.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 8.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Miami Dolphins',
#   'opponent': 'Denver Broncos',
#   'spread': -6.5,
#   'score': 70.0,
#   'diff': 50.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 43.5,
#   'coverprob': 0.4158334732055664,
#   'predspread': 1.624570608139038,
#   'order': 4.0,
#   'coverprob_diff': -0.09241312742233276,
#   'predspread_diff': -6.732315301895142},
#  {'Team': 'Minnesota Vikings',
#   'opponent': 'Philadelphia Eagles',
#   'spread': 5.6,
#   'score': 24.0,
#   'diff': -4.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -5.0,
#   'coverprob': 0.44116074000000005,
#   'predspread': -3.2314384,
#   'order': nan,
#   'coverprob_diff': -0.020097359999999953,
#   'predspread_diff': nan},
#  {'Team': 'Philadelphia Eagles',
#   'opponent': 'Minnesota Vikings',
#   'spread': -5.5,
#   'score': 25.0,
#   'diff': 14.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 9.0,
#   'coverprob': 0.4612581,
#   'predspread': -4.5719843,
#   'order': nan,
#   'coverprob_diff': 0.020097359999999953,
#   'predspread_diff': nan},
#  {'Team': 'San Francisco 49ers',
#   'opponent': 'Los Angeles Rams',
#   'spread': -7.5,
#   'score': 30.0,
#   'diff': 18.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 8.0,
#   'coverprob': 0.52859843,
#   'predspread': -4.5766325,
#   'order': nan,
#   'coverprob_diff': -0.013134210000000035,
#   'predspread_diff': nan},
#  {'Team': 'Kansas City Chiefs',
#   'opponent': 'Detroit Lions',
#   'spread': -4.0,
#   'score': 41.0,
#   'diff': 31.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 18.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Pittsburgh Steelers',
#   'opponent': 'San Francisco 49ers',
#   'spread': 2.0,
#   'score': 23.0,
#   'diff': 5.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 7.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Cincinnati Bengals',
#   'opponent': 'Baltimore Ravens',
#   'spread': -3.5,
#   'score': 19.0,
#   'diff': 3.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 1.5,
#   'coverprob': 0.40546715,
#   'predspread': -5.688749,
#   'order': nan,
#   'coverprob_diff': -0.09399610999999997,
#   'predspread_diff': nan},
#  {'Team': 'Las Vegas Raiders',
#   'opponent': 'Buffalo Bills',
#   'spread': 7.5,
#   'score': 18.0,
#   'diff': -5.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -7.5,
#   'coverprob': 0.48904203999999996,
#   'predspread': -2.2871656,
#   'order': nan,
#   'coverprob_diff': -0.011538629999999994,
#   'predspread_diff': nan},
#  {'Team': 'New England Patriots',
#   'opponent': 'Miami Dolphins',
#   'spread': 1.5,
#   'score': 15.0,
#   'diff': 5.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 2.0,
#   'coverprob': 0.40186584000000003,
#   'predspread': 5.371616,
#   'order': nan,
#   'coverprob_diff': -0.08717619999999993,
#   'predspread_diff': nan},
#  {'Team': 'Washington Commanders',
#   'opponent': 'Denver Broncos',
#   'spread': 3.5,
#   'score': 3.0,
#   'diff': -34.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -27.5,
#   'coverprob': 0.412288,
#   'predspread': -4.1413984,
#   'order': nan,
#   'coverprob_diff': 0.05026140000000001,
#   'predspread_diff': nan},
#  {'Team': 'Atlanta Falcons',
#   'opponent': 'Detroit Lions',
#   'spread': 3.0,
#   'score': 6.0,
#   'diff': -14.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -11.0,
#   'coverprob': 0.5674195885658264,
#   'predspread': 9.257000923156738,
#   'order': 1.0,
#   'coverprob_diff': -0.04872429370880127,
#   'predspread_diff': 8.375475525856018},
#  {'Team': 'Denver Broncos',
#   'opponent': 'Miami Dolphins',
#   'spread': 6.5,
#   'score': 20.0,
#   'diff': -50.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -43.5,
#   'coverprob': 0.5082466006278992,
#   'predspread': 8.35688591003418,
#   'order': 4.0,
#   'coverprob_diff': 0.09241312742233276,
#   'predspread_diff': 6.732315301895142},
#  {'Team': 'Detroit Lions',
#   'opponent': 'Kansas City Chiefs',
#   'spread': 4.0,
#   'score': 20.0,
#   'diff': 14.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 11.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Cleveland Browns',
#   'opponent': 'Cincinnati Bengals',
#   'spread': 2.0,
#   'score': 27.0,
#   'diff': 24.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 21.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Dallas Cowboys',
#   'opponent': 'New York Giants',
#   'spread': -3.0,
#   'score': 16.0,
#   'diff': -12.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -24.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Buffalo Bills',
#   'opponent': 'New York Jets',
#   'spread': -2.5,
#   'score': 37.0,
#   'diff': 34.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 27.5,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Philadelphia Eagles',
#   'opponent': 'New England Patriots',
#   'spread': -3.5,
#   'score': 25.0,
#   'diff': 14.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 9.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Seattle Seahawks',
#   'opponent': 'Los Angeles Rams',
#   'spread': -4.5,
#   'score': 37.0,
#   'diff': 10.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 4.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Tennessee Titans',
#   'opponent': 'Los Angeles Chargers',
#   'spread': 2.5,
#   'score': 3.0,
#   'diff': -24.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -21.0,
#   'coverprob': 0.45447230000000005,
#   'predspread': -6.5363617,
#   'order': nan,
#   'coverprob_diff': 0.11537003000000001,
#   'predspread_diff': nan},
#  {'Team': 'New York Jets',
#   'opponent': 'New England Patriots',
#   'spread': 3.0,
#   'score': 10.0,
#   'diff': -5.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -2.0,
#   'coverprob': 0.6052206754684448,
#   'predspread': -0.5892514586448669,
#   'order': 8.0,
#   'coverprob_diff': 0.10392338037490845,
#   'predspread_diff': 2.2639294266700745},
#  {'Team': 'Denver Broncos',
#   'opponent': 'Washington Commanders',
#   'spread': -3.5,
#   'score': 20.0,
#   'diff': -50.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -43.5,
#   'coverprob': 0.3620266,
#   'predspread': 5.8627305,
#   'order': nan,
#   'coverprob_diff': -0.05026140000000001,
#   'predspread_diff': nan},
#  {'Team': 'Arizona Cardinals',
#   'opponent': 'Dallas Cowboys',
#   'spread': 12.0,
#   'score': 28.0,
#   'diff': 12.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 24.0,
#   'coverprob': 0.5297702550888062,
#   'predspread': -0.06911762803792953,
#   'order': 11.0,
#   'coverprob_diff': 0.10037946701049805,
#   'predspread_diff': -7.632815442979336},
#  {'Team': 'Los Angeles Rams',
#   'opponent': 'Cincinnati Bengals',
#   'spread': 1.5,
#   'score': 16.0,
#   'diff': -3.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -1.5,
#   'coverprob': 0.5228101015090942,
#   'predspread': -1.5184215307235718,
#   'order': 15.0,
#   'coverprob_diff': 0.01572871208190918,
#   'predspread_diff': 0.11476492881774902},
#  {'Team': 'Green Bay Packers',
#   'opponent': 'Chicago Bears',
#   'spread': 1.5,
#   'score': 18.0,
#   'diff': 1.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -1.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'New York Jets',
#   'opponent': 'Buffalo Bills',
#   'spread': 3.0,
#   'score': 10.0,
#   'diff': -5.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -2.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Tampa Bay Buccaneers',
#   'opponent': 'Minnesota Vikings',
#   'spread': 4.5,
#   'score': 11.0,
#   'diff': -14.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -9.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Indianapolis Colts',
#   'opponent': 'Houston Texans',
#   'spread': 1.0,
#   'score': 22.0,
#   'diff': 3.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 10.5,
#   'coverprob': 0.3685705,
#   'predspread': -3.1246805,
#   'order': nan,
#   'coverprob_diff': 0.0,
#   'predspread_diff': nan},
#  {'Team': 'New York Jets',
#   'opponent': 'Dallas Cowboys',
#   'spread': 8.5,
#   'score': 10.0,
#   'diff': -5.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -2.0,
#   'coverprob': 0.52597374,
#   'predspread': -7.41571,
#   'order': nan,
#   'coverprob_diff': 0.04296933999999997,
#   'predspread_diff': nan},
#  {'Team': 'Seattle Seahawks',
#   'opponent': 'Detroit Lions',
#   'spread': 4.5,
#   'score': 37.0,
#   'diff': 10.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 4.0,
#   'coverprob': 0.4359415,
#   'predspread': 2.564864,
#   'order': nan,
#   'coverprob_diff': -0.053100539999999974,
#   'predspread_diff': nan},
#  {'Team': 'San Francisco 49ers',
#   'opponent': 'New York Giants',
#   'spread': -10.0,
#   'score': 30.0,
#   'diff': 18.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 8.0,
#   'coverprob': 0.5533764362335205,
#   'predspread': -6.308135032653809,
#   'order': 0.0,
#   'coverprob_diff': -0.008355140686035156,
#   'predspread_diff': -12.357222080230713},
#  {'Team': 'New Orleans Saints',
#   'opponent': 'Tennessee Titans',
#   'spread': -3.0,
#   'score': 17.0,
#   'diff': -1.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': 1.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Pittsburgh Steelers',
#   'opponent': 'Cleveland Browns',
#   'spread': 2.5,
#   'score': 23.0,
#   'diff': 5.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 7.5,
#   'coverprob': 0.4359415,
#   'predspread': -4.873276,
#   'order': nan,
#   'coverprob_diff': -0.10579114,
#   'predspread_diff': nan},
#  {'Team': 'Detroit Lions',
#   'opponent': 'Atlanta Falcons',
#   'spread': -3.0,
#   'score': 20.0,
#   'diff': 14.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 11.0,
#   'coverprob': 0.6161438822746277,
#   'predspread': 0.8815253973007202,
#   'order': 1.0,
#   'coverprob_diff': 0.04872429370880127,
#   'predspread_diff': -8.375475525856018},
#  {'Team': 'Indianapolis Colts',
#   'opponent': 'Baltimore Ravens',
#   'spread': 7.5,
#   'score': 22.0,
#   'diff': 3.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 10.5,
#   'coverprob': 0.4382648468017578,
#   'predspread': 0.8230835199356079,
#   'order': 2.0,
#   'coverprob_diff': 0.025605320930480957,
#   'predspread_diff': 1.472813367843628},
#  {'Team': 'Atlanta Falcons',
#   'opponent': 'Carolina Panthers',
#   'spread': -3.5,
#   'score': 6.0,
#   'diff': -14.0,
#   'Week': 1,
#   'Year': 2023,
#   'spreadscore': -11.0,
#   'coverprob': nan,
#   'predspread': nan,
#   'order': nan,
#   'coverprob_diff': nan,
#   'predspread_diff': nan},
#  {'Team': 'Arizona Cardinals',
#   'opponent': 'New York Giants',
#   'spread': 4.5,
#   'score': 28.0,
#   'diff': 12.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 24.0,
#   'coverprob': 0.4733419,
#   'predspread': 0.14908272,
#   'order': nan,
#   'coverprob_diff': -0.013880100000000062,
#   'predspread_diff': nan},
#  {'Team': 'Los Angeles Chargers',
#   'opponent': 'Tennessee Titans',
#   'spread': -2.5,
#   'score': 28.0,
#   'diff': 4.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 5.0,
#   'coverprob': 0.33910227000000004,
#   'predspread': -5.080024,
#   'order': nan,
#   'coverprob_diff': -0.11537003000000001,
#   'predspread_diff': nan},
#  {'Team': 'New Orleans Saints',
#   'opponent': 'Carolina Panthers',
#   'spread': -3.0,
#   'score': 17.0,
#   'diff': -1.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 1.0,
#   'coverprob': 0.40186584000000003,
#   'predspread': -4.929265,
#   'order': nan,
#   'coverprob_diff': -0.06643995999999996,
#   'predspread_diff': nan},
#  {'Team': 'Tampa Bay Buccaneers',
#   'opponent': 'Chicago Bears',
#   'spread': -2.5,
#   'score': 11.0,
#   'diff': -14.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': -9.0,
#   'coverprob': 0.50920483,
#   'predspread': 7.881182,
#   'order': nan,
#   'coverprob_diff': 0.10373768000000005,
#   'predspread_diff': nan},
#  {'Team': 'Houston Texans',
#   'opponent': 'Jacksonville Jaguars',
#   'spread': 9.5,
#   'score': 37.0,
#   'diff': 20.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': 29.5,
#   'coverprob': 0.6161438822746277,
#   'predspread': -4.531844139099121,
#   'order': 6.0,
#   'coverprob_diff': 0.04758036136627197,
#   'predspread_diff': -3.8069530725479126},
#  {'Team': 'Cleveland Browns',
#   'opponent': 'Pittsburgh Steelers',
#   'spread': -2.5,
#   'score': 27.0,
#   'diff': 24.0,
#   'Week': 2,
#   'Year': 2023,
#   'spreadscore': 21.0,
#   'coverprob': 0.54173264,
#   'predspread': 2.221873,
#   'order': nan,
#   'coverprob_diff': 0.10579114,
#   'predspread_diff': nan},
#  {'Team': 'Baltimore Ravens',
#   'opponent': 'Indianapolis Colts',
#   'spread': -7.5,
#   'score': 19.0,
#   'diff': -3.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -10.5,
#   'coverprob': 0.41265952587127686,
#   'predspread': -0.64972984790802,
#   'order': 2.0,
#   'coverprob_diff': -0.025605320930480957,
#   'predspread_diff': -1.472813367843628},
#  {'Team': 'New York Giants',
#   'opponent': 'San Francisco 49ers',
#   'spread': 10.0,
#   'score': 12.0,
#   'diff': -18.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -8.0,
#   'coverprob': 0.5617315769195557,
#   'predspread': 6.049087047576904,
#   'order': 0.0,
#   'coverprob_diff': 0.008355140686035156,
#   'predspread_diff': 12.357222080230713},
#  {'Team': 'Tennessee Titans',
#   'opponent': 'Cleveland Browns',
#   'spread': 3.0,
#   'score': 3.0,
#   'diff': -24.0,
#   'Week': 3,
#   'Year': 2023,
#   'spreadscore': -21.0,
#   'coverprob': 0.42554259300231934,
#   'predspread': 4.50513219833374,
#   'order': 9.0,
#   'coverprob_diff': -0.08270400762557983,
#   'predspread_diff': 4.676305577158928},
#  {'Team': 'Arizona Cardinals',
#   'opponent': 'San Francisco 49ers',
#   'spread': 14.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.42743828892707825,
#   'predspread': 0.1527784913778305,
#   'order': 12.0,
#   'coverprob_diff': -0.062240660190582275,
#   'predspread_diff': -1.7450771480798721},
#  {'Team': 'Atlanta Falcons',
#   'opponent': 'Jacksonville Jaguars',
#   'spread': 3.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5852723717689514,
#   'predspread': 1.940460443496704,
#   'order': 1.0,
#   'coverprob_diff': 0.13263195753097534,
#   'predspread_diff': 2.6467296481132507},
#  {'Team': 'Baltimore Ravens',
#   'opponent': 'Cleveland Browns',
#   'spread': 2.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6004742383956909,
#   'predspread': 2.0729827880859375,
#   'order': 2.0,
#   'coverprob_diff': 0.1642475724220276,
#   'predspread_diff': 0.8763167858123779},
#  {'Team': 'Buffalo Bills',
#   'opponent': 'Miami Dolphins',
#   'spread': -3.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.42743828892707825,
#   'predspread': -1.1674468517303467,
#   'order': 3.0,
#   'coverprob_diff': 0.0031648874282836914,
#   'predspread_diff': 0.5161949396133423},
#  {'Team': 'Carolina Panthers',
#   'opponent': 'Minnesota Vikings',
#   'spread': 4.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4408930838108063,
#   'predspread': -0.9763240814208984,
#   'order': 4.0,
#   'coverprob_diff': -0.09231188893318176,
#   'predspread_diff': -1.6937532424926758},
#  {'Team': 'Chicago Bears',
#   'opponent': 'Denver Broncos',
#   'spread': 3.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5336779356002808,
#   'predspread': 1.4495354890823364,
#   'order': 5.0,
#   'coverprob_diff': 0.05499139428138733,
#   'predspread_diff': 0.8578299880027771},
#  {'Team': 'Cincinnati Bengals',
#   'opponent': 'Tennessee Titans',
#   'spread': -2.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5456827878952026,
#   'predspread': 1.698043704032898,
#   'order': 6.0,
#   'coverprob_diff': 0.0768713653087616,
#   'predspread_diff': 1.1818246245384216},
#  {'Team': 'Cleveland Browns',
#   'opponent': 'Baltimore Ravens',
#   'spread': -2.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.43622666597366333,
#   'predspread': 1.1966660022735596,
#   'order': 2.0,
#   'coverprob_diff': -0.1642475724220276,
#   'predspread_diff': -0.8763167858123779},
#  {'Team': 'Dallas Cowboys',
#   'opponent': 'New England Patriots',
#   'spread': -6.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.47868654131889343,
#   'predspread': -1.0897595882415771,
#   'order': 13.0,
#   'coverprob_diff': -0.10679551959037781,
#   'predspread_diff': -1.9857370257377625},
#  {'Team': 'Denver Broncos',
#   'opponent': 'Chicago Bears',
#   'spread': -3.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.47868654131889343,
#   'predspread': 0.5917055010795593,
#   'order': 5.0,
#   'coverprob_diff': -0.05499139428138733,
#   'predspread_diff': -0.8578299880027771},
#  {'Team': 'Detroit Lions',
#   'opponent': 'Green Bay Packers',
#   'spread': -1.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.7234614491462708,
#   'predspread': 1.7952731847763062,
#   'order': 0.0,
#   'coverprob_diff': 0.2682742774486542,
#   'predspread_diff': -0.8830910921096802},
#  {'Team': 'Green Bay Packers',
#   'opponent': 'Detroit Lions',
#   'spread': 1.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4551871716976166,
#   'predspread': 2.6783642768859863,
#   'order': 0.0,
#   'coverprob_diff': -0.2682742774486542,
#   'predspread_diff': 0.8830910921096802},
#  {'Team': 'Houston Texans',
#   'opponent': 'Pittsburgh Steelers',
#   'spread': 3.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4290100336074829,
#   'predspread': 1.3887099027633667,
#   'order': 7.0,
#   'coverprob_diff': -0.10603493452072144,
#   'predspread_diff': 0.014510631561279297},
#  {'Team': 'Indianapolis Colts',
#   'opponent': 'Los Angeles Rams',
#   'spread': -1.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.7175409197807312,
#   'predspread': 3.0614824295043945,
#   'order': 8.0,
#   'coverprob_diff': 0.49859440326690674,
#   'predspread_diff': 4.449153304100037},
#  {'Team': 'Jacksonville Jaguars',
#   'opponent': 'Atlanta Falcons',
#   'spread': -3.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4526404142379761,
#   'predspread': -0.7062692046165466,
#   'order': 1.0,
#   'coverprob_diff': -0.13263195753097534,
#   'predspread_diff': -2.6467296481132507},
#  {'Team': 'Kansas City Chiefs',
#   'opponent': 'New York Jets',
#   'spread': -9.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.41261523962020874,
#   'predspread': 1.9848369359970093,
#   'order': 14.0,
#   'coverprob_diff': 0.094611257314682,
#   'predspread_diff': 3.5780924558639526},
#  {'Team': 'Las Vegas Raiders',
#   'opponent': 'Los Angeles Chargers',
#   'spread': 5.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6115743517875671,
#   'predspread': 1.0517170429229736,
#   'order': 11.0,
#   'coverprob_diff': -0.017240405082702637,
#   'predspread_diff': -0.2833799123764038},
#  {'Team': 'Los Angeles Chargers',
#   'opponent': 'Las Vegas Raiders',
#   'spread': -5.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6288147568702698,
#   'predspread': 1.3350969552993774,
#   'order': 11.0,
#   'coverprob_diff': 0.017240405082702637,
#   'predspread_diff': 0.2833799123764038},
#  {'Team': 'Los Angeles Rams',
#   'opponent': 'Indianapolis Colts',
#   'spread': 1.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.21894651651382446,
#   'predspread': -1.387670874595642,
#   'order': 8.0,
#   'coverprob_diff': -0.49859440326690674,
#   'predspread_diff': -4.449153304100037},
#  {'Team': 'Miami Dolphins',
#   'opponent': 'Buffalo Bills',
#   'spread': 3.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.42427340149879456,
#   'predspread': -1.683641791343689,
#   'order': 3.0,
#   'coverprob_diff': -0.0031648874282836914,
#   'predspread_diff': -0.5161949396133423},
#  {'Team': 'Minnesota Vikings',
#   'opponent': 'Carolina Panthers',
#   'spread': -4.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.533204972743988,
#   'predspread': 0.7174291610717773,
#   'order': 4.0,
#   'coverprob_diff': 0.09231188893318176,
#   'predspread_diff': 1.6937532424926758},
#  {'Team': 'New England Patriots',
#   'opponent': 'Dallas Cowboys',
#   'spread': 6.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5854820609092712,
#   'predspread': 0.8959774374961853,
#   'order': 13.0,
#   'coverprob_diff': 0.10679551959037781,
#   'predspread_diff': 1.9857370257377625},
#  {'Team': 'New Orleans Saints',
#   'opponent': 'Tampa Bay Buccaneers',
#   'spread': -3.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.38506144285202026,
#   'predspread': 2.20150089263916,
#   'order': 9.0,
#   'coverprob_diff': -0.27850502729415894,
#   'predspread_diff': 2.0005494952201843},
#  {'Team': 'New York Giants',
#   'opponent': 'Seattle Seahawks',
#   'spread': -1.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6770291924476624,
#   'predspread': 1.2713764905929565,
#   'order': 15.0,
#   'coverprob_diff': 0.1038593053817749,
#   'predspread_diff': 0.07471048831939697},
#  {'Team': 'New York Jets',
#   'opponent': 'Kansas City Chiefs',
#   'spread': 9.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.31800398230552673,
#   'predspread': -1.5932555198669434,
#   'order': 14.0,
#   'coverprob_diff': -0.094611257314682,
#   'predspread_diff': -3.5780924558639526},
#  {'Team': 'Philadelphia Eagles',
#   'opponent': 'Washington Commanders',
#   'spread': -8.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.47611546516418457,
#   'predspread': 1.7801939249038696,
#   'order': 10.0,
#   'coverprob_diff': 0.028380990028381348,
#   'predspread_diff': 2.268492817878723},
#  {'Team': 'Pittsburgh Steelers',
#   'opponent': 'Houston Texans',
#   'spread': -3.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5350449681282043,
#   'predspread': 1.3741992712020874,
#   'order': 7.0,
#   'coverprob_diff': 0.10603493452072144,
#   'predspread_diff': -0.014510631561279297},
#  {'Team': 'San Francisco 49ers',
#   'opponent': 'Arizona Cardinals',
#   'spread': -14.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4896789491176605,
#   'predspread': 1.8978556394577026,
#   'order': 12.0,
#   'coverprob_diff': 0.062240660190582275,
#   'predspread_diff': 1.7450771480798721},
#  {'Team': 'Seattle Seahawks',
#   'opponent': 'New York Giants',
#   'spread': 1.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.5731698870658875,
#   'predspread': 1.1966660022735596,
#   'order': 15.0,
#   'coverprob_diff': -0.1038593053817749,
#   'predspread_diff': -0.07471048831939697},
#  {'Team': 'Tampa Bay Buccaneers',
#   'opponent': 'New Orleans Saints',
#   'spread': 3.0,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.6635664701461792,
#   'predspread': 0.20095139741897583,
#   'order': 9.0,
#   'coverprob_diff': 0.27850502729415894,
#   'predspread_diff': -2.0005494952201843},
#  {'Team': 'Tennessee Titans',
#   'opponent': 'Cincinnati Bengals',
#   'spread': 2.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.46881142258644104,
#   'predspread': 0.5162190794944763,
#   'order': 6.0,
#   'coverprob_diff': -0.0768713653087616,
#   'predspread_diff': -1.1818246245384216},
#  {'Team': 'Washington Commanders',
#   'opponent': 'Philadelphia Eagles',
#   'spread': 8.5,
#   'score': nan,
#   'diff': nan,
#   'Week': 4,
#   'Year': 2023,
#   'spreadscore': nan,
#   'coverprob': 0.4477344751358032,
#   'predspread': -0.4882988929748535,
#   'order': 10.0,
#   'coverprob_diff': -0.028380990028381348,
#   'predspread_diff': -2.268492817878723}]

# %%
# Insert the data into the MongoDB collection
collection.insert_many(data)
# Close the MongoDB connection
client.close()

# %% [markdown]
# ### below no longer needed
